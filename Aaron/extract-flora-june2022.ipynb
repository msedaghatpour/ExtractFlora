# %%
#!pip uninstall fitz PyMuPDF --yes
#!pip install PyMuPDF
#!pip install PyMuPDF==1.19.1  ## install a release later than 1.19.0
#!pip install PyMuPDF==1.18.19  ## don't install 1.19.0 because of Wrong x0/y0 values for bboxes in get_text("words"), see: https://github.com/pymupdf/PyMuPDF/issues/1328
# ## Releases of PyMuPDF as of Oct 18, 2021: 1.11.2, 1.12.5, 1.13.20, 1.14.19.post2, 1.14.20, 1.14.21, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.16.7, 1.16.8, 1.16.9, 1.16.10, 1.16.11, 1.16.12, 1.16.13, 1.16.14, 1.16.15, 1.16.16, 1.16.17, 1.16.18, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.17.6, 1.17.7, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.18.6, 1.18.7, 1.18.8, 1.18.9, 1.18.10, 1.18.11, 1.18.12, 1.18.13, 1.18.14, 1.18.15, 1.18.16, 1.18.17, 1.18.18, 1.18.19, 1.19.0

# %%
# !open -a Preview book-1.pdf book-2.pdf book-3.pdf

# %%
config = [
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 1.pdf",
    "name" : "book-1",
    "page_count" : 642,
    "sections" : {
      "preface" : [1, 78],
      "toponymique" : [49, 76],
      "abbrev" : [77, 78],
      "content" : [79, 607],
      "sample" : [79, 79+10],
      "index" : [617, 639]},
    },
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 2.pdf",
    "name" : "book-2",
    "page_count" : 725,
    "sections" : {
      "preface" : [1, 79],
      "abbrev" : [6, 7],
      "content" : [8, 700],
      "sample" : [8, 8+10],
      "index" : [704, 725]},
    },
   {"filename" : "NOUVELLE FLORE DU LIBAN ET DE LA SYRIE 3.pdf",
    "name" : "book-3",
    "page_count" : 588,
    "sections" : {
      "preface" : [1, 7],
      "abbrev" : [6, 7],
      "content" : [8, 554],
      "sample" : [8, 8+10],
      "index" : [556, 583],
      "familyidx" : [584, 585]},
    },
]

# %%
import sys, fitz, re
from pprint import pprint

## Purpose: this cell is a pre-processing step that will create a symlink (e.g. book-1.pdf)
##          that points to the original file, and then will create new PDF documents
##          that are excerpts of subsets of the whole book
##          as named sections such as book-1-index.pdf or book-1-abbrev.pdf
##          The file book-X-sample.pdf contains the first 10 pages of the book-1-content.pdf
##          and the sample is used to speed up development/testing later on

## https://pymupdf.readthedocs.io/en/latest/document.html#Document.delete_pages
##    In general, the performance of this method is dependent on the number of remaining pages
##    NOT on the number of deleted pages
## So, keeping fewer pages is faster, and deleting more pages at once is also faster 
def excerpt(infile, outfile, start, end):
  doc = fitz.open(infile)  # open document
  last_page = doc.page_count
  print(start, end, last_page, outfile)
  deleteme = []
  if start - 1 > 0:
    deleteme.extend(list(range(0, start - 1)))       
  if end < last_page:
    deleteme.extend(list(range(end, last_page)))
  # print(deleteme)
  doc.delete_pages(deleteme)
  doc.save(outfile, garbage=4, clean=True)

import os, os.path
for book in config:
   symlink = book["name"] + ".pdf"
   fname = book["filename"]
   if os.path.exists(book["filename"]) and not os.path.exists(symlink):
      print("Creating symlink: ", symlink, " ->", fname)
      os.symlink(book["filename"], symlink)
   for section in book["sections"]:
      #print(s)
      start, end = book["sections"][section];
      out_fname = book["name"] + "-" + section + ".pdf"
      excerpt(book["filename"], out_fname, start, end)

#!open -a Preview book-[1,2,3]-*.pdf

## Runtime of this cell is ~11m38s
# Out:
# 1 78 642 book-1-preface.pdf
# 49 76 642 book-1-toponymique.pdf
# 77 78 642 book-1-abbrev.pdf
# 79 607 642 book-1-content.pdf
# 79 89 642 book-1-sample.pdf
# 617 639 642 book-1-index.pdf
# 1 79 725 book-2-preface.pdf
# 6 7 725 book-2-abbrev.pdf
# 8 700 725 book-2-content.pdf
# 8 18 725 book-2-sample.pdf
# 704 725 725 book-2-index.pdf
# 1 7 588 book-3-preface.pdf
# 6 7 588 book-3-abbrev.pdf
# 8 554 588 book-3-content.pdf
# 8 18 588 book-3-sample.pdf
# 556 583 588 book-3-index.pdf
# 584 585 588 book-3-familyidx.pdf

# %%
# !open -a Preview book-[1,2,3]-*.pdf

# %%
# !open -a Preview book-[1,2,3]-index.pdf

# %%
# https://pymupdf.readthedocs.io/en/latest/faq/#how-to-analyze-font-characteristics

import fitz
import pprint, re

def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return ", ".join(l)

class Face:
    def __init__(self, font, size, color, flags=0):
        self.font = font
        self.size = size
        self.color = color
        self.flags = flags
        self.style = flags_decomposer(self.flags)
    def __str__(self):
        return f"Font: '{self.font}' ({self.style}), size {self.size:g}, color " + ("#%06x" % self.color)
print(Face("Times", 10.929, 0, 4))
# Out:
# Font: 'Times' (serifed, proportional), size 10.929, color #000000

# %%
import sys, fitz, re
from pprint import pprint
# fname = "book-1-sample.pdf"
fname = "book-3.pdf"
doc = fitz.open(fname)  # open document

from fitz.utils import getColor
#blue = getColor("aliceblue")

# txtpgoffset = 77
txtpgoffset = 0
# start_page = 1 + txtpgoffset
start_page = 1
#end_page = start_page + 11
#end_page = start_page + 150
#end_page = start_page + 530
end_page = doc.page_count
items = []
mode = "searching"
print(mode)
for i in range(start_page, end_page):
    page = doc[i]
    # read page text as a dictionary, suppressing extra spaces in CJK fonts
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", flags=flags)["blocks"]
    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        #annot = page.add_rect_annot(br)
        for y,l in enumerate(b["lines"]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            for z,s in enumerate(l["spans"]):  # iterate through the text spans
                if z==0 and mode == "found":
                    mode = "spanning"
                #s["style"] = flags_decomposer(s["flags"])  # readable font flags
                face = Face(s["font"], s["size"], s["color"], s["flags"])
                t = s["text"]
                ## FIXME: [83, 'N  Cystopteris  filix-fragilis  (L.) Borb. —  Polypodiumfilix-fragile  L.,  Cyst,  fragilis']
                ## FIXMECLASS: OCR Error; a spurious mark in the text preceding the genus is interpreted as a letter 'N'
                if z==0 and mode != "found" and re.search(r"Times-Bold\b", str(face)) and s["size"] > 10.0:
                        r_rect = fitz.Rect(lr)
                        r_high = fitz.Rect(s["bbox"])
                        joined = " ".join(list(map(lambda x: x["text"].strip(), l["spans"])))  ## FIXMEDESC: ideally this simplistic code would work if not for OCR Errors
                        item = joined
                        # found = re.match(r"(?P<genus>([A-Z]\w+) (?P<species>\w+)", joined)
                        # d = found.groupdict()
                        matches = re.match(r"([A-Z]\w+) (\w+)", joined)
                        warning = "Possible OCR Error"
                        if matches and len(matches.groups()) == 2:
                            found = matches.groups()
                            warning = "Normal"
                            mode = "found"
                            # item = f"""${d['genus']} ${d['species']}"""
                            item = " ".join(found)
                        else:
                            warning = "Possible OCR Error"

                        print([i, x, y, z, item, warning])
                        annot_high = page.add_highlight_annot(r_high)
                        items.append([t, r_rect, r_high, i, z,s, y,l, x,b, warning])
print(len(items))
#print(i, items[0][:3])
# Out:
# searching
# [6, 8, 5, 0, 'JL', 'Possible OCR Error']
# [7, 6, 0, 0, 'Rhododendron ponticum', 'Normal']
# [8, 4, 0, 0, 'Arbutus unedo', 'Normal']
# [8, 8, 0, 0, 'Arbutus andrachne', 'Normal']
# [9, 1, 0, 0, 'Erica manipuliflora', 'Normal']
# [9, 13, 0, 0, 'Pentapera sicula', 'Normal']
# [10, 7, 0, 0, 'Samolus valerandi', 'Normal']
# [10, 16, 0, 0, 'Ânagallis arvensis L. — A. phoenicea Scop., A. caerulea L., A. latifolia L.', 'Possible OCR Error']
# [11, 18, 0, 0, 'Lysimachia dubia', 'Normal']
# [11, 25, 0, 0, 'Asterolinon linum', 'Normal']
# [12, 12, 0, 0, 'Cyclamen coum', 'Normal']
# [12, 21, 0, 0, 'Cyclamen libanoticum', 'Normal']
# [13, 9, 0, 0, 'Cyclamen persicum', 'Normal']
# [14, 7, 0, 0, 'Androsace villosa', 'Normal']
# [14, 13, 0, 0, 'Androsace multiscapa', 'Normal']
# [14, 18, 0, 0, 'Androsace maxima', 'Normal']
# [15, 3, 0, 0, 'Primula vulgaris', 'Normal']
# [16, 19, 0, 0, 'Acantholimon damassanum', 'Normal']
# [17, 14, 0, 0, 'Acantholimon acerosum', 'Normal']
# [18, 1, 0, 0, 'Acantholimon antilibanoticum', 'Normal']
# [18, 16, 0, 0, 'Acantholimon libanoticum', 'Normal']
# [19, 6, 1, 0, 'Acantholimon ulicinum', 'Normal']
# [20, 1, 0, 0, 'Goniolimon collinum', 'Normal']
# [20, 22, 0, 0, 'Limonium sinuatum', 'Normal']
# [21, 5, 0, 0, 'Limonium thouinii', 'Normal']
# [21, 11, 0, 0, 'Limonium angustifolium', 'Normal']
# [21, 16, 0, 0, 'Limonium sieberi', 'Normal']
# [22, 5, 0, 0, 'Limonium virgatum', 'Normal']
# [22, 8, 0, 0, 'Limonium graecum', 'Normal']
# [22, 13, 0, 0, 'Limonium palmyrense', 'Normal']
# [23, 1, 0, 0, 'Limoniumglobuliferum (Boiss. etHeldr.) O. Kuntze— StaticeglobuliferaBoks.', 'Possible OCR Error']
# [23, 8, 0, 0, 'Psylliostachys spicatus', 'Normal']
# [23, 15, 0, 0, 'Armeria undulata', 'Normal']
# [24, 7, 0, 0, 'Plumbago europaea', 'Normal']
# [25, 3, 0, 0, 'Styrax officinalis', 'Normal']
# [25, 20, 0, 0, 'Olea europaea', 'Normal']
# [26, 8, 0, 0, 'Phillyrea media', 'Normal']
# [26, 18, 0, 0, 'Fontanesia phillyreoides', 'Normal']
# [27, 8, 0, 0, 'Fraxinus ornus', 'Normal']
# [27, 16, 0, 0, 'Fraxinus excelsior', 'Normal']
# [27, 18, 3, 0, 'Fraxinus syriaca', 'Normal']
# [28, 5, 0, 0, 'Jasminum fruticans', 'Normal']
# [29, 1, 0, 0, 'Vinca major', 'Normal']
# [29, 8, 0, 0, 'Vinca herbacea', 'Normal']
# [29, 11, 0, 0, 'Vinca libanotica', 'Normal']
# [29, 20, 0, 0, 'Trachomitum venetum', 'Normal']
# [30, 6, 0, 0, 'Nerium oleander', 'Normal']
# [31, 3, 0, 0, 'Blackstonia perfoliata', 'Normal']
# [31, 8, 1, 0, 'Blackstonia acuminata', 'Normal']
# [31, 15, 0, 0, 'Cicendia filifortnis', 'Normal']
# [32, 11, 0, 0, 'Centaurium pulchellum', 'Normal']
# [32, 18, 0, 0, 'Centaurium tenuiflorum', 'Normal']
# [33, 1, 0, 0, 'Centaurium erythraea', 'Normal']
# [33, 22, 0, 0, 'Centaurium maritimum', 'Normal']
# [33, 26, 0, 0, 'Centaurium spicatum', 'Normal']
# [34, 6, 0, 0, 'Gentiana olivieri', 'Normal']
# [35, 10, 0, 0, 'Vincetoxicum canescens', 'Normal']
# [35, 15, 0, 0, 'Vincetoxicum dionysiense', 'Normal']
# [36, 10, 0, 0, 'Cynanchum acutum', 'Normal']
# [36, 19, 0, 0, 'Cionura erecta', 'Normal']
# [37, 16, 0, 0, 'Periploca graeca', 'Normal']
# [38, 5, 0, 0, 'Periploca angustifolia', 'Normal']
# [40, 12, 0, 0, 'Convolvulus hamrinensis', 'Normal']
# [40, 19, 0, 0, 'Convolvulus dorycnium', 'Normal']
# [41, 7, 0, 0, 'Convolvulus cantabrica', 'Normal']
# [41, 16, 0, 0, 'Convolvulus lineatus', 'Normal']
# [41, 22, 0, 0, 'Convolvulus libanoticus', 'Normal']
# [42, 3, 2, 0, 'Convolvulus secundus', 'Normal']
# [42, 8, 0, 0, 'Convolvulus reticulatus', 'Normal']
# [42, 14, 0, 0, 'Convolvulus pilosellifolius', 'Normal']
# [43, 4, 0, 0, 'Convolvulus galaticus', 'Normal']
# [43, 7, 0, 0, 'Convolvulus betonicifolius', 'Normal']
# [43, 14, 0, 0, 'Convolvulus cassius', 'Normal']
# [44, 3, 0, 0, 'Convolvulus stenophyllus', 'Normal']
# [44, 8, 0, 0, 'Convolvulus althaeoides', 'Normal']
# [44, 17, 0, 0, 'Convolvulus elegantissimus', 'Normal']
# [45, 3, 0, 0, 'Convolvulus stachydifolius', 'Normal']
# [45, 10, 0, 0, 'Convolvulus scammonia', 'Normal']
# [45, 17, 0, 0, 'Convolvulus arvensis', 'Normal']
# [46, 7, 0, 0, 'Convolvulus coelesyriacus', 'Normal']
# [46, 12, 0, 0, 'Convolvulus siculus', 'Normal']
# [46, 15, 0, 0, 'Convolvulus pentapetaloides', 'Normal']
# [47, 6, 0, 0, 'Convolvulus tricolor', 'Normal']
# [47, 11, 0, 0, 'Convolvulus humilis', 'Normal']
# [47, 19, 0, 0, 'Calystegia sepium', 'Normal']
# [48, 3, 0, 0, 'Calystegia silvatica', 'Normal']
# [48, 14, 0, 0, 'Ipomoea stolonifera', 'Normal']
# [48, 20, 0, 0, 'Ipomoea sagittata', 'Normal']
# [49, 3, 0, 0, 'Ipomoea palmata', 'Normal']
# [49, 10, 0, 0, 'Gressa eretica', 'Normal']
# [51, 1, 0, 0, 'Cuscuta epithymum', 'Normal']
# [51, 10, 0, 0, 'Guscuta planiflora', 'Normal']
# [51, 13, 0, 0, 'Cuscuta approximata', 'Normal']
# [52, 8, 0, 0, 'Cuscuta palaestina', 'Normal']
# [52, 18, 0, 0, 'Cuscuta balansae', 'Normal']
# [53, 6, 0, 0, 'Cuscuta brevistyla', 'Normal']
# [53, 14, 0, 0, 'Cuscuta europaea', 'Normal']
# [54, 5, 0, 0, 'Cuscuta kotschyana', 'Normal']
# [54, 8, 0, 0, 'Cuscuta babylonica', 'Normal']
# [54, 11, 0, 0, 'Cuscuta pedicellata', 'Normal']
# [54, 17, 0, 0, 'Cuscuta campestris', 'Normal']
# [55, 6, 0, 0, 'Cuscuta monogyna', 'Normal']
# [56, 22, 0, 0, 'Heliotropium supinum', 'Normal']
# [56, 29, 0, 0, 'Heliotropium myosotoides', 'Normal']
# [57, 7, 0, 0, 'Heliotropium lasiocarpum', 'Normal']
# [57, 15, 0, 0, 'Heliotropium dolosum', 'Normal']
# [57, 18, 0, 0, 'Heliotropium hirsutissimum', 'Normal']
# [58, 8, 0, 0, 'Heliotropium bovei', 'Normal']
# [58, 15, 0, 0, 'Heliotropium schweinfurthii', 'Normal']
# [59, 1, 0, 0, 'Heliotropium greuteri', 'Normal']
# [59, 6, 0, 0, 'Heliotropium rotundifolium', 'Normal']
# [59, 11, 0, 0, 'Heliotropium ramosissimum', 'Normal']
# [60, 2, 0, 0, 'Asperugo procumbens', 'Normal']
# [60, 11, 0, 0, 'Caccinia macranthera', 'Normal']
# [61, 8, 0, 0, 'Lappula spinocarpos', 'Normal']
# [61, 14, 0, 0, 'Lappula barbata', 'Normal']
# [62, 1, 0, 0, 'Lappula sinaica', 'Normal']
# [62, 6, 0, 0, 'Lappula sessiliflora', 'Normal']
# [62, 16, 0, 0, 'Heterocaryum szovitsianum', 'Normal']
# [63, 5, 0, 0, 'Heterocaryum subsessile', 'Normal']
# [63, 11, 0, 0, 'Rindera schlumbergeri', 'Normal']
# [64, 3, 0, 0, 'Paracaryum rugulosum', 'Normal']
# [64, 11, 0, 0, 'Mattiastrum lithospermifolium', 'Normal']
# [64, 17, 0, 0, 'Mattiastrum lamprocarpum', 'Normal']
# [65, 11, 0, 0, 'Rochelia cancellata', 'Normal']
# [65, 16, 0, 0, 'Rochelia disperma', 'Normal']
# [66, 5, 0, 0, 'Rochelia persica', 'Normal']
# [66, 14, 0, 0, 'Solenanthus stamineus', 'Normal']
# [66, 20, 0, 0, 'Solenanthus circinnatus', 'Normal']
# [67, 7, 0, 0, 'Moltkia coerulea', 'Normal']
# [67, 12, 0, 0, 'Moltkia longiflora', 'Normal']
# [68, 5, 0, 0, 'Cynoglossum nebrodense', 'Normal']
# [68, 13, 0, 0, 'Cynoglossum creticum', 'Normal']
# [69, 15, 0, 0, 'Lithospermum officinale', 'Normal']
# [69, 19, 0, 0, 'Lithospermum arvense', 'Normal']
# [70, 1, 0, 0, 'Lithospermum sibthorpianum', 'Normal']
# [70, 4, 0, 0, 'Lithospermum incrassatum', 'Normal']
# [70, 11, 0, 0, 'Lithospermum tenuiflorum', 'Normal']
# [70, 18, 0, 0, 'Lithospermum purpurocaeruleum', 'Normal']
# [71, 5, 0, 0, 'Lithodora hispidula', 'Normal']
# [71, 14, 0, 0, 'Arnebia decumbens', 'Normal']
# [72, 4, 0, 0, 'Ârnebia tubata (Bertol.) Sam. —• Lithospermum tubatum Bertol. (PI. XXXII,', 'Possible OCR Error']
# [72, 9, 0, 0, 'Arnebia lînearifolia', 'Normal']
# [73, 1, 0, 0, 'Cerinthe minor', 'Normal']
# [73, 7, 0, 0, 'Cerinthe major', 'Normal']
# [73, 12, 0, 0, 'Cerinthe palaestina', 'Normal']
# [74, 27, 0, 0, 'Onosma orientalis', 'Normal']
# [75, 9, 0, 0, 'Onosma setosa', 'Normal']
# [76, 12, 0, 0, 'Onosma frutescents', 'Normal']
# [76, 18, 0, 0, 'Onosma cassia', 'Normal']
# [77, 9, 0, 0, 'Onosma mollis', 'Normal']
# [77, 12, 0, 0, 'Onosma cinerea', 'Normal']
# [78, 2, 0, 0, 'Onosma caerulescens', 'Normal']
# [78, 9, 0, 0, 'Onosma rascheyana', 'Normal']
# [79, 5, 0, 0, 'Onosma roussaei', 'Normal']
# [79, 13, 0, 0, 'Onosma aucherana', 'Normal']
# [79, 23, 0, 0, 'Onosma gigantea', 'Normal']
# [80, 6, 0, 0, 'Onosma auriculata', 'Normal']
# [81, 1, 0, 0, 'Echium glomeratum', 'Normal']
# [81, 8, 0, 0, 'Echium italicum', 'Normal']
# [81, 15, 0, 0, 'Echium pabotii', 'Normal']
# [82, 3, 0, 0, 'Echium angustifolium', 'Normal']
# [82, 8, 0, 0, 'Echium plantagineum', 'Normal']
# [82, 15, 0, 0, 'Echium judaeum', 'Normal']
# [83, 6, 0, 0, 'Echium setosum', 'Normal']
# [84, 10, 0, 0, 'Anchusa hybrida', 'Normal']
# [84, 17, 0, 0, 'Anchusa azurea', 'Normal']
# [85, 1, 0, 0, 'Anchusa strigosa', 'Normal']
# [85, 13, 0, 0, 'Anchusa barrelieri', 'Normal']
# [86, 1, 0, 0, 'Anchusa aegyptiaca', 'Normal']
# [86, 9, 0, 0, 'Anchusa milleri', 'Normal']
# [86, 12, 0, 0, 'Anchusa tiberiadis', 'Normal']
# [87, 7, 0, 0, 'Hormuzakia aggregata', 'Normal']
# [87, 18, 0, 0, 'Gastrocotyle hispida', 'Normal']
# [88, 3, 0, 0, 'Phyllocara aucheri', 'Normal']
# [88, 8, 0, 0, 'Brunnera orientalis', 'Normal']
# [89, 12, 0, 0, 'Nonea obtusifolia', 'Normal']
# [89, 19, 0, 0, 'Nonea palmyrensis', 'Normal']
# [90, 3, 1, 0, 'Nonea caspica', 'Normal']
# [90, 21, 0, 0, 'Nonea ventricosa', 'Normal']
# [91, 19, 0, 0, 'Myosotis caespitosa', 'Normal']
# [92, 1, 0, 0, 'Myosotis sicula', 'Normal']
# [92, 6, 0, 0, 'Myosotis lithospermifolia', 'Normal']
# [92, 9, 0, 0, 'Myosotis ramosissima', 'Normal']
# [92, 17, 0, 0, 'Myosotis stricta', 'Normal']
# [93, 5, 0, 0, 'Myosotis refracta', 'Normal']
# [93, 15, 0, 0, 'Myosotis macrosiphon', 'Normal']
# [94, 18, 0, 0, 'Alkanna orientalis', 'Normal']
# [95, 10, 0, 0, 'Alkanna kotschyana', 'Normal']
# [95, 14, 0, 0, 'Alkanna confusa', 'Normal']
# [96, 1, 0, 0, 'Alkanna hirsutissima', 'Normal']
# [96, 10, 0, 0, 'Alkanna prasinophylla', 'Normal']
# [97, 5, 0, 0, 'Alkanna leiocarpa', 'Normal']
# [97, 8, 0, 0, 'Alkanna tinctoria', 'Normal']
# [97, 11, 0, 0, 'Alkanna maleolens', 'Normal']
# [98, 6, 0, 0, 'Alkanna strigosa', 'Normal']
# [99, 5, 0, 0, 'Symphytum anatolicum', 'Normal']
# [99, 8, 0, 0, 'Symphytum palaestinum', 'Normal']
# [99, 17, 0, 0, 'Borago officinalis', 'Normal']
# [100, 7, 0, 0, 'Cordia myxa', 'Normal']
# [100, 17, 0, 0, 'Verbena officinalis', 'Normal']
# [101, 5, 0, 0, 'Verbena supina', 'Normal']
# [102, 7, 0, 0, 'Vitex agnus', 'Normal']
# [103, 15, 0, 0, 'Ajuga orientalis', 'Normal']
# [103, 23, 0, 0, 'Ajuga laevigata', 'Normal']
# [104, 5, 0, 0, 'Ajuga chia', 'Normal']
# [104, 15, 0, 0, 'Ajuga tridactylites', 'Normal']
# [105, 18, 0, 0, 'Ajuga chasmophila', 'Normal']
# [106, 1, 0, 0, 'Ajuga rechingeri', 'Normal']
# [108, 4, 0, 0, 'Teucrium creticum', 'Normal']
# [108, 9, 0, 0, 'Teucrium multicaule', 'Normal']
# [108, 15, 0, 0, 'Teucrium pruinosum', 'Normal']
# [109, 6, 0, 0, 'Teucrium rigidum', 'Normal']
# [109, 10, 0, 0, 'Teucrium orientale', 'Normal']
# [109, 21, 0, 0, 'Teucrium procerum', 'Normal']
# [110, 5, 0, 0, 'Teucrium oliverianum', 'Normal']
# [110, 8, 0, 0, 'Teucrium parviflorum', 'Normal']
# [110, 15, 0, 0, 'Teucrium stachyophyllum', 'Normal']
# [111, 6, 0, 0, 'Teucrium scordium', 'Normal']
# [111, 8, 3, 0, 'Teucrium scordioides', 'Normal']
# [111, 16, 0, 0, 'Teucrium spinosum', 'Normal']
# [112, 8, 0, 0, 'Teucrium montbretii', 'Normal']
# [112, 22, 0, 0, 'Teucrium haradjianii', 'Normal']
# [113, 3, 0, 0, 'Teucrium heterotrichum', 'Normal']
# [113, 6, 0, 0, 'Teucrium chamaedrys', 'Normal']
# [114, 7, 0, 0, 'Teucrium divaricatum', 'Normal']
# [114, 20, 0, 0, 'Teucrium coniortodes', 'Normal']
# [115, 1, 0, 0, 'Teucrium socinianum', 'Normal']
# [115, 7, 0, 0, 'Teucrium polium', 'Normal']
# [116, 1, 0, 0, 'Teucriuflft antilibanoticum', 'Normal']
# [116, 7, 0, 0, 'Prasium majiis', 'Normal']
# [117, 15, 0, 0, 'Scutellaria orientalis', 'Normal']
# [117, 23, 0, 0, 'Scutellaria cretacea', 'Normal']
# [118, 1, 0, 0, 'Scutellaria tomentosa', 'Normal']
# [118, 8, 0, 0, 'Scutellaria diffusa', 'Normal']
# [118, 13, 0, 0, 'Scutellaria heterophylla', 'Normal']
# [118, 20, 0, 0, 'Scutellaria brevibracteata', 'Normal']
# [119, 18, 0, 0, 'Scutellaria utriculata', 'Normal']
# [120, 3, 0, 0, 'Lavandula stoechas', 'Normal']
# [121, 1, 0, 0, 'Marrubium hierapolitanum', 'Normal']
# [121, 5, 0, 0, 'Marrubium libanoticum', 'Normal']
# [121, 16, 0, 0, 'Marrubium cuneatum', 'Normal']
# [122, 5, 0, 0, 'Marrubium radiatum', 'Normal']
# [122, 12, 0, 0, 'Marrubium vulgare', 'Normal']
# [124, 6, 0, 0, 'Nepeta cataria', 'Normal']
# [124, 9, 0, 0, 'Nepeta leucostegia', 'Normal']
# [124, 17, 0, 0, 'Nepeta italica', 'Normal']
# [125, 11, 0, 0, 'Nepeta curviflora', 'Normal']
# [125, 18, 0, 0, 'Nepeta x', 'Normal']
# [126, 3, 0, 0, 'Nepeta cilicica', 'Normal']
# [126, 10, 0, 0, 'Nepeta glomerata', 'Normal']
# [126, 15, 0, 0, 'Nepeta pabotii', 'Normal']
# [127, 2, 0, 0, 'Nepeta nuda', 'Normal']
# [127, 10, 0, 0, 'Nepeta bithynica', 'Normal']
# [127, 15, 0, 0, 'Nepeta trachonitica', 'Normal']
# [128, 1, 0, 0, 'Nepeta calycina', 'Normal']
# [128, 7, 0, 0, 'Nepeta cryptantha', 'Normal']
# [129, 19, 0, 0, 'Sideritis curvidens', 'Normal']
# [129, 26, 0, 0, 'Sideritis montana', 'Normal']
# [130, 4, 0, 0, 'Sideritis remote', 'Normal']
# [130, 9, 0, 0, 'Sideritis balansae', 'Normal']
# [130, 13, 0, 0, 'Sideritis microchlamys', 'Normal']
# [131, 1, 0, 0, 'Sideritis libanotica', 'Normal']
# [131, 16, 0, 0, 'Sideritis nusairiensis', 'Normal']
# [131, 22, 0, 0, 'Sideritis perfoliata', 'Normal']
# [132, 7, 0, 0, 'Sideritis pullulans', 'Normal']
# [132, 20, 0, 0, 'Lallemantia royleana', 'Normal']
# [133, 5, 0, 0, 'Lallemantia iberica', 'Normal']
# [133, 14, 0, 0, 'Thuspeinanta persica', 'Normal']
# [134, 11, 0, 0, 'Prunella vulgaris', 'Normal']
# [134, 16, 0, 0, 'Prunella orientalis', 'Normal']
# [135, 1, 0, 0, 'Prunella laciniata', 'Normal']
# [135, 15, 0, 0, 'Eremostachys laciniata', 'Normal']
# [136, 1, 0, 0, 'Eremostachys macrophylla', 'Normal']
# [137, 14, 0, 0, 'Phlomis bruguieri', 'Normal']
# [137, 19, 0, 0, 'Phlomis cordata', 'Normal']
# [138, 1, 0, 0, 'Phlomis syriaca', 'Normal']
# [138, 9, 0, 0, 'Phlomis kurdica', 'Normal']
# [138, 17, 0, 0, 'Phlomis brachyodon', 'Normal']
# [139, 13, 0, 0, 'Phlomis brevilabris', 'Normal']
# [140, 1, 0, 0, 'Phlomis chrysophylla', 'Normal']
# [140, 8, 0, 0, 'Phlomis viscosa', 'Normal']
# [140, 15, 0, 0, 'Phlomis bailanica', 'Normal']
# [141, 5, 0, 0, 'Phlomis longifolia', 'Normal']
# [141, 12, 0, 0, 'Phlomis rigida', 'Normal']
# [141, 19, 0, 0, 'Phlomis pungens', 'Normal']
# [143, 6, 0, 0, 'Lamium striatum', 'Normal']
# [143, 18, 0, 0, 'Lamium reniforme', 'Normal']
# [143, 23, 0, 0, 'Lamium veronicifolium', 'Normal']
# [144, 5, 0, 0, 'Lamium amplexicaule', 'Normal']
# [144, 14, 0, 0, 'Lamium aleppicum', 'Normal']
# [144, 21, 0, 0, 'Lamium ehrenbergii', 'Normal']
# [145, 6, 0, 0, 'Lamium adoxifolium', 'Normal']
# [145, 9, 0, 0, 'Lamium macrodon', 'Normal']
# [145, 13, 0, 0, 'Lamium truncatum', 'Normal']
# [145, 21, 0, 0, 'Lamium moschatum', 'Normal']
# [146, 9, 0, 0, 'Lamium purpureum', 'Normal']
# [146, 18, 0, 0, 'Wiedemannia orientalis', 'Normal']
# [147, 7, 0, 0, 'Moluccella laevis', 'Normal']
# [147, 14, 0, 0, 'Moluccella spinosa', 'Normal']
# [148, 19, 0, 0, 'Ballota nigra', 'Normal']
# [148, 25, 0, 0, 'Ballota damascena', 'Normal']
# [149, 1, 0, 0, 'Ballota undulata', 'Normal']
# [149, 9, 0, 0, 'Ballota antilibanotica', 'Normal']
# [149, 18, 0, 0, 'Ballota saxatilis', 'Normal']
# [150, 7, 0, 0, 'Ballota semaanica', 'Normal']
# [152, 15, 0, 0, 'Stachys libanotica', 'Normal']
# [152, 26, 0, 0, 'Stachys ehrenbergii', 'Normal']
# [153, 3, 0, 0, 'Stachys eretica', 'Normal']
# [153, 20, 0, 0, 'Stachys pinetorum', 'Normal']
# [154, 3, 0, 0, 'Stachys dictyoneura', 'Normal']
# [154, 9, 0, 0, 'Stachys viticina', 'Normal']
# [154, 15, 0, 0, 'Stachys longispicata', 'Normal']
# [155, 5, 0, 0, 'Stachys hydrophila', 'Normal']
# [155, 10, 0, 0, 'Stachys iberica', 'Normal']
# [155, 14, 0, 0, 'Stachys distans', 'Normal']
# [156, 6, 0, 0, 'Stachys diversifolia', 'Normal']
# [156, 9, 0, 0, 'Stachys nivea', 'Normal']
# [156, 16, 0, 0, 'Stachys paneiana', 'Normal']
# [157, 9, 0, 0, 'Stachys palaestina', 'Normal']
# [157, 16, 0, 0, 'Stachys pumila', 'Normal']
# [157, 23, 0, 0, 'Stachys petrokosmos', 'Normal']
# [158, 6, 0, 0, 'Stachys rupestris', 'Normal']
# [158, 9, 0, 0, 'Stachys annua', 'Normal']
# [159, 1, 0, 0, 'Stachys arabica', 'Normal']
# [159, 8, 0, 0, 'Stachys obscura', 'Normal']
# [159, 15, 0, 0, 'Stachys arvensis', 'Normal']
# [159, 21, 0, 0, 'Stachys ocymastrum', 'Normal']
# [160, 1, 0, 0, 'Stachys satureioides', 'Normal']
# [160, 5, 0, 0, 'Stachys burgsdorffioides', 'Normal']
# [160, 8, 0, 0, 'Stachys neurocalycina', 'Normal']
# [160, 16, 0, 0, 'Rosmarinus officinalis', 'Normal']
# [164, 9, 0, 0, 'Salvia tomentosa', 'Normal']
# [164, 18, 0, 0, 'Salvia aramiensis', 'Normal']
# [165, 1, 0, 0, 'Salvia fruticosa', 'Normal']
# [165, 16, 0, 0, 'Salvia suffruticosa', 'Normal']
# [165, 19, 0, 0, 'Salvia spiraeifolia', 'Normal']
# [166, 5, 0, 0, 'Salvia pinnata', 'Normal']
# [166, 9, 0, 0, 'Salvia rubifolia', 'Normal']
# [166, 16, 0, 0, 'Salvia bracteata', 'Normal']
# [167, 4, 0, 0, 'Salvia multicaulis', 'Normal']
# [167, 13, 0, 0, 'Salvia pinardii', 'Normal']
# [168, 2, 0, 0, 'Salvia nazalena', 'Normal']
# [168, 4, 4, 0, 'Salvia syriaca', 'Normal']
# [168, 10, 1, 0, 'Salvia montbretii', 'Normal']
# [169, 2, 0, 0, 'Salvia spinosa', 'Normal']
# [169, 7, 0, 0, 'Salvia palaestina', 'Normal']
# [169, 12, 0, 0, 'Salvia samuelssonii', 'Normal']
# [170, 4, 0, 0, 'Salvia peyronii', 'Normal']
# [170, 14, 0, 0, 'Salvia dominica', 'Normal']
# [171, 4, 0, 0, 'Salvia sclarea', 'Normal']
# [171, 12, 0, 0, 'Salvia ceratophylla', 'Normal']
# [171, 18, 0, 0, 'Salvia drusica', 'Normal']
# [172, 3, 0, 0, 'Salvia microstegia', 'Normal']
# [172, 10, 0, 0, 'Salvia cassia', 'Normal']
# [173, 10, 0, 0, 'Salvia indica', 'Normal']
# [173, 17, 0, 0, 'Salvia hierosolymitana', 'Normal']
# [174, 4, 0, 0, 'Salvia virgata', 'Normal']
# [174, 8, 0, 0, 'Salvia viscosa', 'Normal']
# [174, 15, 0, 0, 'Salvia verbenaca', 'Normal']
# [175, 12, 0, 0, 'Salvia lanigera', 'Normal']
# [175, 17, 0, 0, 'Salvia viridis', 'Normal']
# [176, 20, 0, 0, 'Salvia judaica', 'Normal']
# [177, 6, 0, 0, 'Salvia russellii', 'Normal']
# [178, 1, 0, 0, 'Melissa officinalis', 'Normal']
# [178, 9, 0, 0, 'Melissa inodora', 'Normal']
# [179, 1, 0, 0, 'Satureia paUaryi', 'Normal']
# [179, 7, 0, 0, 'Satureia cuneifolia', 'Normal']
# [179, 12, 0, 0, 'Satureia thymbra', 'Normal']
# [181, 6, 0, 0, 'Micromeria Juliana', 'Normal']
# [181, 24, 0, 0, 'Micromeria amana', 'Normal']
# [182, 5, 0, 0, 'Micromeria graeca', 'Normal']
# [182, 19, 0, 0, 'Micromeria nummulariifolia', 'Normal']
# [183, 5, 0, 0, 'Micromeria libanotica', 'Normal']
# [183, 11, 0, 0, 'Micromeria shepardi', 'Normal']
# [183, 15, 0, 0, 'Micromeria serpyllifolia', 'Normal']
# [183, 18, 0, 0, 'Micromeria barbata', 'Normal']
# [184, 25, 0, 0, 'Calamintha betulifolia', 'Normal']
# [185, 4, 0, 0, 'Calamintha nepeta', 'Normal']
# [185, 9, 0, 0, 'Calamintha incana', 'Normal']
# [185, 16, 0, 0, 'Calamintha vulgaris', 'Normal']
# [186, 1, 0, 0, 'Calamintha origanifolia', 'Normal']
# [186, 8, 0, 0, 'Calamintha rotundifolia', 'Normal']
# [187, 12, 0, 0, 'Ziziphora canescens', 'Normal']
# [187, 18, 1, 0, 'Ziziphora capitata', 'Normal']
# [188, 6, 0, 0, 'Ziziphora tenuior', 'Normal']
# [188, 14, 0, 0, "Ziziphora 'Abd-el-Asisii Hand.-Mazz. (PL XC, n. 3). —Plante tenue par", 'Possible OCR Error']
# [189, 4, 0, 0, 'Ziziphora acutifolia', 'Normal']
# [189, 11, 0, 0, 'Ziziphora taurica', 'Normal']
# [190, 38, 0, 0, 'Origanum bargyli', 'Normal']
# [191, 7, 0, 0, 'Origanum x', 'Normal']
# [191, 11, 1, 0, 'Origanum libanoticum', 'Normal']
# [191, 16, 0, 0, 'Origanum libanoticum', 'Normal']
# [193, 3, 0, 0, 'Origanum x', 'Normal']
# [193, 12, 0, 0, 'Origanum ehrenbergii', 'Normal']
# [194, 3, 0, 0, 'Origanum ehrenbergii', 'Normal']
# [194, 8, 0, 0, 'Origanum syriacum', 'Normal']
# [195, 23, 0, 0, 'Thymus sipyleus', 'Normal']
# [195, 26, 0, 0, 'Thymus kotschyanus', 'Normal']
# [196, 1, 0, 0, 'Thymus hirsutus', 'Normal']
# [196, 6, 0, 0, 'Thymus decussatus', 'Normal']
# [196, 12, 0, 0, 'Thymus syriacus', 'Normal']
# [197, 1, 0, 0, 'Thymus cilicicus', 'Normal']
# [197, 5, 1, 0, 'Thymus alfredae', 'Normal']
# [197, 12, 0, 0, 'Coridothymus capitatus', 'Normal']
# [197, 19, 0, 0, 'Thymbra spicata', 'Normal']
# [198, 11, 0, 0, 'Lycopus europaeus', 'Normal']
# [199, 6, 0, 0, 'Mentha pulegium', 'Normal']
# [199, 13, 0, 0, 'Mentha aquatica', 'Normal']
# [199, 18, 0, 0, 'Mentha longifolia', 'Normal']
# [200, 5, 0, 0, 'Mentha microphylla', 'Normal']
# [201, 3, 0, 0, 'Nicandra physalodes', 'Normal']
# [201, 17, 0, 0, 'Atropa belladonna', 'Normal']
# [202, 4, 0, 0, 'Mandragora autumnalis', 'Normal']
# [203, 6, 0, 0, 'Lycium europaeum', 'Normal']
# [203, 9, 0, 0, 'Lycium barbarum', 'Normal']
# [203, 15, 0, 0, 'Lycium chinense', 'Normal']
# [204, 11, 0, 0, 'Solanum nigrum', 'Normal']
# [204, 18, 0, 0, 'Solanum luteum', 'Normal']
# [205, 1, 0, 0, 'Solanum luteum', 'Normal']
# [205, 4, 0, 0, 'Solanum dulcamara', 'Normal']
# [205, 13, 0, 0, 'Withania somnifera', 'Normal']
# [206, 1, 0, 0, 'Datura stramonium', 'Normal']
# [206, 8, 0, 0, 'Datura xnetel', 'Normal']
# [206, 15, 0, 0, 'Nicotiana glauca', 'Normal']
# [207, 20, 0, 0, 'Hyoscyamus muticus', 'Normal']
# [207, 23, 0, 0, 'Hyoscyamus desertorum', 'Normal']
# [208, 1, 0, 0, 'Hyoscyamus pusillus', 'Normal']
# [208, 5, 0, 0, 'Hyoscyamus niger', 'Normal']
# [208, 10, 0, 0, 'Hyoscyamus reticulatus', 'Normal']
# [209, 4, 0, 0, 'Hyoscyamus albus', 'Normal']
# [209, 12, 0, 0, 'Hyoscyamus aureus', 'Normal']
# [212, 24, 0, 0, 'Verbascum assurense', 'Normal']
# [213, 3, 0, 0, 'Verbascum glanduliferum', 'Normal']
# [213, 8, 0, 0, 'Verbascum agrimoniifolium', 'Normal']
# [214, 1, 0, 0, 'Verbascum antilibanoticum', 'Normal']
# [214, 9, 0, 0, 'Verbascum levanticum', 'Normal']
# [214, 15, 0, 0, 'Verbascum orientale', 'Normal']
# [215, 8, 0, 0, 'Verbascum blancheanum', 'Normal']
# [215, 15, 0, 0, 'Verbascum berytheum', 'Normal']
# [216, 4, 0, 0, 'Verbascum pinetorum', 'Normal']
# [216, 8, 0, 0, 'Verbascum tiberiadis', 'Normal']
# [216, 15, 0, 0, 'Verbascum scaposum', 'Normal']
# [217, 4, 0, 0, 'Verbascum porter', 'Normal']
# [217, 9, 0, 0, 'Verbascum alepense', 'Normal']
# [218, 1, 0, 0, 'Verbascum oreophilum', 'Normal']
# [218, 4, 0, 0, 'Verbascum infidelium', 'Normal']
# [218, 8, 0, 0, 'Verbascum eremobium', 'Normal']
# [219, 5, 0, 0, 'Verbascum cedreti', 'Normal']
# [219, 12, 0, 0, 'Verbascum damascemun', 'Normal']
# [220, 4, 0, 0, 'Verbascum tropidocarpum', 'Normal']
# [220, 7, 0, 0, 'Verbascum tripolitanum', 'Normal']
# [221, 1, 0, 0, 'Verbascum sinuatum', 'Normal']
# [221, 8, 0, 0, 'Verbascum gaillardotii', 'Normal']
# [222, 1, 0, 0, 'Verbascum palmyrense', 'Normal']
# [222, 6, 0, 0, 'Verbascum ptychophyllum', 'Normal']
# [222, 13, 0, 0, 'Verbascum caesareum', 'Normal']
# [223, 7, 0, 0, 'Verbascum antiochium', 'Normal']
# [223, 10, 0, 0, 'Verbascum galilaeum', 'Normal']
# [224, 1, 0, 0, 'Verbascum qulebicum', 'Normal']
# [224, 4, 0, 0, 'Verbascum antari', 'Normal']
# [224, 9, 0, 0, 'Verbascum libanoticum', 'Normal']
# [225, 4, 0, 0, 'Verbascum aliciae', 'Normal']
# [225, 11, 0, 0, 'Verbascum geminiflorum', 'Normal']
# [225, 16, 0, 0, 'Verbascum mucronatum', 'Normal']
# [226, 3, 0, 0, 'Verbascum glomeratum', 'Normal']
# [226, 8, 0, 0, 'Verbascum leptostachyum', 'Normal']
# [227, 5, 0, 0, 'Verbascum kotschyi', 'Normal']
# [227, 10, 0, 0, 'Verbascum lasianthum', 'Normal']
# [228, 1, 0, 0, 'Verbascum sinaiticum', 'Normal']
# [228, 10, 0, 0, 'Verbascum alepense', 'Normal']
# [228, 10, 2, 0, 'Verbascum aliciae', 'Normal']
# [228, 10, 4, 0, 'Verbascum cedreti', 'Normal']
# [228, 10, 6, 0, 'Verbascum gaillardotii', 'Normal']
# [228, 10, 8, 0, 'Verbascum gaillardotii', 'Normal']
# [228, 10, 10, 0, 'Verbascum galilaeum', 'Normal']
# [228, 10, 12, 0, 'Verbascum leptostachyum', 'Normal']
# [228, 10, 14, 0, 'Verbascum leptostachyum', 'Normal']
# [228, 10, 16, 0, 'Verbascum sinuatum', 'Normal']
# [229, 7, 0, 0, 'Antirrhinum orontium', 'Normal']
# [229, 15, 0, 0, 'Antirrhinum majus', 'Normal']
# [229, 25, 0, 0, 'Antirrhinum tortuosum', 'Normal']
# [230, 3, 0, 0, 'Anarrhinum orientale', 'Normal']
# [231, 6, 0, 0, 'Kickxia commutata', 'Normal']
# [231, 12, 0, 0, 'Kickxia elatine', 'Normal']
# [231, 20, 0, 0, 'Kickxia sieberi', 'Normal']
# [232, 7, 0, 0, 'Kickxia spuria', 'Normal']
# [232, 15, 0, 0, 'Kickxia lanigera', 'Normal']
# [233, 3, 1, 0, 'Kickxia aegyptiaca', 'Normal']
# [233, 6, 3, 0, 'Kickxia gombaultii', 'Normal']
# [235, 1, 0, 0, 'Linaria cymbalaria', 'Normal']
# [235, 8, 0, 0, 'Linaria longipes', 'Normal']
# [235, 11, 0, 0, 'Linaria aucheri', 'Normal']
# [235, 18, 0, 0, 'Linaria damascena', 'Normal']
# [236, 1, 0, 0, 'Linaria pelisseriana', 'Normal']
# [236, 7, 0, 0, 'Linaria arvensis', 'Normal']
# [236, 16, 0, 0, 'Linaria micrantba', 'Normal']
# [237, 5, 0, 0, 'Linaria genistifolia', 'Normal']
# [237, 9, 0, 0, 'Linaria antilibanotica', 'Normal']
# [237, 14, 0, 0, 'linariachalepensis (L.) Miller— AntirrhinumchalepenseL. (PI. CXXII, n. 7).—', 'Possible OCR Error']
# [238, 13, 0, 0, 'Linaria tenuis', 'Normal']
# [239, 1, 0, 0, 'Linaria albifrons', 'Normal']
# [239, 7, 0, 0, 'Linaria minor', 'Normal']
# [239, 10, 0, 0, 'Linaria persica', 'Normal']
# [240, 5, 0, 0, 'Mosheovia galilaea', 'Normal']
# [242, 7, 1, 0, 'Scrophularia peregrina', 'Normal']
# [242, 9, 4, 0, 'Scrophularia umbrosa', 'Normal']
# [242, 18, 0, 0, 'Scrophularia nusairiensis', 'Normal']
# [243, 4, 0, 0, 'Scrophularia scopolii', 'Normal']
# [243, 9, 0, 0, 'Scrophularia scariosa', 'Normal']
# [243, 14, 0, 0, 'Scrophularia hierochuntina', 'Normal']
# [244, 1, 0, 0, 'Scrophularia rubricaulis', 'Normal']
# [244, 8, 0, 0, 'Scrophularia tagetifolia', 'Normal']
# [244, 11, 0, 0, 'Scrophularia lucida', 'Normal']
# [245, 1, 0, 0, 'Scrophularia heldreichii', 'Normal']
# [245, 6, 0, 0, 'Scrophularia deserti', 'Normal']
# [245, 11, 0, 0, 'Scrophularia peyronii', 'Normal']
# [246, 1, 0, 0, 'Scrophularia xylorrhiza', 'Normal']
# [246, 6, 0, 0, 'Scrophularia libanotica', 'Normal']
# [247, 1, 0, 0, 'Scrophularia hypericifolia', 'Normal']
# [247, 8, 0, 0, 'Scrophularia xanthoglossa', 'Normal']
# [247, 15, 0, 0, 'Scrophularia decipiens', 'Normal']
# [251, 8, 0, 0, 'Veronica caespitosa', 'Normal']
# [252, 7, 0, 0, 'Veronica bombycina', 'Normal']
# [252, 17, 0, 0, 'Veronica polifolia', 'Normal']
# [253, 8, 0, 0, 'Veronica leiocarpa', 'Normal']
# [254, 5, 0, 0, 'Veronica macrostachya', 'Normal']
# [255, 1, 0, 0, 'Veronica orientalis', 'Normal']
# [257, 1, 0, 0, 'Veronica anagallis', 'Normal']
# [259, 12, 0, 0, 'Veronica anagalloides', 'Normal']
# [260, 12, 0, 0, 'Veronica beccabunga', 'Normal']
# [261, 2, 0, 0, 'Veronica arvensis', 'Normal']
# [261, 12, 0, 0, 'Veronica viscosa', 'Normal']
# [262, 1, 0, 0, 'Veronica pusilla', 'Normal']
# [262, 8, 0, 0, 'Veronica hispidula', 'Normal']
# [262, 15, 0, 0, 'Veronica reuterana', 'Normal']
# [263, 5, 0, 0, 'Veronica syriaca', 'Normal']
# [263, 12, 0, 0, 'Veronica debilis', 'Normal']
# [264, 4, 0, 0, 'Veronica triphyllos', 'Normal']
# [264, 10, 0, 0, 'Veronica samuelssonii', 'Normal']
# [265, 4, 0, 0, 'Veronica poliţa', 'Normal']
# [265, 15, 0, 0, 'Veronica persica', 'Normal']
# [266, 10, 0, 0, 'Veronica campylopoda', 'Normal']
# [267, 5, 0, 0, 'Veronica biloba', 'Normal']
# [267, 12, 0, 0, 'Veronica hederifolia', 'Normal']
# [268, 8, 0, 0, 'Veronica triloba', 'Normal']
# [269, 4, 0, 0, 'Veronica cymbalaria', 'Normal']
# [269, 15, 0, 0, 'Veronica panormitana', 'Normal']
# [271, 8, 0, 0, 'Digitalis ferruginea', 'Normal']
# [272, 1, 0, 0, 'Siphonostegia syriaca', 'Normal']
# [272, 6, 0, 0, 'Bungea trifida', 'Normal']
# [272, 14, 0, 0, 'Parentucellia latifolia', 'Normal']
# [273, 9, 0, 0, 'Parentucellia viscosa', 'Normal']
# [273, 16, 0, 0, 'Bellardia trixago', 'Normal']
# [274, 9, 0, 0, 'Odontites aucheri', 'Normal']
# [274, 14, 0, 0, 'Odontites lutea', 'Normal']
# [275, 2, 0, 0, 'Pedicularis comosa', 'Normal']
# [275, 10, 0, 0, 'Globularia trichosantha', 'Normal']
# [276, 6, 0, 0, 'Utricularia australia', 'Normal']
# [276, 14, 0, 0, 'Sesamum indicum', 'Normal']
# [277, 10, 0, 0, 'Acanthus mollis', 'Normal']
# [277, 14, 0, 0, 'Acanthus dioscoridis', 'Normal']
# [278, 3, 0, 0, 'Acanthus syriacus', 'Normal']
# [279, 10, 0, 0, 'Cistanche phelipaea', 'Normal']
# [279, 17, 0, 0, 'Cistanche tubulosa', 'Normal']
# [280, 6, 0, 0, 'Cistanche salsa', 'Normal']
# [281, 29, 0, 0, 'Orobanche ramosa', 'Normal']
# [282, 1, 0, 0, 'Orobanche mutelii', 'Normal']
# [282, 10, 0, 0, 'Orobanche nana', 'Normal']
# [282, 19, 0, 0, 'Orobanche lavandulacea', 'Normal']
# [283, 5, 0, 0, 'Orobanche aegyptiaca', 'Normal']
# [283, 14, 0, 0, 'Orobanche astragali', 'Normal']
# [284, 6, 0, 0, 'Orobanche libanotica', 'Normal']
# [284, 12, 0, 0, 'Orobanche schultzii', 'Normal']
# [285, 6, 0, 0, 'Orobanche serratocalyx', 'Normal']
# [285, 11, 0, 0, 'Orobanche hermonis', 'Normal']
# [286, 3, 0, 0, 'Orobanche major', 'Normal']
# [286, 9, 0, 0, 'Orobanche crenata', 'Normal']
# [286, 17, 1, 0, 'Orobanche pubescens', 'Normal']
# [287, 4, 2, 0, 'Orobanche minor', 'Normal']
# [287, 10, 2, 0, 'Orobanche grisebachii', 'Normal']
# [288, 8, 2, 0, 'Orobanche cernua', 'Normal']
# [288, 16, 1, 0, 'Orobanche camptolepis', 'Normal']
# [290, 10, 0, 0, 'Plantago major', 'Normal']
# [290, 17, 0, 0, 'Plantago lanceolate', 'Normal']
# [291, 18, 0, 0, 'Plantago lagopus', 'Normal']
# [291, 26, 0, 0, 'Plantago bellardii', 'Normal']
# [292, 7, 0, 0, 'Plantago eretica', 'Normal']
# [292, 14, 0, 0, 'Plantago ovata', 'Normal']
# [293, 1, 0, 0, 'Plantago loeflingii', 'Normal']
# [293, 7, 0, 0, 'Plantago notata', 'Normal']
# [294, 1, 0, 0, 'Plantago crassifolia', 'Normal']
# [294, 4, 0, 0, 'Plantago maritima', 'Normal']
# [294, 8, 0, 0, 'Plantago holosteum', 'Normal']
# [294, 16, 0, 0, 'Plantago albicans', 'Normal']
# [295, 5, 0, 0, 'Plantago cylindrica', 'Normal']
# [295, 10, 0, 0, 'Plantago coronopus', 'Normal']
# [296, 5, 0, 0, 'Plantago afra', 'Normal']
# [296, 14, 1, 0, 'Plantago squarrosa', 'Normal']
# [297, 14, 1, 0, 'Oldenlandia capensis', 'Normal']
# [298, 3, 0, 0, 'Putoria calabrica', 'Normal']
# [298, 22, 0, 0, 'Rubia aucheri', 'Normal']
# [299, 7, 0, 0, 'Rubia tinctorum', 'Normal']
# [299, 17, 0, 0, 'Rubia tenuifolia', 'Normal']
# [300, 11, 0, 0, 'Sherardia arvensis', 'Normal']
# [301, 10, 0, 0, 'Crucianella latifolia', 'Normal']
# [301, 17, 0, 0, 'Crucianella macrostachya', 'Normal']
# [302, 9, 0, 0, 'Crucianella imbricata', 'Normal']
# [302, 20, 0, 0, 'Crucianella exasperata', 'Normal']
# [303, 1, 0, 0, 'Crucianella herbacea', 'Normal']
# [303, 6, 0, 0, 'Crucianella membranacea', 'Normal']
# [303, 9, 0, 0, 'Crucianella ciliata', 'Normal']
# [304, 22, 0, 0, 'Asperula glomerata', 'Normal']
# [305, 5, 0, 0, 'Asperula arvensis', 'Normal']
# [305, 12, 0, 0, 'Asperula orientali', 'Normal']
# [305, 19, 0, 0, 'Asperula setosa', 'Normal']
# [306, 7, 0, 0, 'Asperula stricta', 'Normal']
# [306, 14, 0, 0, 'Asperula glareosa', 'Normal']
# [306, 19, 0, 0, 'Asperula libanotica', 'Normal']
# [307, 4, 0, 0, 'Asperula bargyli', 'Normal']
# [307, 11, 0, 0, 'Asperula breviflora', 'Normal']
# [307, 16, 0, 0, 'Asperula rivalis', 'Normal']
# [310, 1, 0, 0, 'Galium humifusum', 'Normal']
# [310, 7, 0, 0, 'Galium pestalozzae', 'Normal']
# [311, 1, 0, 0, 'Galium ', 'Possible OCR Error']
# [311, 18, 0, 0, 'Galium prusense', 'Normal']
# [312, 7, 0, 0, 'Galiuxn libanoticum', 'Normal']
# [312, 15, 0, 0, "'Galium bassitense Thiéb. (PI. CLVI, n. 1). — 2J.. Plante dressée ou ascen-", 'Possible OCR Error']
# [312, 18, 0, 0, 'Galium verum', 'Normal']
# [313, 12, 0, 0, 'Galium canum', 'Normal']
# [314, 2, 0, 0, 'Galium thiebautii', 'Normal']
# [314, 9, 0, 0, 'Galium thiebautii', 'Normal']
# [314, 13, 0, 0, 'Galium jungermannioides', 'Normal']
# [315, 1, 0, 0, 'Galiutn verrucosmn', 'Normal']
# [315, 7, 0, 0, 'Galium tricornutum', 'Normal']
# [315, 16, 0, 0, 'Galium aparine', 'Normal']
# [315, 23, 0, 0, 'Galium spurium', 'Normal']
# [316, 8, 0, 0, 'Galium samuelssonii', 'Normal']
# [316, 15, 0, 0, 'Galium pisiferum', 'Normal']
# [316, 20, 2, 0, 'Galium peplidifolium', 'Normal']
# [317, 5, 0, 0, 'Galium parisiense', 'Normal']
# [317, 10, 0, 0, 'Galium divaricatum', 'Normal']
# [317, 16, 0, 0, 'Galium tenuissimum', 'Normal']
# [318, 4, 0, 0, 'Galium nigricans', 'Normal']
# [318, 13, 0, 0, 'Galium chaetopodum', 'Normal']
# [318, 20, 0, 0, 'Galium hierosolymitanum', 'Normal']
# [319, 6, 0, 0, 'Galium cassium', 'Normal']
# [319, 15, 0, 0, 'Galium setaceum', 'Normal']
# [320, 4, 0, 0, 'Galium judaicum', 'Normal']
# [320, 11, 0, 0, 'Galium bracteatum', 'Normal']
# [320, 16, 0, 0, 'Galium murale', 'Normal']
# [321, 1, 0, 0, 'Galium verticillatam', 'Normal']
# [321, 16, 0, 0, 'Cruciata coronata', 'Normal']
# [322, 12, 0, 0, 'Cruciata pedemontana', 'Normal']
# [322, 18, 0, 0, 'Cruciata articulata', 'Normal']
# [323, 9, 0, 0, 'Valantia muralis', 'Normal']
# [323, 15, 0, 0, 'Valantia hispida', 'Normal']
# [323, 25, 0, 0, 'Mericarpaea vaillantioides', 'Normal']
# [324, 12, 0, 0, 'Callipeltis factorovskyi', 'Normal']
# [324, 17, 0, 0, 'Callipeltis cucullaris', 'Normal']
# [325, 16, 0, 0, 'Sambucus ebulus', 'Normal']
# [326, 3, 0, 0, 'Sambucus nigra', 'Normal']
# [326, 10, 0, 0, 'Viburnum tinus', 'Normal']
# [326, 22, 0, 0, 'Lonicera etrusca', 'Normal']
# [327, 8, 0, 0, 'Lonicera nummulariifolia', 'Normal']
# [327, 14, 1, 0, 'Lonicera orientalis', 'Normal']
# [328, 6, 0, 0, 'Valeriana dioscoridis', 'Normal']
# [328, 15, 0, 0, 'Centranthus longiflorus', 'Normal']
# [330, 30, 0, 0, 'Valerianella tuberculata', 'Normal']
# [330, 37, 0, 0, 'Valerianella dactylophylla', 'Normal']
# [331, 7, 0, 0, 'Valerianella oxyrhyncha', 'Normal']
# [331, 12, 0, 0, 'Valerianella cymbicarpa', 'Normal']
# [331, 15, 0, 0, 'Valerianella szovitsiana', 'Normal']
# [332, 5, 0, 0, 'Valerianella huetii', 'Normal']
# [332, 10, 0, 0, 'Valerianella echinata', 'Normal']
# [333, 1, 0, 0, 'Valerianella soyeri', 'Normal']
# [333, 6, 0, 0, 'Valerianella orientalis', 'Normal']
# [333, 13, 0, 0, 'Valerianella locusta', 'Normal']
# [334, 3, 0, 0, 'Valerianella dentata', 'Normal']
# [334, 7, 0, 0, 'Valerianella muricata', 'Normal']
# [334, 15, 0, 0, 'Valerianella carinata', 'Normal']
# [335, 1, 0, 0, '.Valerianella lasiocarpa (Stev.) Betcke. — Fedia lasiocarpa Stev. (PL', 'Possible OCR Error']
# [335, 4, 0, 0, 'Valerianella pumila', 'Normal']
# [335, 10, 0, 0, 'Valerianella dufresnia', 'Normal']
# [336, 1, 0, 0, 'Valerianella antilibanotica', 'Normal']
# [336, 7, 0, 0, 'Valerianella chlorostephana', 'Normal']
# [336, 11, 0, 0, 'Valerianella kotschyi', 'Normal']
# [337, 1, 0, 0, 'Valerianella coronata', 'Normal']
# [337, 9, 0, 0, 'Valerianella discoidea', 'Normal']
# [337, 13, 1, 0, 'Valerianella obtusiloba', 'Normal']
# [338, 1, 0, 0, 'Valerianella vesicaria', 'Normal']
# [338, 15, 0, 0, 'Morina persica', 'Normal']
# [339, 12, 0, 0, 'Dipsacus sativus', 'Normal']
# [339, 15, 0, 0, 'Dipsacus fullonum', 'Normal']
# [340, 10, 0, 0, 'Dipsacus laciniatus', 'Normal']
# [341, 15, 0, 0, 'Cephalaria setosa', 'Normal']
# [342, 1, 0, 0, 'Cephalaria joppensis', 'Normal']
# [342, 8, 0, 0, 'Cephalaria syriaca', 'Normal']
# [343, 8, 0, 0, 'Cephalaria stellipilis', 'Normal']
# [343, 15, 0, 0, 'Cephalaria dîpsacoides', 'Normal']
# [344, 1, 0, 0, 'Cephalaria kesruanica', 'Normal']
# [344, 7, 0, 0, 'Cephalaria.amana Rech. f. (PL CLXXVI). — Plante ainsi décrite: «Rhi-', 'Possible OCR Error']
# [345, 7, 0, 0, 'Cephalaria cedrorum', 'Normal']
# [346, 1, 0, 0, 'Knautia integrifolia', 'Normal']
# [346, 4, 0, 0, 'Knautia bidens', 'Normal']
# [346, 15, 0, 0, 'Pterocephalus plumosus', 'Normal']
# [347, 7, 0, 0, 'Pterocephalus brevis', 'Normal']
# [347, 15, 0, 0, 'Pterocephalus pulverulentus', 'Normal']
# [349, 1, 0, 0, 'Scabiosa webbiana', 'Normal']
# [349, 6, 0, 0, 'Scabiosa intermedia', 'Normal']
# [349, 9, 0, 0, 'Scabiosa argentea', 'Normal']
# [350, 6, 0, 0, 'Scabiosa olivier', 'Normal']
# [350, 11, 0, 0, 'Scabiosa micrantha', 'Normal']
# [350, 15, 0, 0, 'Scabiosa sicula', 'Normal']
# [351, 4, 0, 0, 'Scabiosa prolifera', 'Normal']
# [351, 11, 0, 0, 'Scabiosa palaestina', 'Normal']
# [352, 21, 0, 0, 'Scabiosa aucheri', 'Normal']
# [353, 6, 0, 0, 'Cucumis phrophetarum', 'Normal']
# [354, 2, 0, 0, 'Citrullus colocynthis', 'Normal']
# [354, 12, 0, 0, 'Ecballium elaterium', 'Normal']
# [355, 1, 0, 0, 'Bryonia multiflora', 'Normal']
# [355, 8, 0, 0, 'Bryonia syriaca', 'Normal']
# [355, 14, 0, 0, 'Bryonia lasiocarpa', 'Normal']
# [355, 17, 0, 0, 'Note de', 'Normal']
# [356, 8, 0, 0, 'Laurentia minuta', 'Normal']
# [356, 13, 0, 0, 'Laurentia gasparrinii', 'Normal']
# [358, 25, 0, 0, 'Campanula euclasta', 'Normal']
# [359, 1, 0, 0, 'Campanula damascena', 'Normal']
# [359, 8, 0, 0, 'Campanula trichopoda', 'Normal']
# [359, 12, 2, 0, 'Campanula cymbalaria', 'Normal']
# [360, 1, 0, 0, 'Campanula trachelium', 'Normal']
# [360, 9, 0, 0, 'Campanula stricta', 'Normal']
# [360, 16, 0, 0, 'Campanula stellaris', 'Normal']
# [361, 4, 0, 0, 'Campanula, strigosa Banks et Sol. — C. russeliana Roemer et Schultes. (PI.', 'Possible OCR Error']
# [361, 11, 0, 0, 'Campanula propinqua', 'Normal']
# [362, 1, 0, 0, 'Campanula cecilii', 'Normal']
# [362, 8, 0, 0, 'Campanula reuteriana', 'Normal']
# [362, 12, 0, 0, 'Campanula hierosolymitana', 'Normal']
# [363, 1, 0, 0, 'Campanula sulphurea', 'Normal']
# [363, 9, 0, 0, 'Campanula camptoclada', 'Normal']
# [363, 14, 0, 0, 'Campanula erinus', 'Normal']
# [363, 21, 0, 0, 'Campanula peregrina', 'Normal']
# [364, 5, 0, 0, 'Campanula rapunculus', 'Normal']
# [364, 16, 0, 0, 'Campanula phrygia', 'Normal']
# [365, 4, 0, 0, 'Campanula kotschyana', 'Normal']
# [365, 9, 0, 0, 'Campanula flaccidula', 'Normal']
# [365, 13, 0, 0, 'Campanula retrorşa', 'Normal']
# [366, 4, 0, 0, 'Campanula sidoniensis', 'Normal']
# [366, 10, 0, 0, 'Campanula fastigiata', 'Normal']
# [367, 1, 0, 0, 'Michauxia campanuloides', 'Normal']
# [367, 9, 0, 0, 'Michauxia nuda', 'Normal']
# [368, 1, 0, 0, 'Asyneuma virgatum', 'Normal']
# [368, 7, 0, 0, 'Asyneuma rigidum', 'Normal']
# [369, 4, 0, 0, 'Legousia falcata', 'Normal']
# [369, 11, 0, 0, 'Legousia speculum', 'Normal']
# [369, 18, 0, 0, 'Legousia pentagonia', 'Normal']
# [370, 19, 0, 0, 'Tracheliopsis tubulosa', 'Normal']
# [371, 4, 0, 0, 'Tracheliopsis antilibanotica', 'Normal']
# [371, 9, 0, 0, 'Tracheliopsis postii', 'Normal']
# [372, 7, 0, 0, 'Eupatorium cannabinum', 'Normal']
# [372, 8, 3, 0, 'en corymbes formés de capitules brièvement pédoncules mesurant 4-6 mm de long.', 'Possible OCR Error']
# [372, 17, 0, 0, 'Eupatorium adenophorum', 'Normal']
# [373, 7, 0, 0, 'Solidago virgaurea', 'Normal']
# [373, 23, 0, 0, 'Erigeron libanoticus', 'Normal']
# [374, 4, 0, 0, 'Erigeron canadense', 'Normal']
# [374, 11, 0, 0, 'Erigeron bonariensis', 'Normal']
# [374, 17, 0, 0, 'Erigeron naudinii', 'Normal']
# [375, 5, 0, 0, 'Psychrogeton nigromontanus', 'Normal']
# [375, 10, 0, 0, 'Pluchea dioscoridis', 'Normal']
# [376, 6, 0, 0, 'Bellis a', 'Normal']
# [376, 13, 0, 0, 'Bellis perennis', 'Normal']
# [376, 20, 0, 0, 'Bellis sylvestris', 'Normal']
# [377, 12, 0, 0, 'Asteriscus aquaticus', 'Normal']
# [377, 19, 0, 0, 'Asteriscus pygmaeus', 'Normal']
# [377, 23, 0, 0, 'Asteriscus graveolens', 'Normal']
# [378, 5, 0, 0, 'Pallenis spinosa', 'Normal']
# [379, 1, 0, 0, 'Postia lanuginosa', 'Normal']
# [379, 6, 0, 0, 'Postia tnicrocephala', 'Normal']
# [380, 4, 0, 0, 'Inula salicina', 'Normal']
# [380, 9, 0, 0, 'Inula vulgaris', 'Normal']
# [380, 11, 4, 0, 'Inula crithmoides', 'Normal']
# [380, 14, 0, 0, 'Inula heterolepis', 'Normal']
# [381, 2, 0, 0, 'Inula viscosa', 'Normal']
# [381, 11, 0, 0, 'Inula graveolens', 'Normal']
# [381, 20, 0, 0, 'Pentanema divaricata', 'Normal']
# [382, 18, 0, 0, 'Pulicaria dysenterica', 'Normal']
# [383, 8, 0, 0, 'Pulicaria inuloides', 'Normal']
# [383, 10, 3, 0, 'Pulicaria auranitica', 'Normal']
# [383, 17, 0, 0, 'Pulicaria arabica', 'Normal']
# [384, 8, 0, 0, 'Pulicaria laniceps', 'Normal']
# [384, 14, 0, 0, 'Francœuria undulata', 'Normal']
# [385, 3, 0, 0, 'Varthemia iphionoides', 'Normal']
# [385, 14, 0, 0, 'Phagnalon rupestre', 'Normal']
# [386, 1, 0, 0, 'Phagnalon kotschyi', 'Normal']
# [386, 6, 0, 0, 'Phagnalon linifolium', 'Normal']
# [386, 11, 0, 0, 'Lasiopogon muscoides', 'Normal']
# [387, 4, 0, 0, 'Gnaphalium luteo', 'Normal']
# [387, 11, 0, 0, 'Gnaphalium uliginosum', 'Normal']
# [388, 19, 0, 0, 'Helichrysum conglobatum', 'Normal']
# [389, 7, 0, 0, 'Helichrysum arenarium', 'Normal']
# [389, 10, 0, 0, 'Helichrysum armenium', 'Normal']
# [389, 17, 0, 0, 'Helichrysum pallasii', 'Normal']
# [390, 6, 0, 0, 'Helichrysum pygmaeum', 'Normal']
# [390, 11, 0, 0, 'Helichrysum plicatum', 'Normal']
# [391, 10, 0, 0, 'Helichrysum virgineum', 'Normal']
# [391, 18, 0, 0, 'Helichrysum sanguineum', 'Normal']
# [392, 14, 0, 0, 'Leysera leyseroides', 'Normal']
# [393, 2, 0, 0, 'Gymnarrhena micrantha', 'Normal']
# [393, 10, 0, 0, 'Micropus supinus', 'Normal']
# [394, 4, 0, 0, 'Bombycilaena discolor', 'Normal']
# [394, 8, 0, 0, 'Bombycilaena erecta', 'Normal']
# [394, 14, 0, 0, 'Cymbolaena griffîthii', 'Normal']
# [396, 5, 0, 0, 'Filago eriocephala', 'Normal']
# [396, 12, 0, 0, 'Filago pyramidata', 'Normal']
# [397, 1, 0, 0, 'Filago desertorum', 'Normal']
# [397, 7, 0, 0, 'Filago arvensis', 'Normal']
# [397, 16, 0, 0, 'Filago gallica', 'Normal']
# [398, 6, 0, 0, 'Filago anatolica', 'Normal']
# [398, 13, 0, 0, 'Filago palaestina', 'Normal']
# [398, 18, 0, 0, 'Filago eriosphaera', 'Normal']
# [399, 2, 0, 0, 'Filago contracta', 'Normal']
# [399, 7, 0, 0, 'Filago pygmaea', 'Normal']
# [399, 16, 0, 0, 'Ifloga spicata', 'Normal']
# [400, 5, 0, 0, 'Eclipta prostrata', 'Normal']
# [400, 12, 0, 0, 'Guizotia abyssinica', 'Normal']
# [401, 1, 0, 0, 'Bidens tripartita', 'Normal']
# [401, 4, 0, 0, 'Bidens pilosa', 'Normal']
# [401, 10, 0, 0, 'Bidens frondosa', 'Normal']
# [401, 19, 0, 0, 'Tagetes minuta', 'Normal']
# [402, 9, 0, 0, 'Ambrosia maritima', 'Normal']
# [402, 25, 0, 0, 'Xanthium spinosum', 'Normal']
# [403, 2, 0, 0, 'Xanthium echinatum', 'Normal']
# [403, 11, 0, 0, 'Xanthium strumarium', 'Normal']
# [403, 22, 0, 0, 'Otanthus maritimus', 'Normal']
# [404, 26, 0, 0, 'Achillea membranacea', 'Normal']
# [405, 5, 0, 0, 'Achillea oligocephala', 'Normal']
# [405, 10, 0, 0, 'Achillea fragrantissima', 'Normal']
# [405, 17, 0, 0, 'Achillea wilhelmsii', 'Normal']
# [406, 8, 0, 0, 'Achillea falcata', 'Normal']
# [406, 15, 0, 0, 'Achillea conferta', 'Normal']
# [407, 1, 0, 0, 'Achillea aleppica', 'Normal']
# [407, 8, 0, 0, 'Achillea kotschyi', 'Normal']
# [407, 13, 0, 0, 'Achillea biebersteinii', 'Normal']
# [409, 38, 0, 0, 'Anthémis aaronsohnii', 'Normal']
# [410, 6, 0, 0, 'Anthémis tinctoria', 'Normal']
# [411, 5, 0, 0, 'Anthémis altissima', 'Normal']
# [411, 13, 0, 0, 'Anthémis melanolepis', 'Normal']
# [411, 20, 0, 0, 'Anthémis palestina', 'Normal']
# [412, 11, 0, 0, 'Anthémis austriaca', 'Normal']
# [412, 14, 0, 0, 'Anthémis halophila', 'Normal']
# [413, 1, 3, 0, 'Anthémis samuelssonii', 'Normal']
# [413, 6, 0, 0, 'Anthémis eretica', 'Normal']
# [414, 1, 0, 0, 'Anthémis pauciloba', 'Normal']
# [414, 12, 0, 0, 'Anthémis leucanthemifolia', 'Normal']
# [415, 1, 0, 0, 'Anthémis didymaea', 'Normal']
# [415, 7, 0, 0, 'Anthémis breviradiata', 'Normal']
# [415, 12, 0, 0, 'Anthémis wettsteiniana', 'Normal']
# [416, 5, 0, 0, 'Anthémis hyalina', 'Normal']
# [416, 13, 0, 0, 'Anthémis haussknechtii', 'Normal']
# [417, 6, 0, 0, 'Anthémis chia', 'Normal']
# [417, 11, 0, 0, 'Anthémis cornucopiae', 'Normal']
# [418, 1, 0, 0, 'Anthémis hebronica', 'Normal']
# [418, 4, 0, 0, 'Anthémis secundiramea', 'Normal']
# [418, 11, 0, 0, 'Anthémis rascheyana', 'Normal']
# [419, 1, 0, 0, 'Anthémis scariosa', 'Normal']
# [419, 6, 0, 0, 'Anthémis cotula', 'Normal']
# [419, 14, 0, 0, 'Anthémis pseudocotula', 'Normal']
# [420, 9, 0, 0, 'Anthémis tripolitana', 'Normal']
# [420, 15, 0, 0, 'Anthémis lyonnetioides', 'Normal']
# [421, 15, 0, 0, 'Chamaemelum mixtum', 'Normal']
# [422, 6, 0, 0, 'Anacyclus radiatus', 'Normal']
# [422, 10, 0, 0, 'Anacyclus clavatus', 'Normal']
# [422, 13, 0, 0, 'Anacyclus nigellifolius', 'Normal']
# [423, 10, 0, 0, 'Matricaria chamomilla', 'Normal']
# [423, 19, 0, 0, 'Matricaria aurea', 'Normal']
# [424, 21, 0, 0, 'Tripleurospermum parviflorum', 'Normal']
# [424, 26, 0, 0, 'Tripleurospermum auriculatum', 'Normal']
# [425, 5, 0, 0, 'Tripleurospermum sannineum', 'Normal']
# [425, 10, 0, 0, 'Tripleurospermum microcephalum', 'Normal']
# [425, 13, 0, 0, 'Tripleurospermum oreades', 'Normal']
# [426, 14, 0, 0, 'Chrysanthemum myconis', 'Normal']
# [427, 7, 0, 0, 'Chrysanthemum segetum', 'Normal']
# [427, 15, 0, 0, 'Chrysanthemum coronarium', 'Normal']
# [428, 14, 0, 0, 'Tanacetum parthenium', 'Normal']
# [428, 17, 0, 0, 'Tanacetum poteriifolium', 'Normal']
# [428, 20, 0, 0, 'Tanacetum cilicium', 'Normal']
# [429, 7, 0, 0, 'Tanacetum densum', 'Normal']
# [429, 13, 0, 0, 'Tanacetum yabrudae', 'Normal']
# [430, 1, 0, 0, 'Tanacetum aucheri', 'Normal']
# [430, 6, 0, 0, 'Tanacetum argenteum', 'Normal']
# [431, 6, 0, 0, 'Artemisia monosperma', 'Normal']
# [431, 12, 0, 0, 'Artemisia scoparia', 'Normal']
# [431, 20, 0, 0, 'Artemisia annua', 'Normal']
# [432, 3, 0, 0, 'Artemisiaherba-alba Asso (PI.CCXXXVIII, n.2). —2J..Plante frutescente,', 'Possible OCR Error']
# [432, 13, 0, 0, 'Artemisia verlotorum', 'Normal']
# [432, 21, 0, 0, 'Artemisia arborescens', 'Normal']
# [433, 6, 0, 0, 'Tussilago farfara', 'Normal']
# [433, 16, 0, 0, 'Doronicum orientale', 'Normal']
# [434, 31, 0, 0, 'Senecio vulgaris', 'Normal']
# [435, 6, 0, 0, 'Senecio leucanthemifolius', 'Normal']
# [435, 11, 0, 0, 'Senecio vernalis', 'Normal']
# [436, 1, 0, 0, 'Senecio exilis', 'Normal']
# [436, 6, 0, 0, 'Senecio gallicus', 'Normal']
# [436, 12, 0, 0, 'Senecio aquaticus', 'Normal']
# [437, 1, 0, 0, 'Senecio mouterdei', 'Normal']
# [437, 6, 0, 0, 'Senecio delbesianus', 'Normal']
# [437, 11, 0, 0, 'Senecio bertrami', 'Normal']
# [438, 5, 0, 0, 'Senecio doriiformis', 'Normal']
# [439, 15, 0, 0, 'Calendula officinalis', 'Normal']
# [439, 18, 0, 0, 'Calendula sinuata', 'Normal']
# [440, 2, 0, 0, 'Calendula bicolor', 'Normal']
# [440, 5, 0, 0, 'Calendula arvensis', 'Normal']
# [440, 12, 0, 0, 'Calendula aegyptiaca', 'Normal']
# [441, 9, 0, 0, 'Calendula palaestina', 'Normal']
# [441, 12, 0, 0, 'Calendula tripterocarpa', 'Normal']
# [441, 22, 0, 0, 'Dipterocome pusilla', 'Normal']
# [442, 7, 0, 0, 'Gundelia tournefortii', 'Normal']
# [443, 11, 0, 0, 'Echinops viscosus', 'Normal']
# [443, 21, 0, 0, 'Echinops gaillardotii', 'Normal']
# [444, 5, 0, 0, 'Echinops polyceras', 'Normal']
# [444, 10, 0, 0, 'Echinops descendent', 'Normal']
# [445, 7, 0, 0, 'Acantholepis orientalis', 'Normal']
# [445, 14, 0, 0, 'Cardopatium corymbosum', 'Normal']
# [446, 14, 0, 0, 'Xeranthemum annuum', 'Normal']
# [446, 17, 0, 0, 'Xeranthemum inapertum', 'Normal']
# [447, 3, 0, 0, 'Xeranthemum longipapposum', 'Normal']
# [447, 6, 0, 0, 'Xeranthemum cylindraceum', 'Normal']
# [448, 2, 0, 0, 'Chardinia orientalis', 'Normal']
# [448, 12, 0, 0, 'Siebera pungens', 'Normal']
# [449, 14, 0, 0, 'Carlina curetum', 'Normal']
# [450, 1, 0, 0, 'Carlina involucrata', 'Normal']
# [450, 6, 0, 0, 'Garlina oligocephala', 'Normal']
# [450, 10, 0, 0, 'Carlina hispanica', 'Normal']
# [450, 13, 0, 0, 'Carlina kurdica', 'Normal']
# [451, 3, 0, 0, 'Carlina lanata', 'Normal']
# [451, 15, 0, 0, 'Atractylis carduus', 'Normal']
# [452, 2, 0, 0, 'Atractylis cancellata', 'Normal']
# [452, 10, 0, 0, 'Atractylis comosa', 'Normal']
# [452, 17, 0, 0, 'Staehelina lobelii', 'Normal']
# [453, 11, 0, 0, 'Arctium minus', 'Normal']
# [454, 20, 0, 0, 'Cousinia pestalozzae', 'Normal']
# [455, 4, 0, 0, 'Gousinia ramosissima', 'Normal']
# [455, 12, 0, 0, 'Cousinia stenocephala', 'Normal']
# [455, 17, 0, 0, 'Cousinia postiana', 'Normal']
# [456, 7, 0, 0, 'Gousinia aleppica', 'Normal']
# [456, 12, 0, 0, 'Cousinia libanotica', 'Normal']
# [456, 17, 0, 0, 'Cousinia hermonis', 'Normal']
# [457, 7, 0, 0, 'Cousinia wesheni', 'Normal']
# [457, 12, 0, 0, 'Cousinia aintabensis', 'Normal']
# [458, 11, 0, 0, 'Carduus nutans', 'Normal']
# [458, 17, 0, 0, 'Garduus acicularis', 'Normal']
# [458, 21, 0, 0, 'Garduus pycnocephalus', 'Normal']
# [459, 10, 0, 0, 'Carduus argentatus', 'Normal']
# [460, 15, 0, 0, 'Cirsium lappaceum', 'Normal']
# [460, 24, 0, 0, 'Cirsium phyllocephalum', 'Normal']
# [461, 5, 0, 0, 'Cirsium amani', 'Normal']
# [461, 8, 0, 0, 'Cirsium vulgare', 'Normal']
# [462, 1, 0, 0, 'Cirsium creticum', 'Normal']
# [462, 6, 0, 0, 'Cirsium siculum', 'Normal']
# [462, 9, 0, 0, 'Cirsium libanoticum', 'Normal']
# [463, 6, 0, 0, 'Picnomon acarna', 'Normal']
# [463, 16, 0, 0, 'Notobasis syriaca', 'Normal']
# [464, 10, 0, 0, 'Ptilostemon chamaepeuce', 'Normal']
# [464, 15, 0, 0, 'Ptilostemon diacantha', 'Normal']
# [465, 10, 0, 0, 'Ptilostemon x', 'Normal']
# [465, 15, 0, 0, 'Tyrimnus leucographus', 'Normal']
# [466, 2, 0, 0, 'Silybum marianum', 'Normal']
# [466, 12, 0, 0, 'Cynara syriaca', 'Normal']
# [467, 17, 0, 0, 'Onopordum carduiforme', 'Normal']
# [468, 5, 0, 0, 'Onopordum cynarocephalum', 'Normal']
# [468, 13, 0, 0, 'Onopordum heteracanthum', 'Normal']
# [469, 1, 0, 0, 'Onopordum illyricum', 'Normal']
# [469, 6, 0, 0, 'Onopordum macrocephalum', 'Normal']
# [469, 11, 0, 0, 'Onopordum syriacum', 'Normal']
# [470, 4, 0, 0, 'Onopordum tauricum', 'Normal']
# [470, 13, 0, 0, 'Myopordon thiebauti', 'Normal']
# [470, 18, 0, 0, 'Myopordon pulchellum', 'Normal']
# [471, 9, 0, 0, 'Jurinea staehelinae', 'Normal']
# [471, 14, 0, 0, 'Jurinea mesopotamica', 'Normal']
# [472, 9, 0, 0, 'Zoegea leptaurea', 'Normal']
# [472, 16, 0, 0, 'Zoegea purpurea', 'Normal']
# [473, 5, 0, 0, 'Crupina crupinastrum', 'Normal']
# [474, 7, 0, 0, 'Serratula cerinthifolia', 'Normal']
# [474, 14, 0, 0, 'Serratula mouterdei', 'Normal']
# [475, 3, 0, 0, 'Serratula pusilla', 'Normal']
# [479, 2, 0, 0, 'Centaurea balsamita', 'Normal']
# [479, 5, 0, 0, 'Centaurea balsamitoides', 'Normal']
# [480, 6, 0, 0, 'Centaurea reducta', 'Normal']
# [480, 9, 0, 0, 'Centaurea dumulosa', 'Normal']
# [480, 16, 0, 0, 'Centaurea damascena', 'Normal']
# [481, 7, 0, 0, 'Centaurea ', 'Possible OCR Error']
# [481, 7, 1, 0, 'virgata Lam. (PI. ', 'Possible OCR Error']
# [481, 19, 0, 0, 'Centaurea ammocyanus', 'Normal']
# [482, 6, 0, 0, 'Centaurea laxa', 'Normal']
# [482, 10, 0, 0, 'Centaurea blancheana', 'Normal']
# [483, 4, 0, 0, 'Centaurea cassia', 'Normal']
# [483, 9, 0, 0, 'Centaurea drabifolia', 'Normal']
# [483, 16, 0, 0, 'Centaurea longispina', 'Normal']
# [484, 3, 0, 0, 'Centaurea delbesiana', 'Normal']
# [484, 8, 0, 0, 'Centaurea cheirolopha', 'Normal']
# [485, 1, 0, 0, 'Centaurea hololeuca', 'Normal']
# [485, 6, 0, 0, 'Centaurea speciosa', 'Normal']
# [485, 14, 0, 0, 'Centaurea postii', 'Normal']
# [486, 10, 0, 0, 'Centaurea handelii', 'Normal']
# [486, 18, 0, 0, 'Centaurea regia', 'Normal']
# [487, 3, 0, 0, 'Centaurea ', 'Possible OCR Error']
# [487, 3, 1, 0, 'onopordifolia Boiss. (PI. CCXCV, n.', 'Possible OCR Error']
# [487, 8, 0, 0, 'Centaurea arifolia', 'Normal']
# [488, 5, 0, 0, 'Centaurea spicata', 'Normal']
# [488, 9, 0, 0, 'Centaurea simulans', 'Normal']
# [488, 14, 0, 0, 'Centaurea babylonica', 'Normal']
# [489, 5, 0, 0, 'Centaurea behen', 'Normal']
# [489, 10, 0, 0, 'Centaurea rigida', 'Normal']
# [490, 12, 0, 0, 'Centaurea ptosimopappa', 'Normal']
# [491, 1, 0, 0, 'Centaurea solstitialis', 'Normal']
# [491, 9, 0, 0, 'Centaurea sinaica', 'Normal']
# [491, 16, 0, 0, 'Centaurea microenicus', 'Normal']
# [492, 5, 0, 0, 'Centaurea mesopotamica', 'Normal']
# [492, 10, 0, 0, 'Centaurea verutum', 'Normal']
# [493, 7, 0, 0, 'Centaurea calcitrapa', 'Normal']
# [493, 15, 0, 0, 'Centaurea iberica', 'Normal']
# [494, 19, 0, 0, 'Centaurea pallescens', 'Normal']
# [495, 1, 0, 0, 'Centaurea hyalolepis', 'Normal']
# [495, 7, 1, 0, 'Centaurea procurrens', 'Normal']
# [495, 12, 0, 0, 'Centaurea bruguieriana', 'Normal']
# [496, 5, 0, 0, 'Centaurea eryngioides', 'Normal']
# [496, 12, 0, 0, 'Centaurea mouterdei', 'Normal']
# [497, 2, 0, 0, 'Centaurea ainetensis', 'Normal']
# [497, 13, 0, 0, 'Centaurea carduiformis', 'Normal']
# [498, 1, 0, 0, 'Centaurea trachonitica', 'Normal']
# [498, 5, 0, 0, 'Centaurea crocodylium', 'Normal']
# [498, 11, 1, 0, 'Centaurea heterocarpa', 'Normal']
# [499, 6, 0, 0, 'Centaurea triumfettii', 'Normal']
# [499, 15, 0, 0, 'Centaurea cyanoides', 'Normal']
# [500, 7, 0, 0, 'Centaurea cyanus', 'Normal']
# [500, 15, 0, 0, 'Cnicus benedictus', 'Normal']
# [501, 22, 0, 0, 'Carthamus tinctorius', 'Normal']
# [501, 26, 0, 0, 'Carthamus persicus', 'Normal']
# [502, 7, 0, 0, 'Carthamus oxyacanthus', 'Normal']
# [503, 1, 0, 0, 'Carthamus nitidus', 'Normal']
# [503, 6, 0, 0, 'Carthamus tenuis', 'Normal']
# [504, 4, 0, 0, 'Carthamus dentatus', 'Normal']
# [504, 7, 0, 0, 'Carthamus glaucus', 'Normal']
# [505, 1, 0, 0, 'Carduncellus caeruleus', 'Normal']
# [505, 8, 0, 0, 'Scolymus maculatus', 'Normal']
# [505, 13, 0, 0, 'Scolymus hispanicus', 'Normal']
# [506, 3, 0, 0, 'Catananche lutea', 'Normal']
# [506, 15, 0, 0, 'Cichorium intybus', 'Normal']
# [506, 18, 0, 0, 'Cichorium pumilum', 'Normal']
# [507, 13, 0, 0, 'Hyoseris scabra', 'Normal']
# [508, 3, 0, 0, 'Hedypnois rhagadioloides', 'Normal']
# [508, 12, 0, 0, 'Hedypnois eretica', 'Normal']
# [509, 1, 0, 0, 'Lapsana conununis', 'Normal']
# [509, 10, 0, 0, 'Koelpinia linearis', 'Normal']
# [510, 1, 0, 0, 'Rhagadiolus stellatus', 'Normal']
# [510, 8, 0, 0, 'Rhagadiolus edulis', 'Normal']
# [510, 22, 0, 0, 'Garhadiolus hedypnois', 'Normal']
# [511, 7, 0, 0, 'Garhadiolus hamosus', 'Normal']
# [511, 10, 0, 0, 'Garhadiolus papposus', 'Normal']
# [512, 1, 0, 0, 'Tolpis barbata', 'Normal']
# [512, 5, 0, 0, 'Tolpis virgata', 'Normal']
# [513, 1, 0, 0, 'Leontodon tuberosus', 'Normal']
# [513, 9, 0, 0, 'Leontodon laciniatus', 'Normal']
# [513, 14, 0, 0, 'Leontodon libanoticus', 'Normal']
# [514, 4, 0, 0, 'Leontodon asperrimus', 'Normal']
# [514, 13, 0, 0, 'Urospermum picroides', 'Normal']
# [515, 21, 0, 0, 'Picris hieracioides', 'Normal']
# [515, 24, 0, 0, 'Picris strigosa', 'Normal']
# [516, 7, 0, 0, 'Picris altissima', 'Normal']
# [516, 14, 0, 0, 'Picris kotschyi', 'Normal']
# [516, 19, 0, 0, 'Picris longirostris', 'Normal']
# [517, 5, 0, 0, 'Picris amalecitana', 'Normal']
# [517, 10, 0, 0, 'Picris echioides', 'Normal']
# [518, 9, 0, 0, 'Tragopogon hybridum', 'Normal']
# [518, 17, 0, 0, 'Tragopogon longirostris', 'Normal']
# [519, 6, 0, 0, 'Tragopogon buphthalmoides', 'Normal']
# [520, 1, 0, 0, 'Tragopogon pterocarpus', 'Normal']
# [521, 4, 0, 0, 'Scorzonera cana', 'Normal']
# [522, 1, 0, 0, 'Scorzonera mollis', 'Normal']
# [523, 1, 0, 0, 'Scorzonera phaeopappa', 'Normal']
# [523, 14, 0, 0, 'Scorzonera libanotica', 'Normal']
# [524, 1, 0, 0, 'Scorzonera papposa', 'Normal']
# [524, 12, 0, 0, 'Scorzonera parviflora', 'Normal']
# [525, 1, 0, 0, 'Scorzonera mackmeliana', 'Normal']
# [525, 6, 0, 0, 'Scorzonera rigida', 'Normal']
# [525, 13, 0, 0, 'Scorzonera judaica', 'Normal']
# [526, 1, 0, 0, 'Scorzonera nervosa', 'Normal']
# [526, 5, 0, 0, 'Scorzonera kotschyi', 'Normal']
# [527, 1, 0, 0, 'Hypochoeris glabra', 'Normal']
# [527, 8, 0, 0, 'Seriola aethnensis', 'Normal']
# [529, 16, 0, 0, 'Taraxacum bessarabicum', 'Normal']
# [529, 19, 0, 0, 'Taraxacum assemanii', 'Normal']
# [529, 24, 0, 0, 'Taraxacum microcephalum', 'Normal']
# [530, 3, 0, 0, 'Taraxacum serotinum', 'Normal']
# [530, 6, 0, 0, 'Taraxacum brevirostre', 'Normal']
# [530, 9, 0, 0, 'Taraxacum syriacum', 'Normal']
# [530, 16, 0, 0, 'Taraxacum montanum', 'Normal']
# [530, 19, 0, 0, 'Taraxacum bithynicum', 'Normal']
# [532, 1, 0, 0, 'Taraxacum megalorrhizon', 'Normal']
# [532, 6, 0, 0, 'Taraxacum officinale', 'Normal']
# [532, 13, 0, 0, 'Taraxacum phaleratum', 'Normal']
# [532, 18, 0, 0, 'Taraxacum laevigatum', 'Normal']
# [533, 3, 0, 0, 'Ghondrilla juncea', 'Normal']
# [533, 19, 0, 0, 'Sonchus oleraceus', 'Normal']
# [534, 6, 0, 0, 'Sonchus asper', 'Normal']
# [534, 13, 0, 0, 'Sonchus tenerrimus', 'Normal']
# [534, 18, 0, 0, 'Sonchus maritimus', 'Normal']
# [535, 10, 0, 0, 'Lactuca serriola', 'Normal']
# [535, 18, 0, 0, 'Lactuca aculeata', 'Normal']
# [535, 21, 0, 0, 'Lactuca saligna', 'Normal']
# [536, 5, 0, 0, 'Lactuca undulata', 'Normal']
# [536, 14, 0, 0, 'Scariola viminea', 'Normal']
# [537, 8, 0, 0, 'Scariola orientalis', 'Normal']
# [537, 15, 0, 0, 'Scariola triquetra', 'Normal']
# [538, 3, 0, 0, 'Steptorhamphus tuberosus', 'Normal']
# [538, 13, 0, 0, 'Cicerbita mulgedioides', 'Normal']
# [539, 5, 0, 0, 'Cephalorrhynchus tuberosus', 'Normal']
# [540, 1, 0, 0, 'Reichardia tingitana', 'Normal']
# [540, 7, 0, 0, 'Reichardia intermedia', 'Normal']
# [540, 12, 0, 0, 'Reichardia picroides', 'Normal']
# [540, 17, 0, 0, 'Reichardia glauca', 'Normal']
# [541, 9, 0, 0, 'Launaea tenuiloba', 'Normal']
# [541, 14, 0, 0, 'Launaea nudicaulis', 'Normal']
# [542, 8, 0, 0, 'Aetheorhiza bulbosa', 'Normal']
# [543, 30, 0, 0, 'Crépis palaestina', 'Normal']
# [544, 7, 0, 0, 'Crépis robertioides', 'Normal']
# [544, 14, 0, 0, 'Crépis hierosolymitana', 'Normal']
# [545, 6, 0, 0, 'Crépis reuteriana', 'Normal']
# [546, 9, 0, 0, 'Crépis pulchra', 'Normal']
# [546, 14, 0, 0, 'Crépis micrantha', 'Normal']
# [546, 17, 0, 0, 'Crépis pterothecoides', 'Normal']
# [547, 5, 0, 0, 'Crépis foetida', 'Normal']
# [547, 14, 0, 0, 'Crépis kotschyana', 'Normal']
# [548, 5, 0, 0, 'Crépis senecioides', 'Normal']
# [548, 8, 0, 0, 'Crépis alpina', 'Normal']
# [548, 13, 0, 0, 'Crépis syriaca', 'Normal']
# [549, 6, 0, 0, 'Crépis aculeata', 'Normal']
# [549, 11, 0, 0, 'Crépis aspera', 'Normal']
# [549, 18, 0, 0, 'Crépis sancta', 'Normal']
# [550, 16, 0, 0, 'Andryala integrifolia', 'Normal']
# [551, 12, 0, 0, 'Hieracium bauhinii', 'Normal']
# [551, 13, 0, 0, 'n. 1). — 2J.. Rhizome court émettant des stolons minces, longs, foliés ou, plus rarement, des stolons courts voire absents. Tige principale dressée, 60-100 cm. ou', 'Possible OCR Error']
# [552, 1, 0, 0, 'Hieracium procerum', 'Normal']
# [552, 6, 0, 0, 'Hieracium schmidtii', 'Normal']
# [552, 11, 0, 0, 'Hieracium kneissaeum', 'Normal']
# 1145

# %%
## This cell requires ~20 mins to calculate results from the first book

import math
doc = fitz.open(fname)  # open document
#subset = items[:6]
subset = items
boxes = []
for it, item in enumerate(subset):
    mode = "searching"
    if (it >= len(subset) - 1):
        break
    next_item = subset[it + 1]
    [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0] = item
    [t, rr, rh, i, z,s, y,l, x,b, warning] = [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0]
    [t1, rr1, rh1, i1, z1,s1, y1,l1, x1,b1, warning1] = next_item
    page = doc[i0]
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", flags=flags)["blocks"]
    blocks = blocks[x:]
    r_rect = rr0
    
    #print(t0)
    # if t0 == "Isoetes olympica":
    #print([int(it), len(subset), rr0, t0, "\n", t1])
    
    annot_rect = page.add_rect_annot(rr0)
    annot_rect.set_border(width=1, dashes=[1,2])
    annot_rect.update()

    
    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        #annot = page.add_rect_annot(br)
        for y,l in enumerate(b["lines"][y0:]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            s = l["spans"][0]
            #for z,s in enumerate(l["spans"]):  # iterate through the text spans
            this_line = " ".join(list(map(lambda x: x["text"], l["spans"])))
            if mode != "found":
                if re.search("Aire g", this_line):
                    mode = s["font"] + " " + str(s["size"])
                    r_rect = r_rect.include_rect(lr)
                    #print(str((x, y, s["size"], s["font"])) + "FOUND: " + this_line)
                elif lr.intersects(rr1):                    
                    mode = "found"
                    #print(str((x, y, s["size"], s["font"])) + "FOUND: " + this_line)
                else:
                    if mode != "searching":
                        (font, size) = mode.split(" ")
                        isize = round(math.ceil(float(size)))
                        if s["size"] >= float(isize):
                            mode = "found"
                    if mode != "found":
                        r_rect = r_rect.include_rect(lr)
                        # if y >= y0:
                        #     r_rect = r_rect.include_rect(lr)
                    
    r_high = rh0
    annot_rect = page.add_rect_annot(r_rect)
    annot_high = page.add_highlight_annot(r_high)
    # boxes.append([t0, start_page + it, r_rect, item]) . ## FIXME: thinking it should be i0 not start_page + it
    boxes.append([t0, i0, r_rect, item])


# print(boxes[0])
print(len(boxes))

#doc.delete_pages(end_page, doc.page_count - 1)
#doc.delete_pages(0, start_page - 1)
marked_epithet_fname = "marked-pages-" + doc.name
doc.save(marked_epithet_fname, garbage=4, clean=True)
#!open -a Preview marked-pages-book-1-sample.pdf
#!open -a Preview marked-pages-book-1.pdf
# Out:
# 1144

# %%
import pprint
pp = pprint.PrettyPrinter(compact=True)

import math
doc = fitz.open(fname)  # open document
results = {}
for it, thing in enumerate(boxes):
    mode = "searching"
    #print(thing)
    [name, pageno, rrr, item] = thing
    page = doc[pageno] 
    [t0, rr0, rh0, i0, z0,s0, y0,l0, x0,b0, warning0] = item
    flags = 0 | fitz.TEXT_INHIBIT_SPACES | fitz.TEXT_DEHYPHENATE
    blocks = page.get_text("dict", clip=rr0, flags=flags)["blocks"]    


    print(pageno - txtpgoffset, i0, t0)
    results[t0] = {}
    results[t0]["name"] = t0
    results[t0]["name_rects"] = [rr0]
    results[t0]["pdf_page"] = pageno
    results[t0]["book_page"] = pageno - txtpgoffset
    key = "Extra"
    mode = "searching"
    margins = [[(math.ceil(l["bbox"][0]), l["spans"][0]["text"].split(" ")[0]) for l in filter(lambda bl: bl.get("spans"), b["lines"])] for b in blocks]
    margins = [m for n in margins for m in n]
    targets = list(map(lambda n: n[0], filter(lambda m: m[1] in ["L.", "S.", "Aire"] , margins))) or [blocks[0]["lines"][0]["bbox"][0]]
    margins_max = max(targets or margins)
    margins_min = min(list(map(lambda n: n[0], margins)))

    for x,b in enumerate(blocks):  # iterate through the text blocks
        br = fitz.Rect(b["bbox"])
        for y,l in enumerate(b["lines"][y0:]):  # iterate through the text lines
            lr = fitz.Rect(l["bbox"])
            xloc = min(margins_max, math.ceil(lr.x0))
            this_line = re.sub(r"\s+", " ", " ".join(list(map(lambda x: x["text"].strip(), l["spans"])))).strip()
            # matches = re.match("^(?P<label>L\.|S\.|Aire g\w+\.|Not\w+\.|Fleurs|Fructif\.|Fructific|Floraison\w+)\s", this_line)
            #### FIXME: Phyllitis scolopendrium (L.) Newm. —Asplenium scolopendrium L., Scolopendrium
            #### FIXME: Juniper
            matches = re.match("^(?P<label>" + t0 + "|.*?)(\s|$)", this_line)
            if matches:
                d = matches.groupdict()
                if margins_max - xloc < 5:
                    key = d["label"]
                    if ' ' in key:
                        key = "Description"
                    elif key not in ["Description", "L.", "S.", "Aire"]:
                        key = "Extra"
                    elif key in ["Description", "L.", "S.", "Aire"]:
                        pass
                    else:
                        print("UNHANDLED: " + key)
                        key = "Extra"
                frag = results[t0].get(key) or ""
                results[t0][key] = " ".join([frag.strip(), this_line.strip()]).strip()
                key_rects = key + "_rects"
                if not results[t0].get(key_rects):
                    results[t0][key_rects] = []    
                results[t0][key_rects].append(lr)
                #print([x, y, xloc, mode, this_line])
            else:
                print(["ERROR:", x, y, xloc, mode, this_line])
    # pp.pprint(results[t0])
    print()
    #break
                    
    # r_high = rh0
    # annot_rect = page.add_rect_annot(r_rect)
    # annot_high = page.add_highlight_annot(r_high)
    # boxes.append([t0, r_rect, item])
# Out:
# 6 6 JL
#
# 7 7 Rhododendron
#
# 8 8 Arbutus unedo
#
# 8 8 Arbutus andrachne
#
# 9 9 Erica
#
# 9 9 Pentapera sicula
#
# 10 10 Samolus
#
# 10 10 Ânagallis
#
# 11 11 Lysimachia
#
# 11 11 Asterolinon
#
# 12 12 Cyclamen
#
# 12 12 Cyclamen libanoticum
#
# 13 13 Cyclamen persicum
#
# 14 14 Androsace villosa
#
# 14 14 Androsace
#
# 14 14 Androsace
#
# 15 15 Primula vulgaris
#
# 16 16 Acantholimon
#
# 17 17 Acantholimon acerosum
#
# 18 18 Acantholimon
#
# 18 18 Acantholimon libanoticum
#
# 19 19 Acantholimon ulicinum
#
# 20 20 Goniolimon collinum
#
# 20 20 Limonium
#
# 21 21 Limonium
#
# 21 21 Limonium angustifolium
#
# 21 21 Limonium sieberi
#
# 22 22 Limonium
#
# 22 22 Limonium graecum
#
# 22 22 Limonium
#
# 23 23 Limoniumglobuliferum
#
# 23 23 Psylliostachys spicatus
#
# 23 23 Armeria
#
# 24 24 Plumbago europaea
#
# 25 25 Styrax
#
# 25 25 Olea europaea
#
# 26 26 Phillyrea
#
# 26 26 Fontanesia
#
# 27 27 Fraxinus ornus
#
# 27 27 Fraxinus excelsior
#
# 27 27 Fraxinus syriaca
#
# 28 28 Jasminum fruticans
#
# 29 29 Vinca
#
# 29 29 Vinca
#
# 29 29 Vinca libanotica
#
# 29 29 Trachomitum venetum
#
# 30 30 Nerium oleander
#
# 31 31 Blackstonia perfoliata
#
# 31 31 Blackstonia acuminata
#
# 31 31 Cicendia filifortnis
#
# 32 32 Centaurium pulchellum
#
# 32 32 Centaurium
#
# 33 33 Centaurium erythraea
#
# 33 33 Centaurium maritimum
#
# 33 33 Centaurium spicatum
#
# 34 34 Gentiana
#
# 35 35 Vincetoxicum
#
# 35 35 Vincetoxicum dionysiense
#
# 36 36 Cynanchum acutum
#
# 36 36 Cionura erecta
#
# 37 37 Periploca graeca
#
# 38 38 Periploca
#
# 40 40 Convolvulus hamrinensis
#
# 40 40 Convolvulus dorycnium
#
# 41 41 Convolvulus cantabrica
#
# 41 41 Convolvulus
#
# 41 41 Convolvulus libanoticus
#
# 42 42 Convolvulus secundus
#
# 42 42 Convolvulus reticulatus
#
# 42 42 Convolvulus pilosellifolius
#
# 43 43 Convolvulus galaticus
#
# 43 43 Convolvulus betonicifolius
#
# 43 43 Convolvulus cassius
#
# 44 44 Convolvulus
#
# 44 44 Convolvulus
#
# 44 44 Convolvulus
#
# 45 45 Convolvulus
#
# 45 45 Convolvulus scammonia
#
# 45 45 Convolvulus arvensis
#
# 46 46 Convolvulus coelesyriacus
#
# 46 46 Convolvulus siculus
#
# 46 46 Convolvulus pentapetaloides
#
# 47 47 Convolvulus tricolor
#
# 47 47 Convolvulus
#
# 47 47 Calystegia sepium
#
# 48 48 Calystegia silvatica
#
# 48 48 Ipomoea stolonifera
#
# 48 48 Ipomoea sagittata
#
# 49 49 Ipomoea
#
# 49 49 Gressa eretica
#
# 51 51 Cuscuta
#
# 51 51 Guscuta planiflora
#
# 51 51 Cuscuta approximata
#
# 52 52 Cuscuta
#
# 52 52 Cuscuta balansae
#
# 53 53 Cuscuta brevistyla
#
# 53 53 Cuscuta europaea
#
# 54 54 Cuscuta
#
# 54 54 Cuscuta babylonica
#
# 54 54 Cuscuta pedicellata
#
# 54 54 Cuscuta campestris
#
# 55 55 Cuscuta
#
# 56 56 Heliotropium supinum
#
# 56 56 Heliotropium myosotoides
#
# 57 57 Heliotropium lasiocarpum
#
# 57 57 Heliotropium dolosum
#
# 57 57 Heliotropium
#
# 58 58 Heliotropium bovei
#
# 58 58 Heliotropium
#
# 59 59 Heliotropium
#
# 59 59 Heliotropium
#
# 59 59 Heliotropium ramosissimum
#
# 60 60 Asperugo procumbens
#
# 60 60 Caccinia
#
# 61 61 Lappula spinocarpos
#
# 61 61 Lappula barbata
#
# 62 62 Lappula sinaica
#
# 62 62 Lappula
#
# 62 62 Heterocaryum szovitsianum
#
# 63 63 Heterocaryum subsessile
#
# 63 63 Rindera
#
# 64 64 Paracaryum rugulosum
#
# 64 64 Mattiastrum lithospermifolium
#
# 64 64 Mattiastrum lamprocarpum
#
# 65 65 Rochelia cancellata
#
# 65 65 Rochelia disperma
#
# 66 66 Rochelia
#
# 66 66 Solenanthus stamineus
#
# 66 66 Solenanthus circinnatus
#
# 67 67 Moltkia coerulea
#
# 67 67 Moltkia longiflora
#
# 68 68 Cynoglossum nebrodense
#
# 68 68 Cynoglossum creticum
#
# 69 69 Lithospermum
#
# 69 69 Lithospermum arvense L.
#
# 70 70 Lithospermum sibthorpianum
#
# 70 70 Lithospermum incrassatum
#
# 70 70 Lithospermum
#
# 70 70 Lithospermum
#
# 71 71 Lithodora
#
# 71 71 Arnebia decumbens
#
# 72 72 Ârnebia tubata
#
# 72 72 Arnebia
#
# 73 73 Cerinthe
#
# 73 73 Cerinthe major
#
# 73 73 Cerinthe palaestina
#
# 74 74 Onosma
#
# 75 75 Onosma
#
# 76 76 Onosma frutescents
#
# 76 76 Onosma cassia
#
# 77 77 Onosma mollis
#
# 77 77 Onosma cinerea
#
# 78 78 Onosma
#
# 78 78 Onosma
#
# 79 79 Onosma roussaei
#
# 79 79 Onosma aucherana
#
# 79 79 Onosma gigantea
#
# 80 80 Onosma auriculata
#
# 81 81 Echium glomeratum
#
# 81 81 Echium
#
# 81 81 Echium pabotii
#
# 82 82 Echium angustifolium
#
# 82 82 Echium plantagineum
#
# 82 82 Echium judaeum
#
# 83 83 Echium
#
# 84 84 Anchusa
#
# 84 84 Anchusa azurea
#
# 85 85 Anchusa
#
# 85 85 Anchusa barrelieri
#
# 86 86 Anchusa
#
# 86 86 Anchusa
#
# 86 86 Anchusa tiberiadis
#
# 87 87 Hormuzakia aggregata
#
# 87 87 Gastrocotyle
#
# 88 88 Phyllocara
#
# 88 88 Brunnera
#
# 89 89 Nonea obtusifolia
#
# 89 89 Nonea palmyrensis
#
# 90 90 Nonea caspica
#
# 90 90 Nonea ventricosa
#
# 91 91 Myosotis caespitosa
#
# 92 92 Myosotis sicula
#
# 92 92 Myosotis
#
# 92 92 Myosotis ramosissima
#
# 92 92 Myosotis stricta
#
# 93 93 Myosotis
#
# 93 93 Myosotis macrosiphon
#
# 94 94 Alkanna orientalis
#
# 95 95 Alkanna
#
# 95 95 Alkanna
#
# 96 96 Alkanna hirsutissima
#
# 96 96 Alkanna
#
# 97 97 Alkanna leiocarpa
#
# 97 97 Alkanna tinctoria
#
# 97 97 Alkanna
#
# 98 98 Alkanna strigosa
#
# 99 99 Symphytum
#
# 99 99 Symphytum palaestinum
#
# 99 99 Borago
#
# 100 100 Cordia
#
# 100 100 Verbena
#
# 101 101 Verbena supina
#
# 102 102 Vitex
#
# 103 103 Ajuga orientalis
#
# 103 103 Ajuga laevigata
#
# 104 104 Ajuga chia
#
# 104 104 Ajuga tridactylites
#
# 105 105 Ajuga
#
# 106 106 Ajuga
#
# 108 108 Teucrium creticum
#
# 108 108 Teucrium multicaule
#
# 108 108 Teucrium pruinosum
#
# 109 109 Teucrium
#
# 109 109 Teucrium orientale
#
# 109 109 Teucrium procerum
#
# 110 110 Teucrium oliverianum
#
# 110 110 Teucrium parviflorum
#
# 110 110 Teucrium
#
# 111 111 Teucrium
#
# 111 111 Teucrium scordioides
#
# 111 111 Teucrium spinosum
#
# 112 112 Teucrium montbretii
#
# 112 112 Teucrium haradjianii
#
# 113 113 Teucrium
#
# 113 113 Teucrium
#
# 114 114 Teucrium
#
# 114 114 Teucrium coniortodes
#
# 115 115 Teucrium
#
# 115 115 Teucrium
#
# 116 116 Teucriuflft antilibanoticum
#
# 116 116 Prasium
#
# 117 117 Scutellaria orientalis
#
# 117 117 Scutellaria cretacea
#
# 118 118 Scutellaria
#
# 118 118 Scutellaria diffusa
#
# 118 118 Scutellaria
#
# 118 118 Scutellaria brevibracteata
#
# 119 119 Scutellaria
#
# 120 120 Lavandula
#
# 121 121 Marrubium hierapolitanum
#
# 121 121 Marrubium libanoticum
#
# 121 121 Marrubium cuneatum
#
# 122 122 Marrubium radiatum
#
# 122 122 Marrubium vulgare
#
# 124 124 Nepeta cataria
#
# 124 124 Nepeta leucostegia
#
# 124 124 Nepeta italica
#
# 125 125 Nepeta curviflora
#
# 125 125 Nepeta x
#
# 126 126 Nepeta cilicica
#
# 126 126 Nepeta glomerata
#
# 126 126 Nepeta pabotii
#
# 127 127 Nepeta
#
# 127 127 Nepeta bithynica
#
# 127 127 Nepeta trachonitica
#
# 128 128 Nepeta
#
# 128 128 Nepeta cryptantha
#
# 129 129 Sideritis
#
# 129 129 Sideritis montana
#
# 130 130 Sideritis
#
# 130 130 Sideritis balansae
#
# 130 130 Sideritis
#
# 131 131 Sideritis libanotica
#
# 131 131 Sideritis nusairiensis
#
# 131 131 Sideritis perfoliata
#
# 132 132 Sideritis
#
# 132 132 Lallemantia royleana
#
# 133 133 Lallemantia
#
# 133 133 Thuspeinanta
#
# 134 134 Prunella vulgaris
#
# 134 134 Prunella orientalis
#
# 135 135 Prunella laciniata
#
# 135 135 Eremostachys
#
# 136 136 Eremostachys macrophylla
#
# 137 137 Phlomis
#
# 137 137 Phlomis
#
# 138 138 Phlomis
#
# 138 138 Phlomis kurdica
#
# 138 138 Phlomis brachyodon
#
# 139 139 Phlomis
#
# 140 140 Phlomis chrysophylla
#
# 140 140 Phlomis viscosa
#
# 140 140 Phlomis bailanica
#
# 141 141 Phlomis
#
# 141 141 Phlomis rigida
#
# 141 141 Phlomis pungens
#
# 143 143 Lamium
#
# 143 143 Lamium
#
# 143 143 Lamium veronicifolium
#
# 144 144 Lamium
#
# 144 144 Lamium aleppicum
#
# 144 144 Lamium ehrenbergii
#
# 145 145 Lamium adoxifolium
#
# 145 145 Lamium
#
# 145 145 Lamium truncatum
#
# 145 145 Lamium moschatum
#
# 146 146 Lamium
#
# 146 146 Wiedemannia
#
# 147 147 Moluccella laevis
#
# 147 147 Moluccella spinosa
#
# 148 148 Ballota nigra
#
# 148 148 Ballota damascena
#
# 149 149 Ballota undulata
#
# 149 149 Ballota antilibanotica
#
# 149 149 Ballota saxatilis
#
# 150 150 Ballota semaanica
#
# 152 152 Stachys libanotica
#
# 152 152 Stachys ehrenbergii
#
# 153 153 Stachys eretica
#
# 153 153 Stachys
#
# 154 154 Stachys dictyoneura
#
# 154 154 Stachys viticina
#
# 154 154 Stachys longispicata
#
# 155 155 Stachys hydrophila
#
# 155 155 Stachys iberica
#
# 155 155 Stachys distans
#
# 156 156 Stachys
#
# 156 156 Stachys nivea
#
# 156 156 Stachys paneiana
#
# 157 157 Stachys palaestina
#
# 157 157 Stachys
#
# 157 157 Stachys petrokosmos
#
# 158 158 Stachys
#
# 158 158 Stachys annua
#
# 159 159 Stachys
#
# 159 159 Stachys obscura
#
# 159 159 Stachys arvensis
#
# 159 159 Stachys
#
# 160 160 Stachys satureioides
#
# 160 160 Stachys
#
# 160 160 Stachys neurocalycina
#
# 160 160 Rosmarinus officinalis
#
# 164 164 Salvia tomentosa
#
# 164 164 Salvia
#
# 165 165 Salvia fruticosa
#
# 165 165 Salvia
#
# 165 165 Salvia spiraeifolia
#
# 166 166 Salvia pinnata
#
# 166 166 Salvia
#
# 166 166 Salvia bracteata
#
# 167 167 Salvia
#
# 167 167 Salvia pinardii
#
# 168 168 Salvia nazalena
#
# 168 168 Salvia syriaca
#
# 168 168 Salvia montbretii
#
# 169 169 Salvia spinosa
#
# 169 169 Salvia palaestina
#
# 169 169 Salvia
#
# 170 170 Salvia peyronii
#
# 170 170 Salvia dominica
#
# 171 171 Salvia sclarea
#
# 171 171 Salvia ceratophylla
#
# 171 171 Salvia drusica
#
# 172 172 Salvia microstegia
#
# 172 172 Salvia cassia
#
# 173 173 Salvia indica
#
# 173 173 Salvia hierosolymitana
#
# 174 174 Salvia virgata
#
# 174 174 Salvia viscosa
#
# 174 174 Salvia verbenaca
#
# 175 175 Salvia lanigera
#
# 175 175 Salvia viridis
#
# 176 176 Salvia judaica
#
# 177 177 Salvia russellii
#
# 178 178 Melissa
#
# 178 178 Melissa inodora
#
# 179 179 Satureia
#
# 179 179 Satureia
#
# 179 179 Satureia
#
# 181 181 Micromeria Juliana
#
# 181 181 Micromeria amana
#
# 182 182 Micromeria graeca
#
# 182 182 Micromeria
#
# 183 183 Micromeria
#
# 183 183 Micromeria
#
# 183 183 Micromeria serpyllifolia
#
# 183 183 Micromeria barbata
#
# 184 184 Calamintha betulifolia
#
# 185 185 Calamintha nepeta
#
# 185 185 Calamintha incana
#
# 185 185 Calamintha vulgaris
#
# 186 186 Calamintha origanifolia
#
# 186 186 Calamintha rotundifolia
#
# 187 187 Ziziphora
#
# 187 187 Ziziphora capitata
#
# 188 188 Ziziphora
#
# 188 188 Ziziphora
#
# 189 189 Ziziphora
#
# 189 189 Ziziphora taurica
#
# 190 190 Origanum bargyli
#
# 191 191 Origanum
#
# 191 191 Origanum
#
# 191 191 Origanum libanoticum
#
# 193 193 Origanum
#
# 193 193 Origanum ehrenbergii
#
# 194 194 Origanum ehrenbergii
#
# 194 194 Origanum syriacum
#
# 195 195 Thymus sipyleus
#
# 195 195 Thymus kotschyanus
#
# 196 196 Thymus hirsutus
#
# 196 196 Thymus
#
# 196 196 Thymus syriacus
#
# 197 197 Thymus cilicicus
#
# 197 197 Thymus alfredae
#
# 197 197 Coridothymus
#
# 197 197 Thymbra spicata
#
# 198 198 Lycopus europaeus
#
# 199 199 Mentha pulegium
#
# 199 199 Mentha aquatica
#
# 199 199 Mentha longifolia
#
# 200 200 Mentha microphylla
#
# 201 201 Nicandra
#
# 201 201 Atropa belladonna
#
# 202 202 Mandragora autumnalis
#
# 203 203 Lycium
#
# 203 203 Lycium barbarum
#
# 203 203 Lycium
#
# 204 204 Solanum nigrum
#
# 204 204 Solanum luteum
#
# 205 205 Solanum luteum
#
# 205 205 Solanum dulcamara
#
# 205 205 Withania somnifera
#
# 206 206 Datura
#
# 206 206 Datura xnetel
#
# 206 206 Nicotiana glauca
#
# 207 207 Hyoscyamus muticus
#
# 207 207 Hyoscyamus desertorum
#
# 208 208 Hyoscyamus pusillus
#
# 208 208 Hyoscyamus niger
#
# 208 208 Hyoscyamus reticulatus
#
# 209 209 Hyoscyamus
#
# 209 209 Hyoscyamus aureus
#
# 212 212 Verbascum
#
# 213 213 Verbascum
#
# 213 213 Verbascum agrimoniifolium
#
# 214 214 Verbascum antilibanoticum
#
# 214 214 Verbascum levanticum
#
# 214 214 Verbascum orientale
#
# 215 215 Verbascum blancheanum
#
# 215 215 Verbascum
#
# 216 216 Verbascum
#
# 216 216 Verbascum tiberiadis
#
# 216 216 Verbascum
#
# 217 217 Verbascum
#
# 217 217 Verbascum alepense
#
# 218 218 Verbascum
#
# 218 218 Verbascum
#
# 218 218 Verbascum eremobium
#
# 219 219 Verbascum cedreti
#
# 219 219 Verbascum
#
# 220 220 Verbascum tropidocarpum
#
# 220 220 Verbascum
#
# 221 221 Verbascum sinuatum
#
# 221 221 Verbascum
#
# 222 222 Verbascum
#
# 222 222 Verbascum
#
# 222 222 Verbascum caesareum
#
# 223 223 Verbascum
#
# 223 223 Verbascum galilaeum
#
# 224 224 Verbascum
#
# 224 224 Verbascum antari
#
# 224 224 Verbascum libanoticum
#
# 225 225 Verbascum aliciae
#
# 225 225 Verbascum geminiflorum
#
# 225 225 Verbascum
#
# 226 226 Verbascum glomeratum
#
# 226 226 Verbascum
#
# 227 227 Verbascum
#
# 227 227 Verbascum
#
# 228 228 Verbascum
#
# 228 228 Verbascum alepense
#
# 228 228 Verbascum aliciae
#
# 228 228 Verbascum
#
# 228 228 Verbascum gaillardotii
#
# 228 228 Verbascum gaillardotii
#
# 228 228 Verbascum galilaeum
#
# 228 228 Verbascum leptostachyum
#
# 228 228 Verbascum leptostachyum
#
# 228 228 Verbascum sinuatum L. X tripolitanum
#
# 229 229 Antirrhinum orontium
#
# 229 229 Antirrhinum majus
#
# 229 229 Antirrhinum tortuosum
#
# 230 230 Anarrhinum
#
# 231 231 Kickxia commutata
#
# 231 231 Kickxia elatine
#
# 231 231 Kickxia
#
# 232 232 Kickxia
#
# 232 232 Kickxia lanigera
#
# 233 233 Kickxia
#
# 233 233 Kickxia gombaultii
#
# 235 235 Linaria cymbalaria
#
# 235 235 Linaria longipes
#
# 235 235 Linaria aucheri
#
# 235 235 Linaria
#
# 236 236 Linaria
#
# 236 236 Linaria arvensis
#
# 236 236 Linaria
#
# 237 237 Linaria genistifolia
#
# 237 237 Linaria
#
# 237 237 linariachalepensis
#
# 238 238 Linaria tenuis
#
# 239 239 Linaria
#
# 239 239 Linaria minor
#
# 239 239 Linaria persica
#
# 240 240 Mosheovia
#
# 242 242 Scrophularia
#
# 242 242 Scrophularia
#
# 242 242 Scrophularia
#
# 243 243 Scrophularia
#
# 243 243 Scrophularia scariosa
#
# 243 243 Scrophularia hierochuntina
#
# 244 244 Scrophularia
#
# 244 244 Scrophularia tagetifolia
#
# 244 244 Scrophularia lucida
#
# 245 245 Scrophularia
#
# 245 245 Scrophularia deserti
#
# 245 245 Scrophularia peyronii
#
# 246 246 Scrophularia xylorrhiza
#
# 246 246 Scrophularia libanotica
#
# 247 247 Scrophularia
#
# 247 247 Scrophularia xanthoglossa
#
# 247 247 Scrophularia decipiens
#
# 251 251 Veronica caespitosa
#
# 252 252 Veronica bombycina
#
# 252 252 Veronica
#
# 253 253 Veronica leiocarpa
#
# 254 254 Veronica
#
# 255 255 Veronica orientalis
#
# 257 257 Veronica
#
# 259 259 Veronica anagalloides
#
# 260 260 Veronica beccabunga
#
# 261 261 Veronica arvensis
#
# 261 261 Veronica viscosa
#
# 262 262 Veronica pusilla
#
# 262 262 Veronica hispidula
#
# 262 262 Veronica reuterana
#
# 263 263 Veronica syriaca
#
# 263 263 Veronica
#
# 264 264 Veronica triphyllos
#
# 264 264 Veronica
#
# 265 265 Veronica
#
# 265 265 Veronica persica
#
# 266 266 Veronica
#
# 267 267 Veronica biloba
#
# 267 267 Veronica hederifolia
#
# 268 268 Veronica triloba
#
# 269 269 Veronica
#
# 269 269 Veronica
#
# 271 271 Digitalis ferruginea
#
# 272 272 Siphonostegia syriaca
#
# 272 272 Bungea
#
# 272 272 Parentucellia latifolia
#
# 273 273 Parentucellia viscosa'
#
# 273 273 Bellardia
#
# 274 274 Odontites aucheri
#
# 274 274 Odontites lutea
#
# 275 275 Pedicularis
#
# 275 275 Globularia
#
# 276 276 Utricularia australia
#
# 276 276 Sesamum indicum
#
# 277 277 Acanthus mollis
#
# 277 277 Acanthus dioscoridis
#
# 278 278 Acanthus syriacus
#
# 279 279 Cistanche phelipaea
#
# 279 279 Cistanche tubulosa
#
# 280 280 Cistanche salsa
#
# 281 281 Orobanche ramosa
#
# 282 282 Orobanche mutelii
#
# 282 282 Orobanche nana
#
# 282 282 Orobanche lavandulacea
#
# 283 283 Orobanche
#
# 283 283 Orobanche astragali
#
# 284 284 Orobanche libanotica
#
# 284 284 Orobanche
#
# 285 285 Orobanche serratocalyx
#
# 285 285 Orobanche
#
# 286 286 Orobanche major
#
# 286 286 Orobanche crenata
#
# 286 286 Orobanche pubescens
#
# 287 287 Orobanche
#
# 287 287 Orobanche grisebachii
#
# 288 288 Orobanche cernua
#
# 288 288 Orobanche camptolepis
#
# 290 290 Plantago major
#
# 290 290 Plantago lanceolate
#
# 291 291 Plantago
#
# 291 291 Plantago
#
# 292 292 Plantago
#
# 292 292 Plantago ovata
#
# 293 293 Plantago loeflingii
#
# 293 293 Plantago notata
#
# 294 294 Plantago crassifolia
#
# 294 294 Plantago maritima
#
# 294 294 Plantago
#
# 294 294 Plantago albicans
#
# 295 295 Plantago
#
# 295 295 Plantago coronopus
#
# 296 296 Plantago afra
#
# 296 296 Plantago
#
# 297 297 Oldenlandia
#
# 298 298 Putoria calabrica
#
# 298 298 Rubia aucheri
#
# 299 299 Rubia tinctorum
#
# 299 299 Rubia tenuifolia
#
# 300 300 Sherardia
#
# 301 301 Crucianella latifolia
#
# 301 301 Crucianella
#
# 302 302 Crucianella imbricata
#
# 302 302 Crucianella exasperata
#
# 303 303 Crucianella
#
# 303 303 Crucianella membranacea
#
# 303 303 Crucianella ciliata
#
# 304 304 Asperula glomerata
#
# 305 305 Asperula arvensis
#
# 305 305 Asperula orientali»
#
# 305 305 Asperula
#
# 306 306 Asperula stricta
#
# 306 306 Asperula glareosa
#
# 306 306 Asperula libanotica
#
# 307 307 Asperula bargyli
#
# 307 307 Asperula
#
# 307 307 Asperula rivalis
#
# 310 310 Galium
#
# 310 310 Galium pestalozzae
#
# 311 311 Galium
#
# 311 311 Galium prusense
#
# 312 312 Galiuxn
#
# 312 312 'Galium bassitense
#
# 312 312 Galium verum
#
# 313 313 Galium
#
# 314 314 Galium thiebautii
#
# 314 314 Galium thiebautii X
#
# 314 314 Galium
#
# 315 315 Galiutn verrucosmn
#
# 315 315 Galium tricornutum
#
# 315 315 Galium
#
# 315 315 Galium spurium
#
# 316 316 Galium
#
# 316 316 Galium pisiferum
#
# 316 316 Galium peplidifolium
#
# 317 317 Galium
#
# 317 317 Galium
#
# 317 317 Galium tenuissimum
#
# 318 318 Galium
#
# 318 318 Galium
#
# 318 318 Galium hierosolymitanum
#
# 319 319 Galium
#
# 319 319 Galium setaceum
#
# 320 320 Galium
#
# 320 320 Galium bracteatum
#
# 320 320 Galium murale
#
# 321 321 Galium verticillatam
#
# 321 321 Cruciata coronata
#
# 322 322 Cruciata
#
# 322 322 Cruciata articulata
#
# 323 323 Valantia muralis
#
# 323 323 Valantia hispida
#
# 323 323 Mericarpaea vaillantioides
#
# 324 324 Callipeltis factorovskyi
#
# 324 324 Callipeltis cucullaris
#
# 325 325 Sambucus
#
# 326 326 Sambucus
#
# 326 326 Viburnum tinus
#
# 326 326 Lonicera etrusca
#
# 327 327 Lonicera
#
# 327 327 Lonicera orientalis
#
# 328 328 Valeriana dioscoridis
#
# 328 328 Centranthus longiflorus
#
# 330 330 Valerianella tuberculata
#
# 330 330 Valerianella dactylophylla
#
# 331 331 Valerianella oxyrhyncha
#
# 331 331 Valerianella cymbicarpa
#
# 331 331 Valerianella szovitsiana
#
# 332 332 Valerianella
#
# 332 332 Valerianella
#
# 333 333 Valerianella soyeri
#
# 333 333 Valerianella
#
# 333 333 Valerianella locusta
#
# 334 334 Valerianella dentata
#
# 334 334 Valerianella muricata
#
# 334 334 Valerianella carinata
#
# 335 335 .Valerianella
#
# 335 335 Valerianella pumila
#
# 335 335 Valerianella
#
# 336 336 Valerianella antilibanotica
#
# 336 336 Valerianella
#
# 336 336 Valerianella
#
# 337 337 Valerianella coronata
#
# 337 337 Valerianella discoidea
#
# 337 337 Valerianella
#
# 338 338 Valerianella vesicaria
#
# 338 338 Morina
#
# 339 339 Dipsacus sativus
#
# 339 339 Dipsacus
#
# 340 340 Dipsacus laciniatus
#
# 341 341 Cephalaria
#
# 342 342 Cephalaria
#
# 342 342 Cephalaria syriaca
#
# 343 343 Cephalaria
#
# 343 343 Cephalaria
#
# 344 344 Cephalaria
#
# 344 344 Cephalaria.amana
#
# 345 345 Cephalaria cedrorum
#
# 346 346 Knautia integrifolia
#
# 346 346 Knautia bidens
#
# 346 346 Pterocephalus
#
# 347 347 Pterocephalus brevis
#
# 347 347 Pterocephalus pulverulentus
#
# 349 349 Scabiosa
#
# 349 349 Scabiosa intermedia
#
# 349 349 Scabiosa argentea
#
# 350 350 Scabiosa
#
# 350 350 Scabiosa
#
# 350 350 Scabiosa
#
# 351 351 Scabiosa
#
# 351 351 Scabiosa palaestina
#
# 352 352 Scabiosa
#
# 353 353 Cucumis phrophetarum
#
# 354 354 Citrullus colocynthis
#
# 354 354 Ecballium elaterium
#
# 355 355 Bryonia
#
# 355 355 Bryonia syriaca
#
# 355 355 Bryonia lasiocarpa
#
# 355 355 Note de l'éditeur:
#
# 356 356 Laurentia minuta
#
# 356 356 Laurentia gasparrinii
#
# 358 358 Campanula euclasta
#
# 359 359 Campanula
#
# 359 359 Campanula trichopoda
#
# 359 359 Campanula
#
# 360 360 Campanula
#
# 360 360 Campanula stricta
#
# 360 360 Campanula stellaris
#
# 361 361 Campanula,
#
# 361 361 Campanula propinqua
#
# 362 362 Campanula cecilii
#
# 362 362 Campanula reuteriana
#
# 362 362 Campanula hierosolymitana
#
# 363 363 Campanula
#
# 363 363 Campanula camptoclada
#
# 363 363 Campanula erinus
#
# 363 363 Campanula peregrina
#
# 364 364 Campanula rapunculus
#
# 364 364 Campanula
#
# 365 365 Campanula kotschyana
#
# 365 365 Campanula flaccidula
#
# 365 365 Campanula
#
# 366 366 Campanula sidoniensis
#
# 366 366 Campanula fastigiata
#
# 367 367 Michauxia campanuloides
#
# 367 367 Michauxia
#
# 368 368 Asyneuma virgatum
#
# 368 368 Asyneuma rigidum
#
# 369 369 Legousia falcata
#
# 369 369 Legousia speculum-veneris
#
# 369 369 Legousia pentagonia
#
# 370 370 Tracheliopsis tubulosa
#
# 371 371 Tracheliopsis
#
# 371 371 Tracheliopsis postii
#
# 372 372 Eupatorium
#
# 372 372 en
#
# 372 372 Eupatorium
#
# 373 373 Solidago
#
# 373 373 Erigeron libanoticus
#
# 374 374 Erigeron
#
# 374 374 Erigeron bonariensis
#
# 374 374 Erigeron naudinii
#
# 375 375 Psychrogeton nigromontanus
#
# 375 375 Pluchea dioscoridis
#
# 376 376 Bellis
#
# 376 376 Bellis perennis
#
# 376 376 Bellis sylvestris
#
# 377 377 Asteriscus aquaticus
#
# 377 377 Asteriscus pygmaeus
#
# 377 377 Asteriscus graveolens
#
# 378 378 Pallenis spinosa
#
# 379 379 Postia
#
# 379 379 Postia
#
# 380 380 Inula
#
# 380 380 Inula vulgaris
#
# 380 380 Inula crithmoides
#
# 380 380 Inula heterolepis
#
# 381 381 Inula
#
# 381 381 Inula graveolens
#
# 381 381 Pentanema divaricata
#
# 382 382 Pulicaria dysenterica
#
# 383 383 Pulicaria
#
# 383 383 Pulicaria auranitica
#
# 383 383 Pulicaria arabica
#
# 384 384 Pulicaria laniceps
#
# 384 384 Francœuria
#
# 385 385 Varthemia iphionoides
#
# 385 385 Phagnalon
#
# 386 386 Phagnalon kotschyi
#
# 386 386 Phagnalon
#
# 386 386 Lasiopogon
#
# 387 387 Gnaphalium
#
# 387 387 Gnaphalium uliginosum
#
# 388 388 Helichrysum
#
# 389 389 Helichrysum
#
# 389 389 Helichrysum armenium
#
# 389 389 Helichrysum pallasii
#
# 390 390 Helichrysum
#
# 390 390 Helichrysum plicatum
#
# 391 391 Helichrysum
#
# 391 391 Helichrysum sanguineum
#
# 392 392 Leysera leyseroides
#
# 393 393 Gymnarrhena micrantha
#
# 393 393 Micropus supinus
#
# 394 394 Bombycilaena discolor
#
# 394 394 Bombycilaena erecta
#
# 394 394 Cymbolaena
#
# 396 396 Filago
#
# 396 396 Filago pyramidata
#
# 397 397 Filago
#
# 397 397 Filago arvensis
#
# 397 397 Filago gallica
#
# 398 398 Filago anatolica
#
# 398 398 Filago palaestina
#
# 398 398 Filago
#
# 399 399 Filago contracta
#
# 399 399 Filago pygmaea
#
# 399 399 Ifloga spicata
#
# 400 400 Eclipta prostrata
#
# 400 400 Guizotia
#
# 401 401 Bidens
#
# 401 401 Bidens pilosa L.
#
# 401 401 Bidens frondosa
#
# 401 401 Tagetes minuta
#
# 402 402 Ambrosia maritima
#
# 402 402 Xanthium
#
# 403 403 Xanthium echinatum
#
# 403 403 Xanthium strumarium
#
# 403 403 Otanthus maritimus
#
# 404 404 Achillea membranacea
#
# 405 405 Achillea oligocephala
#
# 405 405 Achillea
#
# 405 405 Achillea
#
# 406 406 Achillea falcata
#
# 406 406 Achillea conferta
#
# 407 407 Achillea
#
# 407 407 Achillea kotschyi
#
# 407 407 Achillea
#
# 409 409 Anthémis
#
# 410 410 Anthémis
#
# 411 411 Anthémis
#
# 411 411 Anthémis
#
# 411 411 Anthémis
#
# 412 412 Anthémis
#
# 412 412 Anthémis
#
# 413 413 Anthémis samuelssonii
#
# 413 413 Anthémis eretica
#
# 414 414 Anthémis
#
# 414 414 Anthémis
#
# 415 415 Anthémis
#
# 415 415 Anthémis
#
# 415 415 Anthémis wettsteiniana
#
# 416 416 Anthémis
#
# 416 416 Anthémis
#
# 417 417 Anthémis chia
#
# 417 417 Anthémis
#
# 418 418 Anthémis
#
# 418 418 Anthémis
#
# 418 418 Anthémis
#
# 419 419 Anthémis
#
# 419 419 Anthémis
#
# 419 419 Anthémis pseudocotula
#
# 420 420 Anthémis
#
# 420 420 Anthémis
#
# 421 421 Chamaemelum mixtum
#
# 422 422 Anacyclus radiatus
#
# 422 422 Anacyclus clavatus
#
# 422 422 Anacyclus nigellifolius
#
# 423 423 Matricaria chamomilla
#
# 423 423 Matricaria aurea
#
# 424 424 Tripleurospermum
#
# 424 424 Tripleurospermum auriculatum
#
# 425 425 Tripleurospermum sannineum
#
# 425 425 Tripleurospermum
#
# 425 425 Tripleurospermum oreades
#
# 426 426 Chrysanthemum
#
# 427 427 Chrysanthemum segetum
#
# 427 427 Chrysanthemum coronarium
#
# 428 428 Tanacetum
#
# 428 428 Tanacetum poteriifolium
#
# 428 428 Tanacetum cilicium
#
# 429 429 Tanacetum
#
# 429 429 Tanacetum yabrudae
#
# 430 430 Tanacetum aucheri
#
# 430 430 Tanacetum argenteum
#
# 431 431 Artemisia monosperma
#
# 431 431 Artemisia scoparia
#
# 431 431 Artemisia annua
#
# 432 432 Artemisiaherba-alba
#
# 432 432 Artemisia verlotorum
#
# 432 432 Artemisia arborescens
#
# 433 433 Tussilago farfara
#
# 433 433 Doronicum orientale
#
# 434 434 Senecio vulgaris
#
# 435 435 Senecio
#
# 435 435 Senecio vernalis
#
# 436 436 Senecio exilis
#
# 436 436 Senecio gallicus
#
# 436 436 Senecio aquaticus
#
# 437 437 Senecio mouterdei
#
# 437 437 Senecio
#
# 437 437 Senecio
#
# 438 438 Senecio
#
# 439 439 Calendula officinalis
#
# 439 439 Calendula sinuata
#
# 440 440 Calendula bicolor
#
# 440 440 Calendula arvensis
#
# 440 440 Calendula aegyptiaca
#
# 441 441 Calendula palaestina
#
# 441 441 Calendula tripterocarpa
#
# 441 441 Dipterocome pusilla
#
# 442 442 Gundelia
#
# 443 443 Echinops
#
# 443 443 Echinops gaillardotii
#
# 444 444 Echinops
#
# 444 444 Echinops
#
# 445 445 Acantholepis
#
# 445 445 Cardopatium corymbosum
#
# 446 446 Xeranthemum
#
# 446 446 Xeranthemum inapertum
#
# 447 447 Xeranthemum
#
# 447 447 Xeranthemum cylindraceum
#
# 448 448 Chardinia
#
# 448 448 Siebera
#
# 449 449 Carlina
#
# 450 450 Carlina
#
# 450 450 Garlina
#
# 450 450 Carlina hispanica
#
# 450 450 Carlina kurdica
#
# 451 451 Carlina
#
# 451 451 Atractylis carduus
#
# 452 452 Atractylis cancellata
#
# 452 452 Atractylis
#
# 452 452 Staehelina
#
# 453 453 Arctium
#
# 454 454 Cousinia
#
# 455 455 Gousinia ramosissima
#
# 455 455 Cousinia stenocephala
#
# 455 455 Cousinia postiana
#
# 456 456 Gousinia
#
# 456 456 Cousinia libanotica
#
# 456 456 Cousinia
#
# 457 457 Cousinia
#
# 457 457 Cousinia
#
# 458 458 Carduus nutans
#
# 458 458 Garduus
#
# 458 458 Garduus pycnocephalus
#
# 459 459 Carduus argentatus
#
# 460 460 Cirsium
#
# 460 460 Cirsium phyllocephalum
#
# 461 461 Cirsium amani
#
# 461 461 Cirsium vulgare
#
# 462 462 Cirsium
#
# 462 462 Cirsium
#
# 462 462 Cirsium libanoticum
#
# 463 463 Picnomon acarna
#
# 463 463 Notobasis syriaca
#
# 464 464 Ptilostemon chamaepeuce
#
# 464 464 Ptilostemon diacantha
#
# 465 465 Ptilostemon x Pabotii
#
# 465 465 Tyrimnus leucographus
#
# 466 466 Silybum marianum
#
# 466 466 Cynara syriaca
#
# 467 467 Onopordum carduiforme
#
# 468 468 Onopordum cynarocephalum
#
# 468 468 Onopordum
#
# 469 469 Onopordum illyricum
#
# 469 469 Onopordum
#
# 469 469 Onopordum syriacum
#
# 470 470 Onopordum
#
# 470 470 Myopordon thiebauti
#
# 470 470 Myopordon pulchellum
#
# 471 471 Jurinea staehelinae
#
# 471 471 Jurinea mesopotamica
#
# 472 472 Zoegea leptaurea
#
# 472 472 Zoegea purpurea
#
# 473 473 Crupina crupinastrum
#
# 474 474 Serratula cerinthifolia
#
# 474 474 Serratula mouterdei
#
# 475 475 Serratula
#
# 479 479 Centaurea
#
# 479 479 Centaurea
#
# 480 480 Centaurea reducta
#
# 480 480 Centaurea dumulosa
#
# 480 480 Centaurea damascena
#
# 481 481 Centaurea
#
# 481 481 virgata
#
# 481 481 Centaurea ammocyanus
#
# 482 482 Centaurea laxa
#
# 482 482 Centaurea blancheana
#
# 483 483 Centaurea cassia
#
# 483 483 Centaurea
#
# 483 483 Centaurea longispina
#
# 484 484 Centaurea
#
# 484 484 Centaurea
#
# 485 485 Centaurea
#
# 485 485 Centaurea speciosa
#
# 485 485 Centaurea postii
#
# 486 486 Centaurea
#
# 486 486 Centaurea regia
#
# 487 487 Centaurea
#
# 487 487 onopordifolia
#
# 487 487 Centaurea
#
# 488 488 Centaurea spicata
#
# 488 488 Centaurea simulans
#
# 488 488 Centaurea babylonica
#
# 489 489 Centaurea
#
# 489 489 Centaurea rigida
#
# 490 490 Centaurea ptosimopappa
#
# 491 491 Centaurea solstitialis
#
# 491 491 Centaurea sinaica
#
# 491 491 Centaurea
#
# 492 492 Centaurea mesopotamica
#
# 492 492 Centaurea verutum
#
# 493 493 Centaurea calcitrapa
#
# 493 493 Centaurea iberica
#
# 494 494 Centaurea pallescens
#
# 495 495 Centaurea
#
# 495 495 Centaurea procurrens
#
# 495 495 Centaurea bruguieriana
#
# 496 496 Centaurea eryngioides
#
# 496 496 Centaurea mouterdei
#
# 497 497 Centaurea
#
# 497 497 Centaurea carduiformis
#
# 498 498 Centaurea trachonitica
#
# 498 498 Centaurea
#
# 498 498 Centaurea heterocarpa
#
# 499 499 Centaurea triumfettii
#
# 499 499 Centaurea
#
# 500 500 Centaurea cyanus
#
# 500 500 Cnicus benedictus
#
# 501 501 Carthamus
#
# 501 501 Carthamus persicus
#
# 502 502 Carthamus
#
# 503 503 Carthamus
#
# 503 503 Carthamus
#
# 504 504 Carthamus dentatus
#
# 504 504 Carthamus glaucus
#
# 505 505 Carduncellus
#
# 505 505 Scolymus maculatus
#
# 505 505 Scolymus hispanicus
#
# 506 506 Catananche lutea
#
# 506 506 Cichorium intybus
#
# 506 506 Cichorium pumilum
#
# 507 507 Hyoseris scabra
#
# 508 508 Hedypnois rhagadioloides
#
# 508 508 Hedypnois
#
# 509 509 Lapsana
#
# 509 509 Koelpinia linearis
#
# 510 510 Rhagadiolus
#
# 510 510 Rhagadiolus edulis
#
# 510 510 Garhadiolus hedypnois
#
# 511 511 Garhadiolus
#
# 511 511 Garhadiolus papposus
#
# 512 512 Tolpis barbata
#
# 512 512 Tolpis virgata
#
# 513 513 Leontodon tuberosus
#
# 513 513 Leontodon laciniatus
#
# 513 513 Leontodon
#
# 514 514 Leontodon
#
# 514 514 Urospermum picroides
#
# 515 515 Picris hieracioides
#
# 515 515 Picris strigosa
#
# 516 516 Picris altissima
#
# 516 516 Picris kotschyi
#
# 516 516 Picris longirostris
#
# 517 517 Picris
#
# 517 517 Picris
#
# 518 518 Tragopogon hybridum
#
# 518 518 Tragopogon longirostris
#
# 519 519 Tragopogon
#
# 520 520 Tragopogon pterocarpus
#
# 521 521 Scorzonera cana
#
# 522 522 Scorzonera mollis
#
# 523 523 Scorzonera
#
# 523 523 Scorzonera libanotica
#
# 524 524 Scorzonera papposa
#
# 524 524 Scorzonera
#
# 525 525 Scorzonera mackmeliana
#
# 525 525 Scorzonera rigida
#
# 525 525 Scorzonera judaica
#
# 526 526 Scorzonera nervosa
#
# 526 526 Scorzonera
#
# 527 527 Hypochoeris
#
# 527 527 Seriola
#
# 529 529 Taraxacum bessarabicum
#
# 529 529 Taraxacum assemanii
#
# 529 529 Taraxacum
#
# 530 530 Taraxacum serotinum
#
# 530 530 Taraxacum brevirostre
#
# 530 530 Taraxacum syriacum
#
# 530 530 Taraxacum montanum
#
# 530 530 Taraxacum bithynicum
#
# 532 532 Taraxacum
#
# 532 532 Taraxacum officinale
#
# 532 532 Taraxacum
#
# 532 532 Taraxacum laevigatum
#
# 533 533 Ghondrilla
#
# 533 533 Sonchus
#
# 534 534 Sonchus
#
# 534 534 Sonchus tenerrimus
#
# 534 534 Sonchus
#
# 535 535 Lactuca serriola
#
# 535 535 Lactuca aculeata
#
# 535 535 Lactuca saligna
#
# 536 536 Lactuca
#
# 536 536 Scariola viminea
#
# 537 537 Scariola orientalis
#
# 537 537 Scariola triquetra
#
# 538 538 Steptorhamphus
#
# 538 538 Cicerbita
#
# 539 539 Cephalorrhynchus tuberosus
#
# 540 540 Reichardia
#
# 540 540 Reichardia intermedia
#
# 540 540 Reichardia picroides
#
# 540 540 Reichardia glauca
#
# 541 541 Launaea
#
# 541 541 Launaea nudicaulis
#
# 542 542 Aetheorhiza
#
# 543 543 Crépis
#
# 544 544 Crépis
#
# 544 544 Crépis
#
# 545 545 Crépis
#
# 546 546 Crépis pulchra
#
# 546 546 Crépis
#
# 546 546 Crépis pterothecoides
#
# 547 547 Crépis
#
# 547 547 Crépis kotschyana
#
# 548 548 Crépis
#
# 548 548 Crépis
#
# 548 548 Crépis
#
# 549 549 Crépis
#
# 549 549 Crépis
#
# 549 549 Crépis
#
# 550 550 Andryala integrifolia
#
# 551 551 Hieracium bauhinii
#
# 551 551 n.
#
# 552 552 Hieracium
#
# 552 552 Hieracium

# %%
from tqdm import tqdm
import math
# marked_fname = "marked-pages-book-1-sample.pdf"
marked_fname = "marked-pages-book-3.pdf"
#doc = fitz.open(fname)  # open document
doc = fitz.open(marked_fname)  # open document
print(len(results))

from fitz.utils import getColorList
cl = getColorList()
from fitz.utils import getColor

pink = getColor("lightpink")
green = getColor("aquamarine")
blue = getColor("lightskyblue")
gray = getColor("whitesmoke")
yellowish = getColor("antiquewhite")
fills= [pink, green, blue, gray, yellowish]

fc = {"L.":pink, "S.":blue, "Aire":green, "Description":gray, "Extra":yellowish}
for it, name in enumerate(tqdm(results.keys())):
    item = results[name]
    #print(item)
    #print(item["Description"])
    book_page = item["book_page"]
    pdf_page = item["pdf_page"]
    print([it, name, book_page, pdf_page])
    page = doc[book_page]
    for k in filter(lambda x: not re.search(r"_page|_rect", x), item.keys()):
        rects = item[k + "_rects"]
        for r in rects:
            #print(k, r)
            
            if not page.rect.intersects(r):
                print(["ERROR: ", k, r])
            else:
                # #annot = page.add_highlight_annot(fitz.Rect(r))
                # annot_rect = page.add_rect_annot(fitz.Rect(r))
                # #annot_rect.set_colors(stroke=(0,1,0))
                # annot_rect.set_border(width=1, dashes=[1,2])
                # annot_rect.update()

                if k in ["L.", "S.", "Aire", "Description", "Extra"]:
                    #print(["HIGHL: ", fc[k], k, r])
                    annot = page.add_highlight_annot(fitz.Rect(r))
                    annot.set_colors(stroke=fc[k])
                    annot.update()
                    #annot_rect = page.add_rect_annot(fitz.Rect(r))
                    #annot_rect.set_colors(stroke=green)
                    #annot_rect.set_border() #(width=1, dashes=[1,2])
                    #annot_rect.update()
                    #annot_rect.update(fill_color=red)


# doc.delete_pages(end_page, doc.page_count - 1)
# doc.delete_pages(0, start_page - 1)
doc_fname = "results-" + doc.name
doc.save(doc_fname, garbage=4, clean=True)
print(doc_fname)
# !open -a Preview results-marked-pages-book-1-sample.pdf
#!open -a Preview results-marked-pages-book-1.pdf
# Out:
# 896
#   0%|          | 0/896 [00:00<?, ?it/s]
# [0, 'JL', 6, 6]
# [1, 'Rhododendron', 7, 7]
# [2, 'Arbutus unedo', 8, 8]
# [3, 'Arbutus andrachne', 8, 8]
# [4, 'Erica', 9, 9]
# [5, 'Pentapera sicula', 9, 9]
# [6, 'Samolus', 10, 10]
# [7, 'Ânagallis', 10, 10]
# [8, 'Lysimachia', 11, 11]
# [9, 'Asterolinon', 11, 11]
# [10, 'Cyclamen', 12, 12]
# [11, 'Cyclamen libanoticum', 12, 12]
# [12, 'Cyclamen persicum', 13, 13]
# [13, 'Androsace villosa', 14, 14]
# [14, 'Androsace', 14, 14]
# [15, 'Primula vulgaris', 15, 15]
# [16, 'Acantholimon', 18, 18]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [17, 'Acantholimon acerosum', 17, 17]
# [18, 'Acantholimon libanoticum', 18, 18]
# [19, 'Acantholimon ulicinum', 19, 19]
# [20, 'Goniolimon collinum', 20, 20]
# [21, 'Limonium', 22, 22]
# [22, 'Limonium angustifolium', 21, 21]
# [23, 'Limonium sieberi', 21, 21]
# [24, 'Limonium graecum', 22, 22]
# [25, 'Limoniumglobuliferum', 23, 23]
# [26, 'Psylliostachys spicatus', 23, 23]
# [27, 'Armeria', 23, 23]
# [28, 'Plumbago europaea', 24, 24]
# [29, 'Styrax', 25, 25]
# [30, 'Olea europaea', 25, 25]
# [31, 'Phillyrea', 26, 26]
# [32, 'Fontanesia', 26, 26]
# [33, 'Fraxinus ornus', 27, 27]
# [34, 'Fraxinus excelsior', 27, 27]
# [35, 'Fraxinus syriaca', 27, 27]
# [36, 'Jasminum fruticans', 28, 28]
# [37, 'Vinca', 29, 29]
# [38, 'Vinca libanotica', 29, 29]
# [39, 'Trachomitum venetum', 29, 29]
# [40, 'Nerium oleander', 30, 30]
# [41, 'Blackstonia perfoliata', 31, 31]
# [42, 'Blackstonia acuminata', 31, 31]
# [43, 'Cicendia filifortnis', 31, 31]
# [44, 'Centaurium pulchellum', 32, 32]
# [45, 'Centaurium', 32, 32]
# [46, 'Centaurium erythraea', 33, 33]
# [47, 'Centaurium maritimum', 33, 33]
# [48, 'Centaurium spicatum', 33, 33]
# [49, 'Gentiana', 34, 34]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [50, 'Vincetoxicum', 35, 35]
# [51, 'Vincetoxicum dionysiense', 35, 35]
# [52, 'Cynanchum acutum', 36, 36]
# [53, 'Cionura erecta', 36, 36]
# [54, 'Periploca graeca', 37, 37]
# [55, 'Periploca', 38, 38]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [56, 'Convolvulus hamrinensis', 40, 40]
# [57, 'Convolvulus dorycnium', 40, 40]
# [58, 'Convolvulus cantabrica', 41, 41]
# [59, 'Convolvulus', 47, 47]
# [60, 'Convolvulus libanoticus', 41, 41]
# [61, 'Convolvulus secundus', 42, 42]
# [62, 'Convolvulus reticulatus', 42, 42]
# [63, 'Convolvulus pilosellifolius', 42, 42]
# [64, 'Convolvulus galaticus', 43, 43]
# [65, 'Convolvulus betonicifolius', 43, 43]
# [66, 'Convolvulus cassius', 43, 43]
# [67, 'Convolvulus scammonia', 45, 45]
# [68, 'Convolvulus arvensis', 45, 45]
# [69, 'Convolvulus coelesyriacus', 46, 46]
# [70, 'Convolvulus siculus', 46, 46]
# [71, 'Convolvulus pentapetaloides', 46, 46]
# [72, 'Convolvulus tricolor', 47, 47]
# [73, 'Calystegia sepium', 47, 47]
# [74, 'Calystegia silvatica', 48, 48]
# [75, 'Ipomoea stolonifera', 48, 48]
# [76, 'Ipomoea sagittata', 48, 48]
# [77, 'Ipomoea', 49, 49]
# [78, 'Gressa eretica', 49, 49]
# [79, 'Cuscuta', 55, 55]
# [80, 'Guscuta planiflora', 51, 51]
#   9%|▉         | 82/896 [00:00<00:01, 809.29it/s]
# [81, 'Cuscuta approximata', 51, 51]
# [82, 'Cuscuta balansae', 52, 52]
# [83, 'Cuscuta brevistyla', 53, 53]
# [84, 'Cuscuta europaea', 53, 53]
# [85, 'Cuscuta babylonica', 54, 54]
# [86, 'Cuscuta pedicellata', 54, 54]
# [87, 'Cuscuta campestris', 54, 54]
# [88, 'Heliotropium supinum', 56, 56]
# [89, 'Heliotropium myosotoides', 56, 56]
# [90, 'Heliotropium lasiocarpum', 57, 57]
# [91, 'Heliotropium dolosum', 57, 57]
# [92, 'Heliotropium', 59, 59]
# [93, 'Heliotropium bovei', 58, 58]
# [94, 'Heliotropium ramosissimum', 59, 59]
# [95, 'Asperugo procumbens', 60, 60]
# [96, 'Caccinia', 60, 60]
# [97, 'Lappula spinocarpos', 61, 61]
# [98, 'Lappula barbata', 61, 61]
# [99, 'Lappula sinaica', 62, 62]
# [100, 'Lappula', 62, 62]
# [101, 'Heterocaryum szovitsianum', 62, 62]
# [102, 'Heterocaryum subsessile', 63, 63]
# [103, 'Rindera', 63, 63]
# [104, 'Paracaryum rugulosum', 64, 64]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [105, 'Mattiastrum lithospermifolium', 64, 64]
# [106, 'Mattiastrum lamprocarpum', 64, 64]
# [107, 'Rochelia cancellata', 65, 65]
# [108, 'Rochelia disperma', 65, 65]
# [109, 'Rochelia', 66, 66]
# [110, 'Solenanthus stamineus', 66, 66]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [111, 'Solenanthus circinnatus', 66, 66]
# [112, 'Moltkia coerulea', 67, 67]
# [113, 'Moltkia longiflora', 67, 67]
# [114, 'Cynoglossum nebrodense', 68, 68]
# [115, 'Cynoglossum creticum', 68, 68]
# [116, 'Lithospermum', 70, 70]
# [117, 'Lithospermum arvense L.', 69, 69]
# [118, 'Lithospermum sibthorpianum', 70, 70]
# [119, 'Lithospermum incrassatum', 70, 70]
# [120, 'Lithodora', 71, 71]
# [121, 'Arnebia decumbens', 71, 71]
# [122, 'Ârnebia tubata', 72, 72]
# [123, 'Arnebia', 72, 72]
# [124, 'Cerinthe', 73, 73]
# [125, 'Cerinthe major', 73, 73]
# [126, 'Cerinthe palaestina', 73, 73]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [127, 'Onosma', 78, 78]
# [128, 'Onosma frutescents', 76, 76]
# [129, 'Onosma cassia', 76, 76]
# [130, 'Onosma mollis', 77, 77]
# [131, 'Onosma cinerea', 77, 77]
# [132, 'Onosma roussaei', 79, 79]
# [133, 'Onosma aucherana', 79, 79]
# [134, 'Onosma gigantea', 79, 79]
# [135, 'Onosma auriculata', 80, 80]
# [136, 'Echium glomeratum', 81, 81]
# [137, 'Echium', 83, 83]
# [138, 'Echium pabotii', 81, 81]
# [139, 'Echium angustifolium', 82, 82]
# [140, 'Echium plantagineum', 82, 82]
# [141, 'Echium judaeum', 82, 82]
# [142, 'Anchusa', 86, 86]
# [143, 'Anchusa azurea', 84, 84]
# [144, 'Anchusa barrelieri', 85, 85]
# [145, 'Anchusa tiberiadis', 86, 86]
# [146, 'Hormuzakia aggregata', 87, 87]
# [147, 'Gastrocotyle', 87, 87]
# [148, 'Phyllocara', 88, 88]
# [149, 'Brunnera', 88, 88]
# [150, 'Nonea obtusifolia', 89, 89]
# [151, 'Nonea palmyrensis', 89, 89]
# [152, 'Nonea caspica', 90, 90]
# [153, 'Nonea ventricosa', 90, 90]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [154, 'Myosotis caespitosa', 91, 91]
# [155, 'Myosotis sicula', 92, 92]
# [156, 'Myosotis', 93, 93]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [157, 'Myosotis ramosissima', 92, 92]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [158, 'Myosotis stricta', 92, 92]
# [159, 'Myosotis macrosiphon', 93, 93]
# [160, 'Alkanna orientalis', 94, 94]
# [161, 'Alkanna', 97, 97]
# [162, 'Alkanna hirsutissima', 96, 96]
# [163, 'Alkanna leiocarpa', 97, 97]
# [164, 'Alkanna tinctoria', 97, 97]
# [165, 'Alkanna strigosa', 98, 98]
# [166, 'Symphytum', 99, 99]
# [167, 'Symphytum palaestinum', 99, 99]
#  19%|█▉        | 168/896 [00:00<00:00, 838.67it/s]
# [168, 'Borago', 99, 99]
# [169, 'Cordia', 100, 100]
# [170, 'Verbena', 100, 100]
# [171, 'Verbena supina', 101, 101]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [172, 'Vitex', 102, 102]
# [173, 'Ajuga orientalis', 103, 103]
# [174, 'Ajuga laevigata', 103, 103]
# [175, 'Ajuga chia', 104, 104]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [176, 'Ajuga tridactylites', 104, 104]
# [177, 'Ajuga', 106, 106]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [178, 'Teucrium creticum', 108, 108]
# [179, 'Teucrium multicaule', 108, 108]
# [180, 'Teucrium pruinosum', 108, 108]
# [181, 'Teucrium', 115, 115]
# [182, 'Teucrium orientale', 109, 109]
# [183, 'Teucrium procerum', 109, 109]
# [184, 'Teucrium oliverianum', 110, 110]
# [185, 'Teucrium parviflorum', 110, 110]
# [186, 'Teucrium scordioides', 111, 111]
# [187, 'Teucrium spinosum', 111, 111]
# [188, 'Teucrium montbretii', 112, 112]
# [189, 'Teucrium haradjianii', 112, 112]
# [190, 'Teucrium coniortodes', 114, 114]
# [191, 'Teucriuflft antilibanoticum', 116, 116]
# [192, 'Prasium', 116, 116]
# [193, 'Scutellaria orientalis', 117, 117]
# [194, 'Scutellaria cretacea', 117, 117]
# [195, 'Scutellaria', 119, 119]
# [196, 'Scutellaria diffusa', 118, 118]
# [197, 'Scutellaria brevibracteata', 118, 118]
# [198, 'Lavandula', 120, 120]
# [199, 'Marrubium hierapolitanum', 121, 121]
# [200, 'Marrubium libanoticum', 121, 121]
# [201, 'Marrubium cuneatum', 121, 121]
# [202, 'Marrubium radiatum', 122, 122]
# [203, 'Marrubium vulgare', 122, 122]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [204, 'Nepeta cataria', 124, 124]
# [205, 'Nepeta leucostegia', 124, 124]
# [206, 'Nepeta italica', 124, 124]
# [207, 'Nepeta curviflora', 125, 125]
# [208, 'Nepeta x', 125, 125]
# [209, 'Nepeta cilicica', 126, 126]
# [210, 'Nepeta glomerata', 126, 126]
# [211, 'Nepeta pabotii', 126, 126]
# [212, 'Nepeta', 128, 128]
# [213, 'Nepeta bithynica', 127, 127]
# [214, 'Nepeta trachonitica', 127, 127]
# [215, 'Nepeta cryptantha', 128, 128]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [216, 'Sideritis', 132, 132]
# [217, 'Sideritis montana', 129, 129]
# [218, 'Sideritis balansae', 130, 130]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [219, 'Sideritis libanotica', 131, 131]
# [220, 'Sideritis nusairiensis', 131, 131]
# [221, 'Sideritis perfoliata', 131, 131]
# [222, 'Lallemantia royleana', 132, 132]
# [223, 'Lallemantia', 133, 133]
# [224, 'Thuspeinanta', 133, 133]
# [225, 'Prunella vulgaris', 134, 134]
#  29%|██▉       | 261/896 [00:00<00:00, 879.55it/s]
# [226, 'Prunella orientalis', 134, 134]
# [227, 'Prunella laciniata', 135, 135]
# [228, 'Eremostachys', 135, 135]
# [229, 'Eremostachys macrophylla', 136, 136]
# [230, 'Phlomis', 141, 141]
# [231, 'Phlomis kurdica', 138, 138]
# [232, 'Phlomis brachyodon', 138, 138]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [233, 'Phlomis chrysophylla', 140, 140]
# [234, 'Phlomis viscosa', 140, 140]
# [235, 'Phlomis bailanica', 140, 140]
# [236, 'Phlomis rigida', 141, 141]
# [237, 'Phlomis pungens', 141, 141]
# [238, 'Lamium', 146, 146]
# [239, 'Lamium veronicifolium', 143, 143]
# [240, 'Lamium aleppicum', 144, 144]
# [241, 'Lamium ehrenbergii', 144, 144]
# [242, 'Lamium adoxifolium', 145, 145]
# [243, 'Lamium truncatum', 145, 145]
# [244, 'Lamium moschatum', 145, 145]
# [245, 'Wiedemannia', 146, 146]
# [246, 'Moluccella laevis', 147, 147]
# [247, 'Moluccella spinosa', 147, 147]
# [248, 'Ballota nigra', 148, 148]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [249, 'Ballota damascena', 148, 148]
# [250, 'Ballota undulata', 149, 149]
# [251, 'Ballota antilibanotica', 149, 149]
# [252, 'Ballota saxatilis', 149, 149]
# [253, 'Ballota semaanica', 150, 150]
# [254, 'Stachys libanotica', 152, 152]
# [255, 'Stachys ehrenbergii', 152, 152]
# [256, 'Stachys eretica', 153, 153]
# [257, 'Stachys', 160, 160]
# [258, 'Stachys dictyoneura', 154, 154]
# [259, 'Stachys viticina', 154, 154]
# [260, 'Stachys longispicata', 154, 154]
# [261, 'Stachys hydrophila', 155, 155]
# [262, 'Stachys iberica', 155, 155]
# [263, 'Stachys distans', 155, 155]
# [264, 'Stachys nivea', 156, 156]
# [265, 'Stachys paneiana', 156, 156]
# [266, 'Stachys palaestina', 157, 157]
# [267, 'Stachys petrokosmos', 157, 157]
# [268, 'Stachys annua', 158, 158]
# [269, 'Stachys obscura', 159, 159]
# [270, 'Stachys arvensis', 159, 159]
# [271, 'Stachys satureioides', 160, 160]
# [272, 'Stachys neurocalycina', 160, 160]
# [273, 'Rosmarinus officinalis', 160, 160]
# [274, 'Salvia tomentosa', 164, 164]
# [275, 'Salvia', 169, 169]
# [276, 'Salvia fruticosa', 165, 165]
# [277, 'Salvia spiraeifolia', 165, 165]
# [278, 'Salvia pinnata', 166, 166]
# [279, 'Salvia bracteata', 166, 166]
# [280, 'Salvia pinardii', 167, 167]
# [281, 'Salvia nazalena', 168, 168]
# [282, 'Salvia syriaca', 168, 168]
# [283, 'Salvia montbretii', 168, 168]
# [284, 'Salvia spinosa', 169, 169]
# [285, 'Salvia palaestina', 169, 169]
# [286, 'Salvia peyronii', 170, 170]
# [287, 'Salvia dominica', 170, 170]
# [288, 'Salvia sclarea', 171, 171]
# [289, 'Salvia ceratophylla', 171, 171]
# [290, 'Salvia drusica', 171, 171]
# [291, 'Salvia microstegia', 172, 172]
# [292, 'Salvia cassia', 172, 172]
# [293, 'Salvia indica', 173, 173]
# [294, 'Salvia hierosolymitana', 173, 173]
# [295, 'Salvia virgata', 174, 174]
# [296, 'Salvia viscosa', 174, 174]
# [297, 'Salvia verbenaca', 174, 174]
# [298, 'Salvia lanigera', 175, 175]
# [299, 'Salvia viridis', 175, 175]
# [300, 'Salvia judaica', 176, 176]
# [301, 'Salvia russellii', 177, 177]
# [302, 'Melissa', 178, 178]
# [303, 'Melissa inodora', 178, 178]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [304, 'Satureia', 179, 179]
# [305, 'Micromeria Juliana', 181, 181]
# [306, 'Micromeria amana', 181, 181]
# [307, 'Micromeria graeca', 182, 182]
# [308, 'Micromeria', 183, 183]
# [309, 'Micromeria serpyllifolia', 183, 183]
# [310, 'Micromeria barbata', 183, 183]
# [311, 'Calamintha betulifolia', 184, 184]
# [312, 'Calamintha nepeta', 185, 185]
# [313, 'Calamintha incana', 185, 185]
# [314, 'Calamintha vulgaris', 185, 185]
# [315, 'Calamintha origanifolia', 186, 186]
# [316, 'Calamintha rotundifolia', 186, 186]
# [317, 'Ziziphora', 189, 189]
# [318, 'Ziziphora capitata', 187, 187]
# [319, 'Ziziphora taurica', 189, 189]
# [320, 'Origanum bargyli', 190, 190]
# [321, 'Origanum', 193, 193]
# [322, 'Origanum libanoticum', 191, 191]
# [323, 'Origanum ehrenbergii', 194, 194]
# [324, 'Origanum syriacum', 194, 194]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [325, 'Thymus sipyleus', 195, 195]
# [326, 'Thymus kotschyanus', 195, 195]
# [327, 'Thymus hirsutus', 196, 196]
# [328, 'Thymus', 196, 196]
# [329, 'Thymus syriacus', 196, 196]
# [330, 'Thymus cilicicus', 197, 197]
# [331, 'Thymus alfredae', 197, 197]
# [332, 'Coridothymus', 197, 197]
# [333, 'Thymbra spicata', 197, 197]
# [334, 'Lycopus europaeus', 198, 198]
# [335, 'Mentha pulegium', 199, 199]
# [336, 'Mentha aquatica', 199, 199]
# [337, 'Mentha longifolia', 199, 199]
# [338, 'Mentha microphylla', 200, 200]
# [339, 'Nicandra', 201, 201]
# [340, 'Atropa belladonna', 201, 201]
# [341, 'Mandragora autumnalis', 202, 202]
# [342, 'Lycium', 203, 203]
# [343, 'Lycium barbarum', 203, 203]
# [344, 'Solanum nigrum', 204, 204]
# [345, 'Solanum luteum', 205, 205]
# [346, 'Solanum dulcamara', 205, 205]
# [347, 'Withania somnifera', 205, 205]
# [348, 'Datura', 206, 206]
#  39%|███▉      | 349/896 [00:00<00:00, 879.02it/s]
# [349, 'Datura xnetel', 206, 206]
# [350, 'Nicotiana glauca', 206, 206]
# [351, 'Hyoscyamus muticus', 207, 207]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [352, 'Hyoscyamus desertorum', 207, 207]
# [353, 'Hyoscyamus pusillus', 208, 208]
# [354, 'Hyoscyamus niger', 208, 208]
# [355, 'Hyoscyamus reticulatus', 208, 208]
# [356, 'Hyoscyamus', 209, 209]
# [357, 'Hyoscyamus aureus', 209, 209]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [358, 'Verbascum', 228, 228]
# [359, 'Verbascum agrimoniifolium', 213, 213]
# [360, 'Verbascum antilibanoticum', 214, 214]
# [361, 'Verbascum levanticum', 214, 214]
# [362, 'Verbascum orientale', 214, 214]
# [363, 'Verbascum blancheanum', 215, 215]
# [364, 'Verbascum tiberiadis', 216, 216]
# [365, 'Verbascum alepense', 228, 228]
# [366, 'Verbascum eremobium', 218, 218]
# [367, 'Verbascum cedreti', 219, 219]
# [368, 'Verbascum tropidocarpum', 220, 220]
# [369, 'Verbascum sinuatum', 221, 221]
# [370, 'Verbascum caesareum', 222, 222]
# [371, 'Verbascum galilaeum', 228, 228]
# [372, 'Verbascum antari', 224, 224]
# [373, 'Verbascum libanoticum', 224, 224]
# [374, 'Verbascum aliciae', 228, 228]
# [375, 'Verbascum geminiflorum', 225, 225]
# [376, 'Verbascum glomeratum', 226, 226]
# [377, 'Verbascum gaillardotii', 228, 228]
# [378, 'Verbascum leptostachyum', 228, 228]
# [379, 'Verbascum sinuatum L. X tripolitanum', 228, 228]
# [380, 'Antirrhinum orontium', 229, 229]
# [381, 'Antirrhinum majus', 229, 229]
# [382, 'Antirrhinum tortuosum', 229, 229]
# [383, 'Anarrhinum', 230, 230]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [384, 'Kickxia commutata', 231, 231]
# [385, 'Kickxia elatine', 231, 231]
# [386, 'Kickxia', 233, 233]
# [387, 'Kickxia lanigera', 232, 232]
# [388, 'Kickxia gombaultii', 233, 233]
# [389, 'Linaria cymbalaria', 235, 235]
# [390, 'Linaria longipes', 235, 235]
# [391, 'Linaria aucheri', 235, 235]
# [392, 'Linaria', 239, 239]
# [393, 'Linaria arvensis', 236, 236]
# [394, 'Linaria genistifolia', 237, 237]
# [395, 'linariachalepensis', 237, 237]
# [396, 'Linaria tenuis', 238, 238]
# [397, 'Linaria minor', 239, 239]
# [398, 'Linaria persica', 239, 239]
# [399, 'Mosheovia', 240, 240]
# [400, 'Scrophularia', 247, 247]
# [401, 'Scrophularia scariosa', 243, 243]
# [402, 'Scrophularia hierochuntina', 243, 243]
# [403, 'Scrophularia tagetifolia', 244, 244]
# [404, 'Scrophularia lucida', 244, 244]
# [405, 'Scrophularia deserti', 245, 245]
# [406, 'Scrophularia peyronii', 245, 245]
# [407, 'Scrophularia xylorrhiza', 246, 246]
# [408, 'Scrophularia libanotica', 246, 246]
# [409, 'Scrophularia xanthoglossa', 247, 247]
# [410, 'Scrophularia decipiens', 247, 247]
# [411, 'Veronica caespitosa', 251, 251]
# [412, 'Veronica bombycina', 252, 252]
# [413, 'Veronica', 269, 269]
# [414, 'Veronica leiocarpa', 253, 253]
# [415, 'Veronica orientalis', 255, 255]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [416, 'Veronica anagalloides', 259, 259]
# [417, 'Veronica beccabunga', 260, 260]
# [418, 'Veronica arvensis', 261, 261]
# [419, 'Veronica viscosa', 261, 261]
# [420, 'Veronica pusilla', 262, 262]
# [421, 'Veronica hispidula', 262, 262]
# [422, 'Veronica reuterana', 262, 262]
# [423, 'Veronica syriaca', 263, 263]
# [424, 'Veronica triphyllos', 264, 264]
# [425, 'Veronica persica', 265, 265]
# [426, 'Veronica biloba', 267, 267]
# [427, 'Veronica hederifolia', 267, 267]
# [428, 'Veronica triloba', 268, 268]
#  49%|████▉     | 437/896 [00:00<00:00, 846.78it/s]
# [429, 'Digitalis ferruginea', 271, 271]
# [430, 'Siphonostegia syriaca', 272, 272]
# [431, 'Bungea', 272, 272]
# [432, 'Parentucellia latifolia', 272, 272]
# [433, "Parentucellia viscosa'", 273, 273]
# [434, 'Bellardia', 273, 273]
# [435, 'Odontites aucheri', 274, 274]
# [436, 'Odontites lutea', 274, 274]
# [437, 'Pedicularis', 275, 275]
# [438, 'Globularia', 275, 275]
# [439, 'Utricularia australia', 276, 276]
# [440, 'Sesamum indicum', 276, 276]
# [441, 'Acanthus mollis', 277, 277]
# [442, 'Acanthus dioscoridis', 277, 277]
# [443, 'Acanthus syriacus', 278, 278]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [444, 'Cistanche phelipaea', 279, 279]
# [445, 'Cistanche tubulosa', 279, 279]
# [446, 'Cistanche salsa', 280, 280]
# [447, 'Orobanche ramosa', 281, 281]
# [448, 'Orobanche mutelii', 282, 282]
# [449, 'Orobanche nana', 282, 282]
# [450, 'Orobanche lavandulacea', 282, 282]
# [451, 'Orobanche', 287, 287]
# [452, 'Orobanche astragali', 283, 283]
# [453, 'Orobanche libanotica', 284, 284]
# [454, 'Orobanche serratocalyx', 285, 285]
# [455, 'Orobanche major', 286, 286]
# [456, 'Orobanche crenata', 286, 286]
# [457, 'Orobanche pubescens', 286, 286]
# [458, 'Orobanche grisebachii', 287, 287]
# [459, 'Orobanche cernua', 288, 288]
# [460, 'Orobanche camptolepis', 288, 288]
# [461, 'Plantago major', 290, 290]
# [462, 'Plantago lanceolate', 290, 290]
# [463, 'Plantago', 296, 296]
# [464, 'Plantago ovata', 292, 292]
# [465, 'Plantago loeflingii', 293, 293]
# [466, 'Plantago notata', 293, 293]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [467, 'Plantago crassifolia', 294, 294]
# [468, 'Plantago maritima', 294, 294]
# [469, 'Plantago albicans', 294, 294]
# [470, 'Plantago coronopus', 295, 295]
# [471, 'Plantago afra', 296, 296]
# [472, 'Oldenlandia', 297, 297]
# [473, 'Putoria calabrica', 298, 298]
# [474, 'Rubia aucheri', 298, 298]
# [475, 'Rubia tinctorum', 299, 299]
# [476, 'Rubia tenuifolia', 299, 299]
# [477, 'Sherardia', 300, 300]
# [478, 'Crucianella latifolia', 301, 301]
# [479, 'Crucianella', 303, 303]
# [480, 'Crucianella imbricata', 302, 302]
# [481, 'Crucianella exasperata', 302, 302]
# [482, 'Crucianella membranacea', 303, 303]
# [483, 'Crucianella ciliata', 303, 303]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [484, 'Asperula glomerata', 304, 304]
# [485, 'Asperula arvensis', 305, 305]
# [486, 'Asperula orientali»', 305, 305]
# [487, 'Asperula', 307, 307]
# [488, 'Asperula stricta', 306, 306]
# [489, 'Asperula glareosa', 306, 306]
# [490, 'Asperula libanotica', 306, 306]
# [491, 'Asperula bargyli', 307, 307]
# [492, 'Asperula rivalis', 307, 307]
# [493, 'Galium', 320, 320]
# [494, 'Galium pestalozzae', 310, 310]
# [495, 'Galium prusense', 311, 311]
# [496, 'Galiuxn', 312, 312]
# [497, "'Galium bassitense", 312, 312]
# [498, 'Galium verum', 312, 312]
# [499, 'Galium thiebautii', 314, 314]
# [500, 'Galium thiebautii X', 314, 314]
# [501, 'Galiutn verrucosmn', 315, 315]
# [502, 'Galium tricornutum', 315, 315]
# [503, 'Galium spurium', 315, 315]
# [504, 'Galium pisiferum', 316, 316]
# [505, 'Galium peplidifolium', 316, 316]
# [506, 'Galium tenuissimum', 317, 317]
# [507, 'Galium hierosolymitanum', 318, 318]
# [508, 'Galium setaceum', 319, 319]
# [509, 'Galium bracteatum', 320, 320]
# [510, 'Galium murale', 320, 320]
# [511, 'Galium verticillatam', 321, 321]
# [512, 'Cruciata coronata', 321, 321]
# [513, 'Cruciata', 322, 322]
# [514, 'Cruciata articulata', 322, 322]
#  59%|█████▊    | 525/896 [00:00<00:00, 857.68it/s]
# [515, 'Valantia muralis', 323, 323]
# [516, 'Valantia hispida', 323, 323]
# [517, 'Mericarpaea vaillantioides', 323, 323]
# [518, 'Callipeltis factorovskyi', 324, 324]
# [519, 'Callipeltis cucullaris', 324, 324]
# [520, 'Sambucus', 326, 326]
# [521, 'Viburnum tinus', 326, 326]
# [522, 'Lonicera etrusca', 326, 326]
# [523, 'Lonicera', 327, 327]
# [524, 'Lonicera orientalis', 327, 327]
# [525, 'Valeriana dioscoridis', 328, 328]
# [526, 'Centranthus longiflorus', 328, 328]
# [527, 'Valerianella tuberculata', 330, 330]
# [528, 'Valerianella dactylophylla', 330, 330]
# [529, 'Valerianella oxyrhyncha', 331, 331]
# [530, 'Valerianella cymbicarpa', 331, 331]
# [531, 'Valerianella szovitsiana', 331, 331]
# [532, 'Valerianella', 337, 337]
# [533, 'Valerianella soyeri', 333, 333]
# [534, 'Valerianella locusta', 333, 333]
# [535, 'Valerianella dentata', 334, 334]
# [536, 'Valerianella muricata', 334, 334]
# [537, 'Valerianella carinata', 334, 334]
# [538, '.Valerianella', 335, 335]
# [539, 'Valerianella pumila', 335, 335]
# [540, 'Valerianella antilibanotica', 336, 336]
# [541, 'Valerianella coronata', 337, 337]
# [542, 'Valerianella discoidea', 337, 337]
# [543, 'Valerianella vesicaria', 338, 338]
# [544, 'Morina', 338, 338]
# [545, 'Dipsacus sativus', 339, 339]
# [546, 'Dipsacus', 339, 339]
# [547, 'Dipsacus laciniatus', 340, 340]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [548, 'Cephalaria', 344, 344]
# [549, 'Cephalaria syriaca', 342, 342]
# [550, 'Cephalaria.amana', 344, 344]
# [551, 'Cephalaria cedrorum', 345, 345]
# [552, 'Knautia integrifolia', 346, 346]
# [553, 'Knautia bidens', 346, 346]
# [554, 'Pterocephalus', 346, 346]
# [555, 'Pterocephalus brevis', 347, 347]
# [556, 'Pterocephalus pulverulentus', 347, 347]
# [557, 'Scabiosa', 352, 352]
# [558, 'Scabiosa intermedia', 349, 349]
# [559, 'Scabiosa argentea', 349, 349]
# [560, 'Scabiosa palaestina', 351, 351]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [561, 'Cucumis phrophetarum', 353, 353]
# [562, 'Citrullus colocynthis', 354, 354]
# [563, 'Ecballium elaterium', 354, 354]
# [564, 'Bryonia', 355, 355]
# [565, 'Bryonia syriaca', 355, 355]
# [566, 'Bryonia lasiocarpa', 355, 355]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [567, "Note de l'éditeur:", 355, 355]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [568, 'Laurentia minuta', 356, 356]
# [569, 'Laurentia gasparrinii', 356, 356]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [570, 'Campanula euclasta', 358, 358]
# [571, 'Campanula', 365, 365]
# [572, 'Campanula trichopoda', 359, 359]
# [573, 'Campanula stricta', 360, 360]
# [574, 'Campanula stellaris', 360, 360]
# [575, 'Campanula,', 361, 361]
# [576, 'Campanula propinqua', 361, 361]
# [577, 'Campanula cecilii', 362, 362]
# [578, 'Campanula reuteriana', 362, 362]
# [579, 'Campanula hierosolymitana', 362, 362]
# [580, 'Campanula camptoclada', 363, 363]
# [581, 'Campanula erinus', 363, 363]
# [582, 'Campanula peregrina', 363, 363]
# [583, 'Campanula rapunculus', 364, 364]
# [584, 'Campanula kotschyana', 365, 365]
# [585, 'Campanula flaccidula', 365, 365]
# [586, 'Campanula sidoniensis', 366, 366]
# [587, 'Campanula fastigiata', 366, 366]
# [588, 'Michauxia campanuloides', 367, 367]
# [589, 'Michauxia', 367, 367]
# [590, 'Asyneuma virgatum', 368, 368]
# [591, 'Asyneuma rigidum', 368, 368]
# [592, 'Legousia falcata', 369, 369]
# [593, 'Legousia speculum-veneris', 369, 369]
# [594, 'Legousia pentagonia', 369, 369]
# [595, 'Tracheliopsis tubulosa', 370, 370]
# [596, 'Tracheliopsis', 371, 371]
# [597, 'Tracheliopsis postii', 371, 371]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [598, 'Eupatorium', 372, 372]
# [599, 'en', 372, 372]
# [600, 'Solidago', 373, 373]
# [601, 'Erigeron libanoticus', 373, 373]
# [602, 'Erigeron', 374, 374]
# [603, 'Erigeron bonariensis', 374, 374]
# [604, 'Erigeron naudinii', 374, 374]
# [605, 'Psychrogeton nigromontanus', 375, 375]
# [606, 'Pluchea dioscoridis', 375, 375]
# [607, 'Bellis', 376, 376]
# [608, 'Bellis perennis', 376, 376]
# [609, 'Bellis sylvestris', 376, 376]
# [610, 'Asteriscus aquaticus', 377, 377]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
#  68%|██████▊   | 611/896 [00:00<00:00, 845.48it/s]
# [611, 'Asteriscus pygmaeus', 377, 377]
# [612, 'Asteriscus graveolens', 377, 377]
# [613, 'Pallenis spinosa', 378, 378]
# [614, 'Postia', 379, 379]
# [615, 'Inula', 381, 381]
# [616, 'Inula vulgaris', 380, 380]
# [617, 'Inula crithmoides', 380, 380]
# [618, 'Inula heterolepis', 380, 380]
# [619, 'Inula graveolens', 381, 381]
# [620, 'Pentanema divaricata', 381, 381]
# [621, 'Pulicaria dysenterica', 382, 382]
# [622, 'Pulicaria', 383, 383]
# [623, 'Pulicaria auranitica', 383, 383]
# [624, 'Pulicaria arabica', 383, 383]
# [625, 'Pulicaria laniceps', 384, 384]
# [626, 'Francœuria', 384, 384]
# [627, 'Varthemia iphionoides', 385, 385]
# [628, 'Phagnalon', 386, 386]
# [629, 'Phagnalon kotschyi', 386, 386]
# [630, 'Lasiopogon', 386, 386]
# [631, 'Gnaphalium', 387, 387]
# [632, 'Gnaphalium uliginosum', 387, 387]
# [633, 'Helichrysum', 391, 391]
# [634, 'Helichrysum armenium', 389, 389]
# [635, 'Helichrysum pallasii', 389, 389]
# [636, 'Helichrysum plicatum', 390, 390]
# [637, 'Helichrysum sanguineum', 391, 391]
# [638, 'Leysera leyseroides', 392, 392]
# [639, 'Gymnarrhena micrantha', 393, 393]
# [640, 'Micropus supinus', 393, 393]
# [641, 'Bombycilaena discolor', 394, 394]
# [642, 'Bombycilaena erecta', 394, 394]
# [643, 'Cymbolaena', 394, 394]
# [644, 'Filago', 398, 398]
# [645, 'Filago pyramidata', 396, 396]
# [646, 'Filago arvensis', 397, 397]
# [647, 'Filago gallica', 397, 397]
# [648, 'Filago anatolica', 398, 398]
# [649, 'Filago palaestina', 398, 398]
# [650, 'Filago contracta', 399, 399]
# [651, 'Filago pygmaea', 399, 399]
# [652, 'Ifloga spicata', 399, 399]
# [653, 'Eclipta prostrata', 400, 400]
# [654, 'Guizotia', 400, 400]
# [655, 'Bidens', 401, 401]
# [656, 'Bidens pilosa L.', 401, 401]
# [657, 'Bidens frondosa', 401, 401]
# [658, 'Tagetes minuta', 401, 401]
# [659, 'Ambrosia maritima', 402, 402]
# [660, 'Xanthium', 402, 402]
# [661, 'Xanthium echinatum', 403, 403]
# [662, 'Xanthium strumarium', 403, 403]
# [663, 'Otanthus maritimus', 403, 403]
# [664, 'Achillea membranacea', 404, 404]
# [665, 'Achillea oligocephala', 405, 405]
# [666, 'Achillea', 407, 407]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [667, 'Achillea falcata', 406, 406]
# [668, 'Achillea conferta', 406, 406]
# [669, 'Achillea kotschyi', 407, 407]
# [670, 'Anthémis', 420, 420]
# [671, 'Anthémis samuelssonii', 413, 413]
# [672, 'Anthémis eretica', 413, 413]
# [673, 'Anthémis wettsteiniana', 415, 415]
# [674, 'Anthémis chia', 417, 417]
# [675, 'Anthémis pseudocotula', 419, 419]
# [676, 'Chamaemelum mixtum', 421, 421]
# [677, 'Anacyclus radiatus', 422, 422]
# [678, 'Anacyclus clavatus', 422, 422]
# [679, 'Anacyclus nigellifolius', 422, 422]
# [680, 'Matricaria chamomilla', 423, 423]
# [681, 'Matricaria aurea', 423, 423]
# [682, 'Tripleurospermum', 425, 425]
# [683, 'Tripleurospermum auriculatum', 424, 424]
# [684, 'Tripleurospermum sannineum', 425, 425]
# [685, 'Tripleurospermum oreades', 425, 425]
# [686, 'Chrysanthemum', 426, 426]
# [687, 'Chrysanthemum segetum', 427, 427]
# [688, 'Chrysanthemum coronarium', 427, 427]
# [689, 'Tanacetum', 429, 429]
# [690, 'Tanacetum poteriifolium', 428, 428]
# [691, 'Tanacetum cilicium', 428, 428]
# [692, 'Tanacetum yabrudae', 429, 429]
# [693, 'Tanacetum aucheri', 430, 430]
# [694, 'Tanacetum argenteum', 430, 430]
# [695, 'Artemisia monosperma', 431, 431]
# [696, 'Artemisia scoparia', 431, 431]
# [697, 'Artemisia annua', 431, 431]
# [698, 'Artemisiaherba-alba', 432, 432]
# [699, 'Artemisia verlotorum', 432, 432]
# [700, 'Artemisia arborescens', 432, 432]
# [701, 'Tussilago farfara', 433, 433]
# [702, 'Doronicum orientale', 433, 433]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [703, 'Senecio vulgaris', 434, 434]
# [704, 'Senecio', 438, 438]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [705, 'Senecio vernalis', 435, 435]
#  79%|███████▉  | 706/896 [00:00<00:00, 873.82it/s]
# [706, 'Senecio exilis', 436, 436]
# [707, 'Senecio gallicus', 436, 436]
# [708, 'Senecio aquaticus', 436, 436]
# [709, 'Senecio mouterdei', 437, 437]
# [710, 'Calendula officinalis', 439, 439]
# [711, 'Calendula sinuata', 439, 439]
# [712, 'Calendula bicolor', 440, 440]
# [713, 'Calendula arvensis', 440, 440]
# [714, 'Calendula aegyptiaca', 440, 440]
# [715, 'Calendula palaestina', 441, 441]
# [716, 'Calendula tripterocarpa', 441, 441]
# [717, 'Dipterocome pusilla', 441, 441]
# [718, 'Gundelia', 442, 442]
# [719, 'Echinops', 444, 444]
# [720, 'Echinops gaillardotii', 443, 443]
# [721, 'Acantholepis', 445, 445]
# [722, 'Cardopatium corymbosum', 445, 445]
# [723, 'Xeranthemum', 447, 447]
# [724, 'Xeranthemum inapertum', 446, 446]
# [725, 'Xeranthemum cylindraceum', 447, 447]
# [726, 'Chardinia', 448, 448]
# [727, 'Siebera', 448, 448]
# [728, 'Carlina', 451, 451]
# [729, 'Garlina', 450, 450]
# [730, 'Carlina hispanica', 450, 450]
# [731, 'Carlina kurdica', 450, 450]
# [732, 'Atractylis carduus', 451, 451]
# [733, 'Atractylis cancellata', 452, 452]
# [734, 'Atractylis', 452, 452]
# [735, 'Staehelina', 452, 452]
# [736, 'Arctium', 453, 453]
# [737, 'Cousinia', 457, 457]
# [738, 'Gousinia ramosissima', 455, 455]
# [739, 'Cousinia stenocephala', 455, 455]
# [740, 'Cousinia postiana', 455, 455]
# [741, 'Gousinia', 456, 456]
# [742, 'Cousinia libanotica', 456, 456]
# [743, 'Carduus nutans', 458, 458]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [744, 'Garduus', 458, 458]
# [745, 'Garduus pycnocephalus', 458, 458]
# [746, 'Carduus argentatus', 459, 459]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [747, 'Cirsium', 462, 462]
# [748, 'Cirsium phyllocephalum', 460, 460]
# [749, 'Cirsium amani', 461, 461]
# [750, 'Cirsium vulgare', 461, 461]
# [751, 'Cirsium libanoticum', 462, 462]
# [752, 'Picnomon acarna', 463, 463]
# [753, 'Notobasis syriaca', 463, 463]
# [754, 'Ptilostemon chamaepeuce', 464, 464]
# [755, 'Ptilostemon diacantha', 464, 464]
# [756, 'Ptilostemon x Pabotii', 465, 465]
# [757, 'Tyrimnus leucographus', 465, 465]
# [758, 'Silybum marianum', 466, 466]
# [759, 'Cynara syriaca', 466, 466]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [760, 'Onopordum carduiforme', 467, 467]
# [761, 'Onopordum cynarocephalum', 468, 468]
# [762, 'Onopordum', 470, 470]
# [763, 'Onopordum illyricum', 469, 469]
# [764, 'Onopordum syriacum', 469, 469]
# [765, 'Myopordon thiebauti', 470, 470]
# [766, 'Myopordon pulchellum', 470, 470]
# [767, 'Jurinea staehelinae', 471, 471]
# [768, 'Jurinea mesopotamica', 471, 471]
# [769, 'Zoegea leptaurea', 472, 472]
# [770, 'Zoegea purpurea', 472, 472]
# [771, 'Crupina crupinastrum', 473, 473]
# [772, 'Serratula cerinthifolia', 474, 474]
# [773, 'Serratula mouterdei', 474, 474]
# [774, 'Serratula', 475, 475]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [775, 'Centaurea', 499, 499]
# [776, 'Centaurea reducta', 480, 480]
# [777, 'Centaurea dumulosa', 480, 480]
# [778, 'Centaurea damascena', 480, 480]
# [779, 'virgata', 481, 481]
# [780, 'Centaurea ammocyanus', 481, 481]
# [781, 'Centaurea laxa', 482, 482]
# [782, 'Centaurea blancheana', 482, 482]
# [783, 'Centaurea cassia', 483, 483]
# [784, 'Centaurea longispina', 483, 483]
# [785, 'Centaurea speciosa', 485, 485]
# [786, 'Centaurea postii', 485, 485]
# [787, 'Centaurea regia', 486, 486]
# [788, 'onopordifolia', 487, 487]
# [789, 'Centaurea spicata', 488, 488]
# [790, 'Centaurea simulans', 488, 488]
# [791, 'Centaurea babylonica', 488, 488]
# [792, 'Centaurea rigida', 489, 489]
# [793, 'Centaurea ptosimopappa', 490, 490]
# [794, 'Centaurea solstitialis', 491, 491]
# [795, 'Centaurea sinaica', 491, 491]
# [796, 'Centaurea mesopotamica', 492, 492]
# [797, 'Centaurea verutum', 492, 492]
# [798, 'Centaurea calcitrapa', 493, 493]
#  89%|████████▉ | 799/896 [00:00<00:00, 887.36it/s]
# [799, 'Centaurea iberica', 493, 493]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [800, 'Centaurea pallescens', 494, 494]
# [801, 'Centaurea procurrens', 495, 495]
# [802, 'Centaurea bruguieriana', 495, 495]
# [803, 'Centaurea eryngioides', 496, 496]
# [804, 'Centaurea mouterdei', 496, 496]
# [805, 'Centaurea carduiformis', 497, 497]
# [806, 'Centaurea trachonitica', 498, 498]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [807, 'Centaurea heterocarpa', 498, 498]
# [808, 'Centaurea triumfettii', 499, 499]
# [809, 'Centaurea cyanus', 500, 500]
# [810, 'Cnicus benedictus', 500, 500]
# [811, 'Carthamus', 503, 503]
# [812, 'Carthamus persicus', 501, 501]
# [813, 'Carthamus dentatus', 504, 504]
# [814, 'Carthamus glaucus', 504, 504]
# [815, 'Carduncellus', 505, 505]
# [816, 'Scolymus maculatus', 505, 505]
# [817, 'Scolymus hispanicus', 505, 505]
# [818, 'Catananche lutea', 506, 506]
# [819, 'Cichorium intybus', 506, 506]
# [820, 'Cichorium pumilum', 506, 506]
# [821, 'Hyoseris scabra', 507, 507]
# [822, 'Hedypnois rhagadioloides', 508, 508]
# [823, 'Hedypnois', 508, 508]
# [824, 'Lapsana', 509, 509]
# [825, 'Koelpinia linearis', 509, 509]
# [826, 'Rhagadiolus', 510, 510]
# [827, 'Rhagadiolus edulis', 510, 510]
# [828, 'Garhadiolus hedypnois', 510, 510]
# [829, 'Garhadiolus', 511, 511]
# [830, 'Garhadiolus papposus', 511, 511]
# [831, 'Tolpis barbata', 512, 512]
# [832, 'Tolpis virgata', 512, 512]
# [833, 'Leontodon tuberosus', 513, 513]
# [834, 'Leontodon laciniatus', 513, 513]
# [835, 'Leontodon', 514, 514]
# [836, 'Urospermum picroides', 514, 514]
# [837, 'Picris hieracioides', 515, 515]
# [838, 'Picris strigosa', 515, 515]
# [839, 'Picris altissima', 516, 516]
# [840, 'Picris kotschyi', 516, 516]
# [841, 'Picris longirostris', 516, 516]
# [842, 'Picris', 517, 517]
# [843, 'Tragopogon hybridum', 518, 518]
# [844, 'Tragopogon longirostris', 518, 518]
# [845, 'Tragopogon', 519, 519]
# [846, 'Tragopogon pterocarpus', 520, 520]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [847, 'Scorzonera cana', 521, 521]
# [848, 'Scorzonera mollis', 522, 522]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [849, 'Scorzonera', 526, 526]
# [850, 'Scorzonera libanotica', 523, 523]
# [851, 'Scorzonera papposa', 524, 524]
# [852, 'Scorzonera mackmeliana', 525, 525]
# [853, 'Scorzonera rigida', 525, 525]
# [854, 'Scorzonera judaica', 525, 525]
# [855, 'Scorzonera nervosa', 526, 526]
# [856, 'Hypochoeris', 527, 527]
# [857, 'Seriola', 527, 527]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [858, 'Taraxacum bessarabicum', 529, 529]
# [859, 'Taraxacum assemanii', 529, 529]
# [860, 'Taraxacum', 532, 532]
# [861, 'Taraxacum serotinum', 530, 530]
# [862, 'Taraxacum brevirostre', 530, 530]
# [863, 'Taraxacum syriacum', 530, 530]
# [864, 'Taraxacum montanum', 530, 530]
# [865, 'Taraxacum bithynicum', 530, 530]
# [866, 'Taraxacum officinale', 532, 532]
# [867, 'Taraxacum laevigatum', 532, 532]
# [868, 'Ghondrilla', 533, 533]
# [869, 'Sonchus', 534, 534]
# [870, 'Sonchus tenerrimus', 534, 534]
# [871, 'Lactuca serriola', 535, 535]
# [872, 'Lactuca aculeata', 535, 535]
# [873, 'Lactuca saligna', 535, 535]
# [874, 'Lactuca', 536, 536]
# [875, 'Scariola viminea', 536, 536]
# [876, 'Scariola orientalis', 537, 537]
# [877, 'Scariola triquetra', 537, 537]
# [878, 'Steptorhamphus', 538, 538]
# [879, 'Cicerbita', 538, 538]
# [880, 'Cephalorrhynchus tuberosus', 539, 539]
# [881, 'Reichardia', 540, 540]
# [882, 'Reichardia intermedia', 540, 540]
# [883, 'Reichardia picroides', 540, 540]
# [884, 'Reichardia glauca', 540, 540]
# [885, 'Launaea', 541, 541]
# 100%|██████████| 896/896 [00:01<00:00, 864.74it/s]
# [886, 'Launaea nudicaulis', 541, 541]
# [887, 'Aetheorhiza', 542, 542]
# [888, 'Crépis', 549, 549]
# [889, 'Crépis pulchra', 546, 546]
# [890, 'Crépis pterothecoides', 546, 546]
# [891, 'Crépis kotschyana', 547, 547]
# [892, 'Andryala integrifolia', 550, 550]
# [893, 'Hieracium bauhinii', 551, 551]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [894, 'n.', 551, 551]
# ['ERROR: ', 'Extra', Rect(2147483520.0, 2147483520.0, -2147483648.0, -2147483648.0)]
# [895, 'Hieracium', 552, 552]
# results-marked-pages-book-3.pdf

# %%
doc.name
# Out:
# 'marked-pages-book-1.pdf'

# %%
import pandas as pd

df = pd.DataFrame.from_dict(results.values()).fillna('')
df = df[df.columns.drop(list(df.filter(regex='_rects')))]
df.to_csv("book-1.csv", index=False)
df
# Out:
#                         name  pdf_page  book_page  \
# 0                          J        59         59
# 1                         JL        77         77
# 2         Lycopodium cernuum        78         78
# 3    Selaginella denticulata        79         79
# 4            Isoetes hystrix        79         79
# ..                       ...       ...        ...
# 856        Dianthus strictus       599        599
# 857        Dianthus judaicus       603        603
# 858    Dianthus pachypetalus       603        603
# 859        Dianthus crinitus       604        604
# 860   Dianthus actinopetalus       606        606
#
#                                                  Extra  \
# 0    J Lettre alternant dans la transcription de mo...
# 1    Nahal Nik Np Ol P Pb Pr Reese Russ Sam Schw Th...
# 2    Fructification de novembre à mars. Sur grès tr...
# 3    Végétation active de novembre à avril. Fructif...
# 4    Sur terrains très humides, émergée. Spores au ...
# ..                                                 ...
# 856  Floraison: mai-décembre. CC. tous terrains. Le...
# 857  Var. auraniticus (Post.) n. comb. — Calice 3 c...
# 858
# 859                               Floraison: mai-juin.
# 860              Floraison: été. Rochers et murailles.
#
#                                            Description  \
# 0
# 1
# 2    Lycopodium cernuum L. var. capillaceum Willd (...
# 3    Selaginella denticulata (L.) Link — Lycopodium...
# 4    Isoetes hystrix Dur., forma subinermis Dur. (P...
# ..                                                 ...
# 856  Dianthus strictus Banks et Sol. (non Sibth. et...
# 857  Dianthus judaicus Boiss. — D. pattens Sibth. e...
# 858  Dianthus pachypetalus Stapf— D. floribundus Bo...
# 859  Dianthus crinitus Smith (PI. CLXXXV, n. 4). — ...
# 860  Dianthus actinopetalus Fenzl (PI. CLXXXVI, n. ...
#
#                                                     L.  \
# 0
# 1
# 2    L. Mi. Entre Nahr es Safa et 'Aïn Qa'a, 1942 e...
# 3    L. Ct. et ML, Ce. Saïda (Bl), Beyrouth et envi...
# 4    L. 'Akkar. Prairies humides au nord de la rout...
# ..                                                 ...
# 856
# 857  L. Sy. Baalbeck (Wall). St. Qamou'at Hermel (P...
# 858
# 859
# 860
#
#                                                   Aire  \
# 0
# 1
# 2    Aire géogr. —- Régions tropicales et subtropic...
# 3    Aire géogr. —• Tour de la Méditerranée. Madère...
# 4    Aire géogr. — Tour de la Méditerranée, Côte de...
# ..                                                 ...
# 856
# 857  Aire géogr. — Turquie sud, Syrie, Liban, Pales...
# 858
# 859  Aire géogr. — Turquie, Géorgie, Iran, Bélouchi...
# 860       Aire géogr. — Ile de Cos, Turquie, Antioche.
#
#                                                     S.
# 0
# 1
# 2
# 3    S. Non signalée. Présence presque certaine, Ct...
# 4    S. Présence non constatée mais presque certain...
# ..                                                 ...
# 856
# 857  S. A.L. Ouadi-el-Qarn (Sam, Mt, Pb), Zebdani, ...
# 858
# 859                                 S. St. Zélaf (Pb).
# 860                  S. Est de Lattaquié : Bdama (JL).
#
# [861 rows x 8 columns]

# %%
# !open -a Preview results-marked-pages-book-1.pdf
