# %%
import pandas as pd

# %%
text_file_path = '../input/wcvp_v9_jun_2022.txt'
file_df = pd.read_csv(text_file_path, sep = '|')

# %%
file_df.shape
# Out:
# (1232931, 18)

# %%
file_df['taxonomic_status'].unique()
# Out:
# array(['Synonym', 'Homotypic_Synonym', 'Accepted', 'Unplaced',
#        'Artificial Hybrid'], dtype=object)

# %%
not_accepted = file_df[(file_df['taxonomic_status'] != 'Accepted')]

# %%
not_accepted_no_accId = not_accepted[((not_accepted['accepted_kew_id']).isnull())]

# %%
no_acc_kew_has_acc_name = file_df[~((file_df['accepted_kew_id']).isnull()) & ((file_df['accepted_name']).isnull())]

# %%
file_df[((file_df['accepted_kew_id']).isnull()) & ~((file_df['accepted_name']).isnull())]
# Out:
# Empty DataFrame
# Columns: [kew_id, family, genus, species, infraspecies, taxon_name, authors, rank, taxonomic_status, accepted_kew_id, accepted_name, accepted_authors, parent_kew_id, parent_name, parent_authors, reviewed, publication, original_name_id]
# Index: []

# %%
not_accepted_no_accId['taxonomic_status'].unique()
# Out:
# array(['Unplaced', 'Synonym', 'Homotypic_Synonym', 'Artificial Hybrid'],
#       dtype=object)

# %%
not_accepted_id = file_df[((file_df['accepted_kew_id']).isnull()) & (file_df['taxonomic_status'] != 'Accepted')]
# Out:
#            kew_id          family        genus       species infraspecies  \
# 84        44844-1     Acanthaceae     Acanthus     boissieri          NaN
# 128       44874-1     Acanthaceae     Acanthus    imbricatus          NaN
# 153       44904-1     Acanthaceae     Acanthus      ponticus          NaN
# 159       44913-1     Acanthaceae     Acanthus        rubens          NaN
# 184       19963-1     Acanthaceae     Adelaida           NaN          NaN
# ...           ...             ...          ...           ...          ...
# 1232806  873626-1  Zygophyllaceae  Zygophyllum   maximiliani          NaN
# 1232870  873674-1  Zygophyllaceae  Zygophyllum  ramosissimum          NaN
# 1232879  873682-1  Zygophyllaceae  Zygophyllum       rigidum          NaN
# 1232898  873697-1  Zygophyllaceae  Zygophyllum       sonderi          NaN
# 1232899  873698-1  Zygophyllaceae  Zygophyllum    spatulatum          NaN
#
#                        taxon_name             authors     rank  \
# 84             Acanthus boissieri            Hausskn.  SPECIES
# 128           Acanthus imbricatus              Edgew.  SPECIES
# 153             Acanthus ponticus            Jordanov  SPECIES
# 159               Acanthus rubens                Raf.  SPECIES
# 184                      Adelaida             Buc'hoz    GENUS
# ...                           ...                 ...      ...
# 1232806   Zygophyllum maximiliani  Schltr. ex Huysst.  SPECIES
# 1232870  Zygophyllum ramosissimum               Popov  SPECIES
# 1232879       Zygophyllum rigidum               Royle  SPECIES
# 1232898       Zygophyllum sonderi           H.Eichler  SPECIES
# 1232899    Zygophyllum spatulatum               D.Don  SPECIES
#
#         taxonomic_status accepted_kew_id accepted_name accepted_authors  \
# 84              Unplaced             NaN           NaN              NaN
# 128             Unplaced             NaN           NaN              NaN
# 153             Unplaced             NaN           NaN              NaN
# 159             Unplaced             NaN           NaN              NaN
# 184             Unplaced             NaN           NaN              NaN
# ...                  ...             ...           ...              ...
# 1232806         Unplaced             NaN           NaN              NaN
# 1232870         Unplaced             NaN           NaN              NaN
# 1232879          Synonym             NaN           NaN              NaN
# 1232898         Unplaced             NaN           NaN              NaN
# 1232899         Unplaced             NaN           NaN              NaN
#
#         parent_kew_id parent_name parent_authors   reviewed  \
# 84                NaN         NaN            NaN  In review
# 128               NaN         NaN            NaN  In review
# 153               NaN         NaN            NaN  In review
# 159               NaN         NaN            NaN  In review
# 184               NaN         NaN            NaN  In review
# ...               ...         ...            ...        ...
# 1232806           NaN         NaN            NaN  In review
# 1232870           NaN         NaN            NaN  In review
# 1232879           NaN         NaN            NaN  In review
# 1232898           NaN         NaN            NaN  In review
# 1232899           NaN         NaN            NaN  In review
#
#                                                publication original_name_id
# 84         Mitt. Geogr. Ges. (Thüringen) Jena 5: 62 (1887)              NaN
# 128                  J. Asiat. Soc. Bengal 16: 1217 (1847)              NaN
# 153      God. Sofiisk. Univ. Fiz.-Mat. Fak. 30: 412 (1934)              NaN
# 159                                  Fl. Ludov.: 37 (1817)              NaN
# 184                    Herb. Color. Amérique: t. 74 (1783)              NaN
# ...                                                    ...              ...
# 1232806  Morphol.-Syst. Stud. Gatt. Zygophyllum: 60 (1937)              NaN
# 1232870  Byull. Sredne-Aziatsk. Gosud. Univ. 11: 115 (1...              NaN
# 1232879                  Ill. Bot. Himal. Mts.: 154 (1835)              NaN
# 1232898                               Taxon 12: 297 (1963)       77202377-1
# 1232899                           Gen. Hist. 1: 771 (1831)              NaN
#
# [48195 rows x 18 columns]

# %%
output = '../output/wcvp_v9_jun_2022.csv'
file_df.to_csv()
# Out:
#              kew_id          family        genus       species infraspecies  \
# 0             338-1     Acanthaceae  Acanthodium           NaN          NaN
# 1           44787-1     Acanthaceae  Acanthodium      angustum          NaN
# 2           44788-1     Acanthaceae  Acanthodium       capense          NaN
# 3           44789-1     Acanthaceae  Acanthodium  carduifolium          NaN
# 4           44790-1     Acanthaceae  Acanthodium       delilii          NaN
# ...             ...             ...          ...           ...          ...
# 1232926    873721-1  Zygophyllaceae  Zygophyllum     webbianum          NaN
# 1232927  77205534-1  Zygophyllaceae  Zygophyllum   xanthoxylum          NaN
# 1232928    873723-1  Zygophyllaceae  Zygophyllum   zanthoxylum          NaN
# 1232929  77184991-1  Zygophyllaceae  Zygophyllum     zilloides          NaN
# 1232930    873724-1  Zygophyllaceae  Zygophyllum    zonuzensis          NaN
#
#                        taxon_name                      authors     rank  \
# 0                     Acanthodium                       Delile    GENUS
# 1            Acanthodium angustum                         Nees  SPECIES
# 2             Acanthodium capense                  (L.f.) Nees  SPECIES
# 3        Acanthodium carduifolium                  (L.f.) Nees  SPECIES
# 4             Acanthodium delilii                       H.Buek  SPECIES
# ...                           ...                          ...      ...
# 1232926     Zygophyllum webbianum                        Coss.  SPECIES
# 1232927   Zygophyllum xanthoxylum               (Bunge) Maxim.  SPECIES
# 1232928   Zygophyllum zanthoxylum              Engl. ex Dippel  SPECIES
# 1232929     Zygophyllum zilloides  (Humbert) Christenh. & Byng  SPECIES
# 1232930    Zygophyllum zonuzensis                       Sabeti  SPECIES
#
#           taxonomic_status accepted_kew_id  \
# 0                  Synonym           427-1
# 1        Homotypic_Synonym         46469-1
# 2        Homotypic_Synonym         46487-1
# 3        Homotypic_Synonym         44830-1
# 4                  Synonym         46503-1
# ...                    ...             ...
# 1232926            Synonym        873565-1
# 1232927           Accepted             NaN
# 1232928            Synonym      77205534-1
# 1232929           Accepted             NaN
# 1232930            Synonym      77251284-1
#
#                                   accepted_name     accepted_authors  \
# 0                                     Blepharis                Juss.
# 1                             Blepharis angusta    (Nees) T.Anderson
# 2                            Blepharis capensis         (L.f.) Pers.
# 3                       Acanthopsis carduifolia        (L.f.) Schinz
# 4                              Blepharis edulis      (Forssk.) Pers.
# ...                                         ...                  ...
# 1232926                  Zygophyllum fontanesii      Webb & Berthel.
# 1232927                                     NaN                  NaN
# 1232928                 Zygophyllum xanthoxylum       (Bunge) Maxim.
# 1232929                                     NaN                  NaN
# 1232930  Tetracera sarmentosa subsp. andamanica  (Hoogland) Hoogland
#
#         parent_kew_id  parent_name parent_authors   reviewed  \
# 0                 NaN          NaN            NaN  In review
# 1                 NaN          NaN            NaN  In review
# 2                 NaN          NaN            NaN  In review
# 3                 NaN          NaN            NaN  In review
# 4                 NaN          NaN            NaN  In review
# ...               ...          ...            ...        ...
# 1232926           NaN          NaN            NaN  In review
# 1232927       41749-1  Zygophyllum             L.  In review
# 1232928           NaN          NaN            NaN  In review
# 1232929       41749-1  Zygophyllum             L.  In review
# 1232930           NaN          NaN            NaN  In review
#
#                                            publication original_name_id
# 0        Descr. Egypte, Hist. Nat. 2(Mém.): 241 (1813)              NaN
# 1               A.P.de Candolle, Prodr. 11: 273 (1847)              NaN
# 2                               Linnaea 15: 361 (1841)              NaN
# 3               A.P.de Candolle, Prodr. 11: 278 (1847)          44848-1
# 4                        Gen. Sp. Candoll. 3: 1 (1858)              NaN
# ...                                                ...              ...
# 1232926           Bull. Soc. Bot. France 2: 365 (1855)              NaN
# 1232927                        Fl. Tangut.: 103 (1889)         873370-1
# 1232928                Handb. Laubholzk. 2: 358 (1893)              NaN
# 1232929                        Global Fl. 4: 93 (2018)         873235-1
# 1232930     Forests, Trees & Shrubs of Iran: 12 (1976)              NaN
#
# [1232931 rows x 18 columns]
